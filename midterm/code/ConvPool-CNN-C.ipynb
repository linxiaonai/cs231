# %%
import torch
from torch.utils.data import sampler
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import os
import copy
import matplotlib.pyplot as plt

# %%
NUM_TRAIN = 49000

transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
            ])
cifar10_train = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=True,
                                           download=True, transform=transform)
loader_train = torch.utils.data.DataLoader(cifar10_train, batch_size=64,
                                      sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))
cifar10_val = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=False,
                                         download=True, transform=transform)
loader_val = torch.utils.data.DataLoader(cifar10_train, batch_size=64,
                                    sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))
cifar10_test = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=False,
                                         download=True, transform=transform)
loader_test = torch.utils.data.DataLoader(cifar10_train, batch_size=64)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_images, train_labels = iter(loader_train).next()
print("train_X:", train_images.size(), "train_y:", train_labels.size())
val_images, val_labels = iter(loader_val).next()
print("val_X:", val_images.size(), "val_y:", val_labels.size())
test_images, test_labels = iter(loader_test).next()
print("test_X:", test_images.size(), "test_y:", test_labels.size())
# Out:
# train_X: torch.Size([64, 3, 32, 32]) train_y: torch.Size([64])
# val_X: torch.Size([64, 3, 32, 32]) val_y: torch.Size([64])
# test_X: torch.Size([64, 3, 32, 32]) test_y: torch.Size([64])

# %%
USE_GPU = True

dtype = torch.float32

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
print('using device', device)
# Out:
# using device cuda

# %%
class Model(nn.Module):
    def __init__(self, in_channel, channel_1, channel_2, 
                 channel_3, channel_4, num_classes):
        """
        Default initialization:
        model = Model(in_channel=3, channel_1=96, channel_2=192, 
                 channel_3=192, channel_4=192, num_classes=10)
        """
        super().__init__()
        self.conv1_1 = nn.Conv2d(in_channel, channel_1, 3, padding=1)  #(3, 96, 3)
        self.conv1_2 = nn.Conv2d(channel_1, channel_1, 3, padding=1)   #(96, 96, 3)
        self.conv1_3 = nn.Conv2d(channel_1, channel_1, 3, padding=1)  #(96, 96, 3)
        self.pool1 = nn.MaxPool2d(3, stride=2, padding=1)
        self.conv2_1 = nn.Conv2d(channel_1, channel_2, 3, padding=1)   #(96, 192, 3)
        self.conv2_2 = nn.Conv2d(channel_2, channel_2, 3, padding=1)   #(192, 192, 3)
        self.conv2_3 = nn.Conv2d(channel_2, channel_2, 3, padding=1)  #(192, 192, 3)
        self.pool2 = nn.MaxPool2d(3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(channel_2, channel_3, 3)   #(192, 192, 3)
        self.conv4 = nn.Conv2d(channel_3, channel_4, 1)   #(192, 192, 1)
        self.conv5 = nn.Conv2d(channel_4, num_classes, 1) #(192, 10, 1)
        
    def forward(self, x):
        """
        x.shape: (64, 3, 32, 32)
        """
        N = x.shape[0]
        x_drop = F.dropout(x, .2)
        conv1_1_out = F.relu(self.conv1_1(x_drop))            # (64, 96, 32, 32)
        conv1_2_out = F.relu(self.conv1_2(conv1_1_out))  # (64, 96, 32, 32)
        conv1_3_out = F.relu(self.conv1_3(conv1_2_out))  # (64, 96, 32, 32)
        layer1_out = self.pool1(conv1_3_out)                        # (64, 96, 16, 16)
        layer1_out_drop = F.dropout(layer1_out, .5)
        conv2_1_out = F.relu(self.conv2_1(layer1_out_drop))   # (64, 192, 16, 16)
        conv2_2_out = F.relu(self.conv2_2(conv2_1_out))   # (64, 192, 16, 16)        
        conv2_3_out = F.relu(self.conv2_3(conv2_2_out))   # (64, 192, 16, 16)        
        layer2_out = self.pool2(conv2_3_out)                      # (64, 192, 8, 8)
        layer2_out_drop = F.dropout(layer2_out, .5)
        layer3_out = F.relu(self.conv3(layer2_out_drop))             # (64, 192, 6, 6)
        layer4_out = F.relu(self.conv4(layer3_out))             # (64, 192, 6, 6)
        layer5_out = F.relu(self.conv5(layer4_out))             # (64, 10, 6, 6)
#         print(x.size(), conv1_1_out.size(), conv1_2_out.size(), layer1_out.size(),layer5_out.size())
        out = layer5_out.view(N, 10, -1).mean(dim=2)
        return out
        
def test_Model():
    x = torch.zeros((64, 3, 32, 32), dtype=dtype)
    model = Model(in_channel=3, channel_1=96, channel_2=192, 
                 channel_3=192, channel_4=192, num_classes=10)
    scores = model(x)
    print(scores.size())
test_Model()
# Out:
# torch.Size([64, 10])

# %%
def check_accuracy(loader, model):
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set') 
    num_correct = 0
    num_samples = 0
    model.eval()
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            scores = model(x)
            _, preds = scores.max(1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def plot(x_lst, y_lst, path, name, xlabel, ylabel):
    plt.plot(x_lst, y_lst)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    plt.savefig(path + name)

# %%
print_every = 100
    
def train(model, optimizer, scheduler, weight_decay=0.001, epochs=1, best_acc=0.0):
    loss_his = []
    epoch_lst = []
    acc_his = []
    
    model = model.to(device=device)
    model = nn.DataParallel(model,device_ids=[0,1])  
        
    for e in range(epochs):
        scheduler.step()
        for step, (x, y) in enumerate(loader_train):
            model.train()
            x = x.to(device=device, dtype=dtype)
            y = y.to(device=device, dtype=torch.long)
            
            scores = model(x)
            loss = F.cross_entropy(scores, y)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step % print_every == 0:
                print('Epoch %d, Iteration %d, loss = %.4f' % (e, step, loss.item()))
                acc = check_accuracy(loader_val, model)
                if acc > best_acc:
                    best_acc = acc
                    best_model_wts = copy.deepcopy(model.state_dict())
                fo = open("model_convpool_cnn_c.log", "a")
                fo.write("Epoch: {}\t Step: {}\t loss: {:.4f}\t accuracy: {:.2f}\n"\
                         .format(e, step, loss.item(), acc))
                fo.close()
                print()
        epoch_lst.append(e)
        loss_his.append(loss.item())
        acc_his.append(acc)
    
    plot(epoch_lst, loss_his, path="../results figure/", name="Model ConvPool CNN C_Loss accross Epoch", 
        xlabel="epoch", ylabel="loss")
    plot(epoch_lst, acc_his, path="../results figure/", name="Model ConvPool CNN C_Accuracy accross Epoch",
        xlabel="epoch", ylabel="accuracy")
                
    print("Best accuracy:", best_acc)
    fo = open("model_convpool_cnn_c.log", "a")
    fo.write("Best accuracy: {}".format(best_acc))
    fo.close()
    model.load_state_dict(best_model_wts)
    return model

# %%
lr_lst = [0.01]

fo = open("model_convpool_cnn_c.log", "w")
fo.write("Model ConvPool CNN C Trainning log\n")
fo.close()

for learning_rate in lr_lst:
    fo = open("model_convpool_cnn_c.log", "a")
    fo.write("\nOriginal Learning rate: {}\n".format(learning_rate))
    fo.close()
    print("Learning_rate:", learning_rate)
    model = Model(in_channel=3, channel_1=96, channel_2=192, 
             channel_3=192, channel_4=192, num_classes=10) 
    optimizer = optim.SGD(model.parameters(), lr = learning_rate, momentum=0.9, weight_decay=0.001)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                                               milestones=[200, 250, 300], gamma=0.1)
    best_model = train(model, optimizer, scheduler, epochs=350, best_acc=0.0)
    print()
# Out:
# Learning_rate: 0.01
# Epoch 0, Iteration 0, loss = 2.2978
# Checking accuracy on validation set
# Got 78 / 1000 correct (7.80)
#
# Epoch 0, Iteration 100, loss = 2.2992
# Checking accuracy on validation set
# Got 119 / 1000 correct (11.90)
#
# Epoch 0, Iteration 200, loss = 2.3036
# Checking accuracy on validation set
# Got 79 / 1000 correct (7.90)
#
# Epoch 0, Iteration 300, loss = 2.3028
# Checking accuracy on validation set
# Got 78 / 1000 correct (7.80)
#
# Epoch 0, Iteration 400, loss = 2.3009
# Checking accuracy on validation set
# Got 90 / 1000 correct (9.00)
#
# Epoch 0, Iteration 500, loss = 2.3010
# Checking accuracy on validation set
# Got 114 / 1000 correct (11.40)
#
# Epoch 0, Iteration 600, loss = 2.2935
# Checking accuracy on validation set
# Got 141 / 1000 correct (14.10)
#
# Epoch 0, Iteration 700, loss = 2.2944
# Checking accuracy on validation set
# Got 161 / 1000 correct (16.10)
#
# Epoch 1, Iteration 0, loss = 2.2311
# Checking accuracy on validation set
# Got 170 / 1000 correct (17.00)
#
# Epoch 1, Iteration 100, loss = 2.0741
# Checking accuracy on validation set
# Got 177 / 1000 correct (17.70)
#
# Epoch 1, Iteration 200, loss = 2.1388
# Checking accuracy on validation set
# Got 180 / 1000 correct (18.00)
#
# Epoch 1, Iteration 300, loss = 1.9125
# Checking accuracy on validation set
# Got 282 / 1000 correct (28.20)
#
# Epoch 1, Iteration 400, loss = 1.9199
# Checking accuracy on validation set
# Got 270 / 1000 correct (27.00)
#
# Epoch 1, Iteration 500, loss = 1.9135
# Checking accuracy on validation set
# Got 265 / 1000 correct (26.50)
#
# Epoch 1, Iteration 600, loss = 1.7326
# Checking accuracy on validation set
# Got 302 / 1000 correct (30.20)
#
# Epoch 1, Iteration 700, loss = 1.8096
# Checking accuracy on validation set
# Got 289 / 1000 correct (28.90)
#
# Epoch 2, Iteration 0, loss = 1.8604
# Checking accuracy on validation set
# Got 320 / 1000 correct (32.00)
#
# Epoch 2, Iteration 100, loss = 1.6705
# Checking accuracy on validation set
# Got 314 / 1000 correct (31.40)
#
# Epoch 2, Iteration 200, loss = 1.9290
# Checking accuracy on validation set
# Got 287 / 1000 correct (28.70)
#
# Epoch 2, Iteration 300, loss = 1.6521
# Checking accuracy on validation set
# Got 373 / 1000 correct (37.30)
#
# Epoch 2, Iteration 400, loss = 1.8864
# Checking accuracy on validation set
# Got 344 / 1000 correct (34.40)
#
# Epoch 2, Iteration 500, loss = 1.5868
# Checking accuracy on validation set
# Got 327 / 1000 correct (32.70)
#
# Epoch 2, Iteration 600, loss = 1.6476
# Checking accuracy on validation set
# Got 409 / 1000 correct (40.90)
#
# Epoch 2, Iteration 700, loss = 1.6294
# Checking accuracy on validation set
# Got 350 / 1000 correct (35.00)
#
# Epoch 3, Iteration 0, loss = 1.6570
# Checking accuracy on validation set
# Got 426 / 1000 correct (42.60)
#
# Epoch 3, Iteration 100, loss = 1.6374
# Checking accuracy on validation set
# Got 420 / 1000 correct (42.00)
#
# Epoch 3, Iteration 200, loss = 1.5492
# Checking accuracy on validation set
# Got 383 / 1000 correct (38.30)
#
# Epoch 3, Iteration 300, loss = 1.2712
# Checking accuracy on validation set
# Got 417 / 1000 correct (41.70)
#
# Epoch 3, Iteration 400, loss = 1.4846
# Checking accuracy on validation set
# Got 454 / 1000 correct (45.40)
#
# Epoch 3, Iteration 500, loss = 1.3799
# Checking accuracy on validation set
# Got 449 / 1000 correct (44.90)
#
# Epoch 3, Iteration 600, loss = 1.3374
# Checking accuracy on validation set
# Got 448 / 1000 correct (44.80)
#
# Epoch 3, Iteration 700, loss = 1.5224
# Checking accuracy on validation set
# Got 481 / 1000 correct (48.10)
#
# Epoch 4, Iteration 0, loss = 1.2420
# Checking accuracy on validation set
# Got 481 / 1000 correct (48.10)
#
# Epoch 4, Iteration 100, loss = 1.3572
# Checking accuracy on validation set
# Got 489 / 1000 correct (48.90)
#
# Epoch 4, Iteration 200, loss = 1.2411
# Checking accuracy on validation set
# Got 520 / 1000 correct (52.00)
#
# Epoch 4, Iteration 300, loss = 1.1731
# Checking accuracy on validation set
# Got 484 / 1000 correct (48.40)
#
# Epoch 4, Iteration 400, loss = 1.5042
# Checking accuracy on validation set
# Got 491 / 1000 correct (49.10)
#
# Epoch 4, Iteration 500, loss = 1.4310
# Checking accuracy on validation set
# Got 549 / 1000 correct (54.90)
#
# Epoch 4, Iteration 600, loss = 1.1993
# Checking accuracy on validation set
# Got 520 / 1000 correct (52.00)
#
# Epoch 4, Iteration 700, loss = 1.1602
# Checking accuracy on validation set
# Got 530 / 1000 correct (53.00)
#
# Epoch 5, Iteration 0, loss = 1.4624
# Checking accuracy on validation set
# Got 577 / 1000 correct (57.70)
#
# Epoch 5, Iteration 100, loss = 1.0504
# Checking accuracy on validation set
# Got 557 / 1000 correct (55.70)
#
# Epoch 5, Iteration 200, loss = 1.3715
# Checking accuracy on validation set
# Got 588 / 1000 correct (58.80)
#
# Epoch 5, Iteration 300, loss = 1.3865
# Checking accuracy on validation set
# Got 582 / 1000 correct (58.20)
#
# Epoch 5, Iteration 400, loss = 0.9955
# Checking accuracy on validation set
# Got 605 / 1000 correct (60.50)
#
# Epoch 5, Iteration 500, loss = 1.1784
# Checking accuracy on validation set
# Got 569 / 1000 correct (56.90)
#
# Epoch 5, Iteration 600, loss = 1.2701
# Checking accuracy on validation set
# Got 601 / 1000 correct (60.10)
#
# Epoch 5, Iteration 700, loss = 1.3428
# Checking accuracy on validation set
# Got 562 / 1000 correct (56.20)
#
# Epoch 6, Iteration 0, loss = 1.0386
# Checking accuracy on validation set
# Got 615 / 1000 correct (61.50)
#
# Epoch 6, Iteration 100, loss = 1.1214
# Checking accuracy on validation set
# Got 557 / 1000 correct (55.70)
#
# Epoch 6, Iteration 200, loss = 1.1550
# Checking accuracy on validation set
# Got 623 / 1000 correct (62.30)
#
# Epoch 6, Iteration 300, loss = 1.3027
# Checking accuracy on validation set
# Got 644 / 1000 correct (64.40)
#
# Epoch 6, Iteration 400, loss = 0.9534
# Checking accuracy on validation set
# Got 619 / 1000 correct (61.90)
#
# Epoch 6, Iteration 500, loss = 1.2747
# Checking accuracy on validation set
# Got 635 / 1000 correct (63.50)
#
# Epoch 6, Iteration 600, loss = 0.6885
# Checking accuracy on validation set
# Got 642 / 1000 correct (64.20)
#
# Epoch 6, Iteration 700, loss = 1.0306
# Checking accuracy on validation set
# Got 595 / 1000 correct (59.50)
#
# Epoch 7, Iteration 0, loss = 1.0080
# Checking accuracy on validation set
# Got 611 / 1000 correct (61.10)
#
# Epoch 7, Iteration 100, loss = 1.0355
# Checking accuracy on validation set
# Got 603 / 1000 correct (60.30)
#
# Epoch 7, Iteration 200, loss = 0.7674
# Checking accuracy on validation set
# Got 628 / 1000 correct (62.80)
#
# Epoch 7, Iteration 300, loss = 0.7509
# Checking accuracy on validation set
# Got 646 / 1000 correct (64.60)
#
# Epoch 7, Iteration 400, loss = 0.7409
# Checking accuracy on validation set
# Got 655 / 1000 correct (65.50)
#
# Epoch 7, Iteration 500, loss = 0.9263
# Checking accuracy on validation set
# Got 639 / 1000 correct (63.90)
#
# Epoch 7, Iteration 600, loss = 1.2114
# Checking accuracy on validation set
# Got 660 / 1000 correct (66.00)
#
# Epoch 7, Iteration 700, loss = 1.3879
# Checking accuracy on validation set
# Got 657 / 1000 correct (65.70)
#
# Epoch 8, Iteration 0, loss = 0.8765
# Checking accuracy on validation set
# Got 607 / 1000 correct (60.70)
#
# Epoch 8, Iteration 100, loss = 0.9745
# Checking accuracy on validation set
# Got 667 / 1000 correct (66.70)
#
# Epoch 8, Iteration 200, loss = 0.9503
# Checking accuracy on validation set
# Got 644 / 1000 correct (64.40)
#
# Epoch 8, Iteration 300, loss = 0.9469
# Checking accuracy on validation set
# Got 698 / 1000 correct (69.80)
#
# Epoch 8, Iteration 400, loss = 0.7934
# Checking accuracy on validation set
# Got 679 / 1000 correct (67.90)
#
# Epoch 8, Iteration 500, loss = 0.7940
# Checking accuracy on validation set
# Got 685 / 1000 correct (68.50)
#
# Epoch 8, Iteration 600, loss = 0.8263
# Checking accuracy on validation set
# Got 685 / 1000 correct (68.50)
#
# Epoch 8, Iteration 700, loss = 0.7433
# Checking accuracy on validation set
# Got 695 / 1000 correct (69.50)
#
# Epoch 9, Iteration 0, loss = 0.6567
# Checking accuracy on validation set
# Got 694 / 1000 correct (69.40)
#
# Epoch 9, Iteration 100, loss = 0.6569
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Epoch 9, Iteration 200, loss = 1.0679
# Checking accuracy on validation set
# Got 659 / 1000 correct (65.90)
#
# Epoch 9, Iteration 300, loss = 0.6474
# Checking accuracy on validation set
# Got 690 / 1000 correct (69.00)
#
# Epoch 9, Iteration 400, loss = 0.9326
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Epoch 9, Iteration 500, loss = 1.0664
# Checking accuracy on validation set
# Got 703 / 1000 correct (70.30)
#
# Epoch 9, Iteration 600, loss = 0.7022
# Checking accuracy on validation set
# Got 699 / 1000 correct (69.90)
#
# Epoch 9, Iteration 700, loss = 0.6369
# Checking accuracy on validation set
# Got 688 / 1000 correct (68.80)
#
# Epoch 10, Iteration 0, loss = 0.8789
# Checking accuracy on validation set
# Got 713 / 1000 correct (71.30)
#
# Epoch 10, Iteration 100, loss = 0.7371
# Checking accuracy on validation set
# Got 706 / 1000 correct (70.60)
#
# Epoch 10, Iteration 200, loss = 0.7211
# Checking accuracy on validation set
# Got 712 / 1000 correct (71.20)
#
# Epoch 10, Iteration 300, loss = 0.7147
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
#
# Epoch 10, Iteration 400, loss = 0.7754
# Checking accuracy on validation set
# Got 738 / 1000 correct (73.80)
#
# Epoch 10, Iteration 500, loss = 0.6670
# Checking accuracy on validation set
# Got 694 / 1000 correct (69.40)
#
# Epoch 10, Iteration 600, loss = 1.0011
# Checking accuracy on validation set
# Got 714 / 1000 correct (71.40)
#
# Epoch 10, Iteration 700, loss = 0.7535
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Epoch 11, Iteration 0, loss = 0.7047
# Checking accuracy on validation set
# Got 692 / 1000 correct (69.20)
#
# Epoch 11, Iteration 100, loss = 0.6120
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
#
# Epoch 11, Iteration 200, loss = 0.6387
# Checking accuracy on validation set
# Got 741 / 1000 correct (74.10)
#
# Epoch 11, Iteration 300, loss = 0.8028
# Checking accuracy on validation set
# Got 749 / 1000 correct (74.90)
#
# Epoch 11, Iteration 400, loss = 0.7844
# Checking accuracy on validation set
# Got 721 / 1000 correct (72.10)
#
# Epoch 11, Iteration 500, loss = 0.5385
# Checking accuracy on validation set
# Got 762 / 1000 correct (76.20)
#
# Epoch 11, Iteration 600, loss = 0.6491
# Checking accuracy on validation set
# Got 755 / 1000 correct (75.50)
#
# Epoch 11, Iteration 700, loss = 1.0463
# Checking accuracy on validation set
# Got 721 / 1000 correct (72.10)
#
# Epoch 12, Iteration 0, loss = 0.8428
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
#
# Epoch 12, Iteration 100, loss = 0.6972
# Checking accuracy on validation set
# Got 731 / 1000 correct (73.10)
#
# Epoch 12, Iteration 200, loss = 0.7251
# Checking accuracy on validation set
# Got 764 / 1000 correct (76.40)
#
# Epoch 12, Iteration 300, loss = 0.4375
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
#
# Epoch 12, Iteration 400, loss = 0.7799
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
#
# Epoch 12, Iteration 500, loss = 0.6702
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
#
# Epoch 12, Iteration 600, loss = 0.5414
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
#
# Epoch 12, Iteration 700, loss = 0.8811
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
#
# Epoch 13, Iteration 0, loss = 0.6191
# Checking accuracy on validation set
# Got 762 / 1000 correct (76.20)
#
# Epoch 13, Iteration 100, loss = 0.7325
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
#
# Epoch 13, Iteration 200, loss = 0.5345
# Checking accuracy on validation set
# Got 756 / 1000 correct (75.60)
#
# Epoch 13, Iteration 300, loss = 0.3928
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 13, Iteration 400, loss = 0.5926
# Checking accuracy on validation set
# Got 774 / 1000 correct (77.40)
#
# Epoch 13, Iteration 500, loss = 0.6485
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Epoch 13, Iteration 600, loss = 0.6478
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
#
# Epoch 13, Iteration 700, loss = 0.5675
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
#
# Epoch 14, Iteration 0, loss = 0.5417
# Checking accuracy on validation set
# Got 734 / 1000 correct (73.40)
#
# Epoch 14, Iteration 100, loss = 0.4301
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Epoch 14, Iteration 200, loss = 0.6246
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 14, Iteration 300, loss = 0.6790
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
#
# Epoch 14, Iteration 400, loss = 0.5272
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
#
# Epoch 14, Iteration 500, loss = 0.6665
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
#
# Epoch 14, Iteration 600, loss = 0.6333
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
#
# Epoch 14, Iteration 700, loss = 0.7884
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
#
# Epoch 15, Iteration 0, loss = 0.6087
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
#
# Epoch 15, Iteration 100, loss = 0.6554
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
#
# Epoch 15, Iteration 200, loss = 0.7856
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
#
# Epoch 15, Iteration 300, loss = 0.6606
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
#
# Epoch 15, Iteration 400, loss = 0.4306
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
#
# Epoch 15, Iteration 500, loss = 0.6105
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 15, Iteration 600, loss = 0.4095
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
#
# Epoch 15, Iteration 700, loss = 0.5510
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 16, Iteration 0, loss = 0.6783
# Checking accuracy on validation set
# Got 774 / 1000 correct (77.40)
#
# Epoch 16, Iteration 100, loss = 0.5215
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
#
# Epoch 16, Iteration 200, loss = 0.5612
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Epoch 16, Iteration 300, loss = 0.4349
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
#
# Epoch 16, Iteration 400, loss = 0.5115
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 16, Iteration 500, loss = 0.4939
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 16, Iteration 600, loss = 0.7496
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
#
# Epoch 16, Iteration 700, loss = 0.4348
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Epoch 17, Iteration 0, loss = 0.5330
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 17, Iteration 100, loss = 0.3967
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 17, Iteration 200, loss = 0.4275
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 17, Iteration 300, loss = 0.4930
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 17, Iteration 400, loss = 0.4436
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 17, Iteration 500, loss = 0.6939
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 17, Iteration 600, loss = 0.4192
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
#
# Epoch 17, Iteration 700, loss = 0.3172
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 18, Iteration 0, loss = 0.5127
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
#
# Epoch 18, Iteration 100, loss = 0.6616
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 18, Iteration 200, loss = 0.5690
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 18, Iteration 300, loss = 0.3259
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
#
# Epoch 18, Iteration 400, loss = 0.5500
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 18, Iteration 500, loss = 0.3376
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Epoch 18, Iteration 600, loss = 0.4548
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 18, Iteration 700, loss = 0.5807
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 19, Iteration 0, loss = 0.3329
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
#
# Epoch 19, Iteration 100, loss = 0.3739
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 19, Iteration 200, loss = 0.3811
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 19, Iteration 300, loss = 0.3119
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 19, Iteration 400, loss = 0.4433
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 19, Iteration 500, loss = 0.3474
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 19, Iteration 600, loss = 0.4254
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 19, Iteration 700, loss = 0.3933
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 20, Iteration 0, loss = 0.4894
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 20, Iteration 100, loss = 0.3702
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 20, Iteration 200, loss = 0.4048
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 20, Iteration 300, loss = 0.3838
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
#
# Epoch 20, Iteration 400, loss = 0.4805
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 20, Iteration 500, loss = 0.5780
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 20, Iteration 600, loss = 0.2514
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 20, Iteration 700, loss = 0.5100
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 21, Iteration 0, loss = 0.5445
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 21, Iteration 100, loss = 0.4358
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 21, Iteration 200, loss = 0.3034
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 21, Iteration 300, loss = 0.4235
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 21, Iteration 400, loss = 0.3828
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 21, Iteration 500, loss = 0.3024
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 21, Iteration 600, loss = 0.5070
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 21, Iteration 700, loss = 0.5678
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Epoch 22, Iteration 0, loss = 0.3165
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 22, Iteration 100, loss = 0.3500
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 22, Iteration 200, loss = 0.3507
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
#
# Epoch 22, Iteration 300, loss = 0.3318
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 22, Iteration 400, loss = 0.1997
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 22, Iteration 500, loss = 0.5666
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 22, Iteration 600, loss = 0.1978
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 22, Iteration 700, loss = 0.4481
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 23, Iteration 0, loss = 0.2998
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 23, Iteration 100, loss = 0.3100
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 23, Iteration 200, loss = 0.4097
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 23, Iteration 300, loss = 0.2416
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 23, Iteration 400, loss = 0.4348
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 23, Iteration 500, loss = 0.3375
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 23, Iteration 600, loss = 0.2445
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 23, Iteration 700, loss = 0.3670
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 24, Iteration 0, loss = 0.3045
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Epoch 24, Iteration 100, loss = 0.2614
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 24, Iteration 200, loss = 0.4269
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 24, Iteration 300, loss = 0.3211
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 24, Iteration 400, loss = 0.3913
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 24, Iteration 500, loss = 0.3313
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 24, Iteration 600, loss = 0.3809
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 24, Iteration 700, loss = 0.2081
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
#
# Epoch 25, Iteration 0, loss = 0.2247
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 25, Iteration 100, loss = 0.3693
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 25, Iteration 200, loss = 0.4626
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 25, Iteration 300, loss = 0.2686
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 25, Iteration 400, loss = 0.1505
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 25, Iteration 500, loss = 0.3331
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 25, Iteration 600, loss = 0.2015
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 25, Iteration 700, loss = 0.4519
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 26, Iteration 0, loss = 0.3054
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 26, Iteration 100, loss = 0.2012
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 26, Iteration 200, loss = 0.4160
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 26, Iteration 300, loss = 0.4962
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 26, Iteration 400, loss = 0.2004
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 26, Iteration 500, loss = 0.3678
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 26, Iteration 600, loss = 0.3307
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 26, Iteration 700, loss = 0.2984
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 27, Iteration 0, loss = 0.1634
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 27, Iteration 100, loss = 0.2552
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 27, Iteration 200, loss = 0.0801
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 27, Iteration 300, loss = 0.2926
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 27, Iteration 400, loss = 0.1768
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 27, Iteration 500, loss = 0.2154
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 27, Iteration 600, loss = 0.3503
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 27, Iteration 700, loss = 0.2211
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 28, Iteration 0, loss = 0.3712
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 28, Iteration 100, loss = 0.1412
# Checking accuracy on validation set
# Got 853 / 1000 correct (85.30)
#
# Epoch 28, Iteration 200, loss = 0.2643
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 28, Iteration 300, loss = 0.1850
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 28, Iteration 400, loss = 0.1754
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 28, Iteration 500, loss = 0.2970
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 28, Iteration 600, loss = 0.3171
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 28, Iteration 700, loss = 0.1819
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 29, Iteration 0, loss = 0.2533
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 29, Iteration 100, loss = 0.2168
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 29, Iteration 200, loss = 0.1656
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 29, Iteration 300, loss = 0.2964
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 29, Iteration 400, loss = 0.5646
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 29, Iteration 500, loss = 0.1678
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 29, Iteration 600, loss = 0.3405
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 29, Iteration 700, loss = 0.4163
# Checking accuracy on validation set
# Got 859 / 1000 correct (85.90)
#
# Epoch 30, Iteration 0, loss = 0.2800
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 30, Iteration 100, loss = 0.2952
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Epoch 30, Iteration 200, loss = 0.2015
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 30, Iteration 300, loss = 0.4154
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 30, Iteration 400, loss = 0.4391
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 30, Iteration 500, loss = 0.1348
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 30, Iteration 600, loss = 0.3146
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 30, Iteration 700, loss = 0.1726
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 31, Iteration 0, loss = 0.2533
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 31, Iteration 100, loss = 0.1873
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 31, Iteration 200, loss = 0.3237
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 31, Iteration 300, loss = 0.2538
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 31, Iteration 400, loss = 0.2453
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 31, Iteration 500, loss = 0.2450
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Epoch 31, Iteration 600, loss = 0.2585
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 31, Iteration 700, loss = 0.2056
# Checking accuracy on validation set
# Got 863 / 1000 correct (86.30)
#
# Epoch 32, Iteration 0, loss = 0.4903
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 32, Iteration 100, loss = 0.1382
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 32, Iteration 200, loss = 0.2710
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 32, Iteration 300, loss = 0.1912
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 32, Iteration 400, loss = 0.2915
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 32, Iteration 500, loss = 0.2326
# Checking accuracy on validation set
# Got 855 / 1000 correct (85.50)
#
# Epoch 32, Iteration 600, loss = 0.1923
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 32, Iteration 700, loss = 0.1839
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 33, Iteration 0, loss = 0.2237
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 33, Iteration 100, loss = 0.1935
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 33, Iteration 200, loss = 0.1072
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 33, Iteration 300, loss = 0.2042
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 33, Iteration 400, loss = 0.2730
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 33, Iteration 500, loss = 0.3887
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 33, Iteration 600, loss = 0.2557
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 33, Iteration 700, loss = 0.1050
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 34, Iteration 0, loss = 0.1778
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 34, Iteration 100, loss = 0.1906
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 34, Iteration 200, loss = 0.2003
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 34, Iteration 300, loss = 0.3118
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 34, Iteration 400, loss = 0.1964
# Checking accuracy on validation set
# Got 860 / 1000 correct (86.00)
#
# Epoch 34, Iteration 500, loss = 0.4278
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 34, Iteration 600, loss = 0.0995
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 34, Iteration 700, loss = 0.3093
# Checking accuracy on validation set
# Got 856 / 1000 correct (85.60)
#
# Epoch 35, Iteration 0, loss = 0.1543
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 35, Iteration 100, loss = 0.1259
# Checking accuracy on validation set
# Got 860 / 1000 correct (86.00)
#
# Epoch 35, Iteration 200, loss = 0.1601
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 35, Iteration 300, loss = 0.3239
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 35, Iteration 400, loss = 0.2337
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 35, Iteration 500, loss = 0.2171
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 35, Iteration 600, loss = 0.1213
# Checking accuracy on validation set
# Got 863 / 1000 correct (86.30)
#
# Epoch 35, Iteration 700, loss = 0.1372
# Checking accuracy on validation set
# Got 863 / 1000 correct (86.30)
#
# Epoch 36, Iteration 0, loss = 0.1742
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 36, Iteration 100, loss = 0.1578
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 36, Iteration 200, loss = 0.1068
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 36, Iteration 300, loss = 0.1444
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 36, Iteration 400, loss = 0.1228
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 36, Iteration 500, loss = 0.1997
# Checking accuracy on validation set
# Got 859 / 1000 correct (85.90)
#
# Epoch 36, Iteration 600, loss = 0.0854
# Checking accuracy on validation set
# Got 856 / 1000 correct (85.60)
#
# Epoch 36, Iteration 700, loss = 0.2755
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 37, Iteration 0, loss = 0.0878
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 37, Iteration 100, loss = 0.1641
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 37, Iteration 200, loss = 0.1491
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 37, Iteration 300, loss = 0.0936
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 37, Iteration 400, loss = 0.1387
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 37, Iteration 500, loss = 0.3944
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 37, Iteration 600, loss = 0.2743
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 37, Iteration 700, loss = 0.2273
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 38, Iteration 0, loss = 0.0563
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 38, Iteration 100, loss = 0.0312
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 38, Iteration 200, loss = 0.2188
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 38, Iteration 300, loss = 0.1225
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 38, Iteration 400, loss = 0.2058
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 38, Iteration 500, loss = 0.2734
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 38, Iteration 600, loss = 0.0976
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 38, Iteration 700, loss = 0.3044
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 39, Iteration 0, loss = 0.1099
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 39, Iteration 100, loss = 0.2502
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 39, Iteration 200, loss = 0.0884
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 39, Iteration 300, loss = 0.1529
# Checking accuracy on validation set
# Got 854 / 1000 correct (85.40)
#
# Epoch 39, Iteration 400, loss = 0.1493
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 39, Iteration 500, loss = 0.1365
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 39, Iteration 600, loss = 0.1170
# Checking accuracy on validation set
# Got 854 / 1000 correct (85.40)
#
# Epoch 39, Iteration 700, loss = 0.0862
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 40, Iteration 0, loss = 0.2475
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 40, Iteration 100, loss = 0.2683
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 40, Iteration 200, loss = 0.1037
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 40, Iteration 300, loss = 0.0901
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 40, Iteration 400, loss = 0.2281
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 40, Iteration 500, loss = 0.2238
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 40, Iteration 600, loss = 0.1929
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 40, Iteration 700, loss = 0.1209
# Checking accuracy on validation set
# Got 862 / 1000 correct (86.20)
#
# Epoch 41, Iteration 0, loss = 0.2693
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 41, Iteration 100, loss = 0.2970
# Checking accuracy on validation set
# Got 853 / 1000 correct (85.30)
#
# Epoch 41, Iteration 200, loss = 0.1660
# Checking accuracy on validation set
# Got 853 / 1000 correct (85.30)
#
# Epoch 41, Iteration 300, loss = 0.2966
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 41, Iteration 400, loss = 0.1625
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 41, Iteration 500, loss = 0.1734
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 41, Iteration 600, loss = 0.1785
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 41, Iteration 700, loss = 0.1566
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 42, Iteration 0, loss = 0.2112
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 42, Iteration 100, loss = 0.1445
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 42, Iteration 200, loss = 0.1235
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 42, Iteration 300, loss = 0.2432
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 42, Iteration 400, loss = 0.0929
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 42, Iteration 500, loss = 0.1112
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 42, Iteration 600, loss = 0.2284
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 42, Iteration 700, loss = 0.2789
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 43, Iteration 0, loss = 0.0814
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 43, Iteration 100, loss = 0.2287
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 43, Iteration 200, loss = 0.0491
# Checking accuracy on validation set
# Got 862 / 1000 correct (86.20)
#
# Epoch 43, Iteration 300, loss = 0.0835
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 43, Iteration 400, loss = 0.1387
# Checking accuracy on validation set
# Got 868 / 1000 correct (86.80)
#
# Epoch 43, Iteration 500, loss = 0.3141
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 43, Iteration 600, loss = 0.2121
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Epoch 43, Iteration 700, loss = 0.2317
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 44, Iteration 0, loss = 0.1951
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 44, Iteration 100, loss = 0.1110
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 44, Iteration 200, loss = 0.0848
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 44, Iteration 300, loss = 0.0788
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 44, Iteration 400, loss = 0.0944
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 44, Iteration 500, loss = 0.2501
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 44, Iteration 600, loss = 0.2623
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 44, Iteration 700, loss = 0.0948
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 45, Iteration 0, loss = 0.1509
# Checking accuracy on validation set
# Got 859 / 1000 correct (85.90)
#
# Epoch 45, Iteration 100, loss = 0.0481
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 45, Iteration 200, loss = 0.2589
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 45, Iteration 300, loss = 0.1723
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 45, Iteration 400, loss = 0.1523
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 45, Iteration 500, loss = 0.2303
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 45, Iteration 600, loss = 0.1283
# Checking accuracy on validation set
# Got 853 / 1000 correct (85.30)
#
# Epoch 45, Iteration 700, loss = 0.1838
# Checking accuracy on validation set
# Got 853 / 1000 correct (85.30)
#
# Epoch 46, Iteration 0, loss = 0.1256
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 46, Iteration 100, loss = 0.1879
# Checking accuracy on validation set
# Got 863 / 1000 correct (86.30)
#
# Epoch 46, Iteration 200, loss = 0.1204
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 46, Iteration 300, loss = 0.0953
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 46, Iteration 400, loss = 0.1937
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 46, Iteration 500, loss = 0.0651
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 46, Iteration 600, loss = 0.2586
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 46, Iteration 700, loss = 0.3433
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 47, Iteration 0, loss = 0.0476
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 47, Iteration 100, loss = 0.0775
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 47, Iteration 200, loss = 0.1278
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 47, Iteration 300, loss = 0.1258
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 47, Iteration 400, loss = 0.0881
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 47, Iteration 500, loss = 0.1141
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 47, Iteration 600, loss = 0.0951
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 47, Iteration 700, loss = 0.1788
# Checking accuracy on validation set
# Got 858 / 1000 correct (85.80)
#
# Epoch 48, Iteration 0, loss = 0.1243
# Checking accuracy on validation set
# Got 867 / 1000 correct (86.70)
#
# Epoch 48, Iteration 100, loss = 0.1306
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 48, Iteration 200, loss = 0.0844
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 48, Iteration 300, loss = 0.2003
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 48, Iteration 400, loss = 0.1341
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 48, Iteration 500, loss = 0.1770
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 48, Iteration 600, loss = 0.0947
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 48, Iteration 700, loss = 0.0501
# Checking accuracy on validation set
# Got 864 / 1000 correct (86.40)
#
# Epoch 49, Iteration 0, loss = 0.0848
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 49, Iteration 100, loss = 0.0888
# Checking accuracy on validation set
# Got 854 / 1000 correct (85.40)
#
# Epoch 49, Iteration 200, loss = 0.1326
# Checking accuracy on validation set
# Got 855 / 1000 correct (85.50)
#
# Epoch 49, Iteration 300, loss = 0.0392
# Checking accuracy on validation set
# Got 859 / 1000 correct (85.90)
#
# Epoch 49, Iteration 400, loss = 0.0893
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 49, Iteration 500, loss = 0.1325
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 49, Iteration 600, loss = 0.0904
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 49, Iteration 700, loss = 0.2210
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 50, Iteration 0, loss = 0.0809
# Checking accuracy on validation set
# Got 868 / 1000 correct (86.80)
#
# Epoch 50, Iteration 100, loss = 0.0795
# Checking accuracy on validation set
# Got 855 / 1000 correct (85.50)
#
# Epoch 50, Iteration 200, loss = 0.2145
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 50, Iteration 300, loss = 0.1627
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 50, Iteration 400, loss = 0.1787
# Checking accuracy on validation set
# Got 859 / 1000 correct (85.90)
#
# Epoch 50, Iteration 500, loss = 0.1025
# Checking accuracy on validation set
# Got 865 / 1000 correct (86.50)
#
# Epoch 50, Iteration 600, loss = 0.1388
# Checking accuracy on validation set
# Got 853 / 1000 correct (85.30)
#
# Epoch 50, Iteration 700, loss = 0.0860
# Checking accuracy on validation set
# Got 855 / 1000 correct (85.50)
#
# Epoch 51, Iteration 0, loss = 0.0360
# Checking accuracy on validation set
# Got 856 / 1000 correct (85.60)
#
# Epoch 51, Iteration 100, loss = 0.1893
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 51, Iteration 200, loss = 0.1601
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 51, Iteration 300, loss = 0.1109
# Checking accuracy on validation set
# Got 856 / 1000 correct (85.60)
#
# Epoch 51, Iteration 400, loss = 0.1157
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Epoch 51, Iteration 500, loss = 0.1157
# Checking accuracy on validation set
# Got 858 / 1000 correct (85.80)
#
# Epoch 51, Iteration 600, loss = 0.0718
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 51, Iteration 700, loss = 0.2554
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 52, Iteration 0, loss = 0.1423
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 52, Iteration 100, loss = 0.0754
# Checking accuracy on validation set
# Got 856 / 1000 correct (85.60)
#
# Epoch 52, Iteration 200, loss = 0.1371
# Checking accuracy on validation set
# Got 859 / 1000 correct (85.90)
#
# Epoch 52, Iteration 300, loss = 0.0943
# Checking accuracy on validation set
# Got 863 / 1000 correct (86.30)
#
# Epoch 52, Iteration 400, loss = 0.1685
# Checking accuracy on validation set
# Got 853 / 1000 correct (85.30)
#
# Epoch 52, Iteration 500, loss = 0.2102
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 52, Iteration 600, loss = 0.0813
# Checking accuracy on validation set
# Got 853 / 1000 correct (85.30)
#
# Epoch 52, Iteration 700, loss = 0.1095
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 53, Iteration 0, loss = 0.1237
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 53, Iteration 100, loss = 0.2438
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 53, Iteration 200, loss = 0.0955
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 53, Iteration 300, loss = 0.1211
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 53, Iteration 400, loss = 0.0984
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 53, Iteration 500, loss = 0.0474
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 53, Iteration 600, loss = 0.1841
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 53, Iteration 700, loss = 0.1184
# Checking accuracy on validation set
# Got 856 / 1000 correct (85.60)
#
# Epoch 54, Iteration 0, loss = 0.1120
# Checking accuracy on validation set
# Got 858 / 1000 correct (85.80)
#
# Epoch 54, Iteration 100, loss = 0.1413
# Checking accuracy on validation set
# Got 857 / 1000 correct (85.70)
#
# Epoch 54, Iteration 200, loss = 0.0853
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 54, Iteration 300, loss = 0.0656
# Checking accuracy on validation set
# Got 856 / 1000 correct (85.60)
#
# Epoch 54, Iteration 400, loss = 0.0477
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 54, Iteration 500, loss = 0.0936
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 54, Iteration 600, loss = 0.2498
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Epoch 54, Iteration 700, loss = 0.0447
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 55, Iteration 0, loss = 0.0654
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 55, Iteration 100, loss = 0.1083
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Epoch 55, Iteration 200, loss = 0.1161
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 55, Iteration 300, loss = 0.1237
# Checking accuracy on validation set
# Got 860 / 1000 correct (86.00)
#
# Epoch 55, Iteration 400, loss = 0.2492
# Checking accuracy on validation set
# Got 860 / 1000 correct (86.00)
#
# Epoch 55, Iteration 500, loss = 0.1272
# Checking accuracy on validation set
# Got 857 / 1000 correct (85.70)
#
# Epoch 55, Iteration 600, loss = 0.1161
# Checking accuracy on validation set
# Got 868 / 1000 correct (86.80)
#
# Epoch 55, Iteration 700, loss = 0.1776
# Checking accuracy on validation set
# Got 863 / 1000 correct (86.30)
#
# Epoch 56, Iteration 0, loss = 0.2621
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 56, Iteration 100, loss = 0.0325
# Checking accuracy on validation set
# Got 855 / 1000 correct (85.50)
#
# ...
# Got 880 / 1000 correct (88.00)
#
# Epoch 331, Iteration 400, loss = 0.0059
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 331, Iteration 500, loss = 0.0031
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 331, Iteration 600, loss = 0.0061
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 331, Iteration 700, loss = 0.0088
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 332, Iteration 0, loss = 0.0027
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 332, Iteration 100, loss = 0.0054
# Checking accuracy on validation set
# Got 880 / 1000 correct (88.00)
#
# Epoch 332, Iteration 200, loss = 0.0084
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 332, Iteration 300, loss = 0.0044
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 332, Iteration 400, loss = 0.0035
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 332, Iteration 500, loss = 0.0060
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 332, Iteration 600, loss = 0.0040
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 332, Iteration 700, loss = 0.0136
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 333, Iteration 0, loss = 0.0039
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 333, Iteration 100, loss = 0.0052
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 333, Iteration 200, loss = 0.0056
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 333, Iteration 300, loss = 0.0059
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 333, Iteration 400, loss = 0.0050
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 333, Iteration 500, loss = 0.0048
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 333, Iteration 600, loss = 0.0054
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 333, Iteration 700, loss = 0.0083
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 334, Iteration 0, loss = 0.0088
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 334, Iteration 100, loss = 0.0067
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 334, Iteration 200, loss = 0.0051
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 334, Iteration 300, loss = 0.0058
# Checking accuracy on validation set
# Got 880 / 1000 correct (88.00)
#
# Epoch 334, Iteration 400, loss = 0.0048
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 334, Iteration 500, loss = 0.0075
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 334, Iteration 600, loss = 0.0050
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 334, Iteration 700, loss = 0.0068
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 335, Iteration 0, loss = 0.0043
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 335, Iteration 100, loss = 0.0060
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 335, Iteration 200, loss = 0.0052
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
# Epoch 335, Iteration 300, loss = 0.0056
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 335, Iteration 400, loss = 0.0084
# Checking accuracy on validation set
# Got 880 / 1000 correct (88.00)
#
# Epoch 335, Iteration 500, loss = 0.0049
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 335, Iteration 600, loss = 0.0047
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 335, Iteration 700, loss = 0.0062
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 336, Iteration 0, loss = 0.0070
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 336, Iteration 100, loss = 0.0088
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 336, Iteration 200, loss = 0.0082
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 336, Iteration 300, loss = 0.0046
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 336, Iteration 400, loss = 0.0056
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 336, Iteration 500, loss = 0.0088
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 336, Iteration 600, loss = 0.0085
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 336, Iteration 700, loss = 0.0104
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 337, Iteration 0, loss = 0.0039
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 337, Iteration 100, loss = 0.0041
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 337, Iteration 200, loss = 0.0053
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 337, Iteration 300, loss = 0.0057
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 337, Iteration 400, loss = 0.0061
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 337, Iteration 500, loss = 0.0049
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 337, Iteration 600, loss = 0.0061
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 337, Iteration 700, loss = 0.0054
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 338, Iteration 0, loss = 0.0041
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 338, Iteration 100, loss = 0.0050
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 338, Iteration 200, loss = 0.0045
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 338, Iteration 300, loss = 0.0049
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 338, Iteration 400, loss = 0.0058
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 338, Iteration 500, loss = 0.0030
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 338, Iteration 600, loss = 0.0052
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 338, Iteration 700, loss = 0.0048
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 339, Iteration 0, loss = 0.0050
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 339, Iteration 100, loss = 0.0060
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 339, Iteration 200, loss = 0.0097
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 339, Iteration 300, loss = 0.0091
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 339, Iteration 400, loss = 0.0116
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 339, Iteration 500, loss = 0.0059
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 339, Iteration 600, loss = 0.0038
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 339, Iteration 700, loss = 0.0063
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 340, Iteration 0, loss = 0.0038
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 340, Iteration 100, loss = 0.0045
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 340, Iteration 200, loss = 0.0029
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 340, Iteration 300, loss = 0.0048
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 340, Iteration 400, loss = 0.0077
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 340, Iteration 500, loss = 0.0036
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 340, Iteration 600, loss = 0.0036
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 340, Iteration 700, loss = 0.0041
# Checking accuracy on validation set
# Got 880 / 1000 correct (88.00)
#
# Epoch 341, Iteration 0, loss = 0.0050
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 341, Iteration 100, loss = 0.0046
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 341, Iteration 200, loss = 0.0050
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 341, Iteration 300, loss = 0.0088
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 341, Iteration 400, loss = 0.0078
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 341, Iteration 500, loss = 0.0063
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 341, Iteration 600, loss = 0.0052
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 341, Iteration 700, loss = 0.0030
# Checking accuracy on validation set
# Got 880 / 1000 correct (88.00)
#
# Epoch 342, Iteration 0, loss = 0.0062
# Checking accuracy on validation set
# Got 879 / 1000 correct (87.90)
#
# Epoch 342, Iteration 100, loss = 0.0052
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 342, Iteration 200, loss = 0.0051
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 342, Iteration 300, loss = 0.0069
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 342, Iteration 400, loss = 0.0051
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 342, Iteration 500, loss = 0.0053
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 342, Iteration 600, loss = 0.0072
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 342, Iteration 700, loss = 0.0056
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 343, Iteration 0, loss = 0.0083
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 343, Iteration 100, loss = 0.0036
# Checking accuracy on validation set
# Got 880 / 1000 correct (88.00)
#
# Epoch 343, Iteration 200, loss = 0.0053
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 343, Iteration 300, loss = 0.0053
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 343, Iteration 400, loss = 0.0052
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 343, Iteration 500, loss = 0.0100
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 343, Iteration 600, loss = 0.0050
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 343, Iteration 700, loss = 0.0050
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 344, Iteration 0, loss = 0.0056
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 344, Iteration 100, loss = 0.0051
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 344, Iteration 200, loss = 0.0054
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 344, Iteration 300, loss = 0.0044
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 344, Iteration 400, loss = 0.0034
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 344, Iteration 500, loss = 0.0076
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 344, Iteration 600, loss = 0.0067
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 344, Iteration 700, loss = 0.0031
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 345, Iteration 0, loss = 0.0058
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 345, Iteration 100, loss = 0.0057
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 345, Iteration 200, loss = 0.0049
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 345, Iteration 300, loss = 0.0066
# Checking accuracy on validation set
# Got 880 / 1000 correct (88.00)
#
# Epoch 345, Iteration 400, loss = 0.0093
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 345, Iteration 500, loss = 0.0076
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 345, Iteration 600, loss = 0.0062
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 345, Iteration 700, loss = 0.0063
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 346, Iteration 0, loss = 0.0058
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 346, Iteration 100, loss = 0.0093
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 346, Iteration 200, loss = 0.0073
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 346, Iteration 300, loss = 0.0082
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 346, Iteration 400, loss = 0.0093
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 346, Iteration 500, loss = 0.0085
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 346, Iteration 600, loss = 0.0076
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 346, Iteration 700, loss = 0.0060
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 347, Iteration 0, loss = 0.0084
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 347, Iteration 100, loss = 0.0061
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 347, Iteration 200, loss = 0.0037
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 347, Iteration 300, loss = 0.0124
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 347, Iteration 400, loss = 0.0068
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 347, Iteration 500, loss = 0.0049
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 347, Iteration 600, loss = 0.0077
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 347, Iteration 700, loss = 0.0049
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 348, Iteration 0, loss = 0.0061
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 348, Iteration 100, loss = 0.0065
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 348, Iteration 200, loss = 0.0038
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 348, Iteration 300, loss = 0.0062
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 348, Iteration 400, loss = 0.0084
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 348, Iteration 500, loss = 0.0071
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 348, Iteration 600, loss = 0.0064
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 348, Iteration 700, loss = 0.0052
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 349, Iteration 0, loss = 0.0066
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 349, Iteration 100, loss = 0.0027
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 349, Iteration 200, loss = 0.0084
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 349, Iteration 300, loss = 0.0030
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 349, Iteration 400, loss = 0.0044
# Checking accuracy on validation set
# Got 881 / 1000 correct (88.10)
#
# Epoch 349, Iteration 500, loss = 0.0068
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 349, Iteration 600, loss = 0.0087
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
#
# Epoch 349, Iteration 700, loss = 0.0056
# Checking accuracy on validation set
# Got 882 / 1000 correct (88.20)
# Best accuracy: 0.891

# %%
PATH = "../best_model/"
model_name = "best_model_convpool_cnn_c.pt"
if not os.path.exists(PATH):
    os.mkdir(PATH)
torch.save(best_model.state_dict(), PATH + model_name)
