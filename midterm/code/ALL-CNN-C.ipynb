# %%
import torch
from torch.utils.data import sampler
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import os
import copy
import matplotlib.pyplot as plt

# %%
NUM_TRAIN = 49000

transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
            ])
cifar10_train = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=True,
                                           download=True, transform=transform)
loader_train = torch.utils.data.DataLoader(cifar10_train, batch_size=64,
                                      sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))
cifar10_val = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=False,
                                         download=True, transform=transform)
loader_val = torch.utils.data.DataLoader(cifar10_train, batch_size=64,
                                    sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))
cifar10_test = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=False,
                                         download=True, transform=transform)
loader_test = torch.utils.data.DataLoader(cifar10_train, batch_size=64)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_images, train_labels = iter(loader_train).next()
print("train_X:", train_images.size(), "train_y:", train_labels.size())
val_images, val_labels = iter(loader_val).next()
print("val_X:", val_images.size(), "val_y:", val_labels.size())
test_images, test_labels = iter(loader_test).next()
print("test_X:", test_images.size(), "test_y:", test_labels.size())
# Out:
# train_X: torch.Size([64, 3, 32, 32]) train_y: torch.Size([64])
# val_X: torch.Size([64, 3, 32, 32]) val_y: torch.Size([64])
# test_X: torch.Size([64, 3, 32, 32]) test_y: torch.Size([64])

# %%
USE_GPU = True

dtype = torch.float32

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
print('using device', device)
# Out:
# using device cuda

# %%
class Model(nn.Module):
    def __init__(self, in_channel, channel_1, channel_2, 
                 channel_3, channel_4, num_classes):
        """
        Default initialization:
        model = Model(in_channel=3, channel_1=96, channel_2=192, 
                 channel_3=192, channel_4=192, num_classes=10)
        """
        super().__init__()
        self.conv1_1 = nn.Conv2d(in_channel, channel_1, 3, padding=1)           #(3, 96, 3)
        self.conv1_2 = nn.Conv2d(channel_1, channel_1, 3, padding=1)            #(96, 96, 3)
        self.conv1_3 = nn.Conv2d(channel_1, channel_1, 3, padding=1, stride=2)  #(96, 96, 3)
        self.conv2_1 = nn.Conv2d(channel_1, channel_2, 3, padding=1)            #(96, 192, 3)
        self.conv2_2 = nn.Conv2d(channel_2, channel_2, 3, padding=1)            #(192, 192, 3)
        self.conv2_3 = nn.Conv2d(channel_2, channel_2, 3, padding=1, stride=2)  #(192, 192, 3)
        self.conv3 = nn.Conv2d(channel_2, channel_3, 3)                         #(192, 192, 3)
        self.conv4 = nn.Conv2d(channel_3, channel_4, 1)                         #(192, 192, 1)
        self.conv5 = nn.Conv2d(channel_4, num_classes, 1)                       #(192, 10, 1)
        
    def forward(self, x):
        """
        x.shape: (64, 3, 32, 32)
        """
        N = x.shape[0]
        x_drop = F.dropout(x, .2)
        conv1_1_out = F.relu(self.conv1_1(x_drop))            # (64, 96, 32, 32)
        conv1_2_out = F.relu(self.conv1_2(conv1_1_out))  # (64, 96, 32, 32)
        layer1_out = F.relu(self.conv1_3(conv1_2_out))  # (64, 96, 32, 32)
        layer1_out_drop = F.dropout(layer1_out, .5)
        conv2_1_out = F.relu(self.conv2_1(layer1_out_drop))   # (64, 192, 16, 16)
        conv2_2_out = F.relu(self.conv2_2(conv2_1_out))   # (64, 192, 16, 16)        
        layer2_out = F.relu(self.conv2_3(conv2_2_out))   # (64, 192, 16, 16)
        layer2_out_drop = F.dropout(layer2_out, .5)  
        layer3_out = F.relu(self.conv3(layer2_out_drop))             # (64, 192, 6, 6)
        layer4_out = F.relu(self.conv4(layer3_out))             # (64, 192, 6, 6)
        layer5_out = F.relu(self.conv5(layer4_out))             # (64, 10, 6, 6)
#         print(x.size(), conv1_1_out.size(), conv1_2_out.size(), layer1_out.size(), layer4_out.size(), layer5_out.size())
        out = layer5_out.view(N, 10, -1).mean(dim=2)
        return out
        
def test_Model():
    x = torch.zeros((64, 3, 32, 32), dtype=dtype)
    model = Model(in_channel=3, channel_1=96, channel_2=192, 
                 channel_3=192, channel_4=192, num_classes=10)
    scores = model(x)
    print(scores.size())
test_Model()
# Out:
# torch.Size([64, 10])

# %%
def check_accuracy(loader, model):
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set') 
    num_correct = 0
    num_samples = 0
    model.eval()
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            scores = model(x)
            _, preds = scores.max(1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def plot(x_lst, y_lst, path, name, xlabel, ylabel):
    plt.plot(x_lst, y_lst)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    plt.savefig(path + name)

# %%
print_every = 100
    
def train(model, optimizer, scheduler, weight_decay=0.001, epochs=1, best_acc=0.0):
    loss_his = []
    epoch_lst = []
    acc_his = []
    
    model = model.to(device=device)
    model = nn.DataParallel(model,device_ids=[0,1])  
    
    for e in range(epochs):
        scheduler.step()
        for step, (x, y) in enumerate(loader_train):
            model.train()
            x = x.to(device=device, dtype=dtype)
            y = y.to(device=device, dtype=torch.long)
            
            scores = model(x)
            loss = F.cross_entropy(scores, y)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step % print_every == 0:
                print('Epoch %d, Iteration %d, loss = %.4f' % (e, step, loss.item()))
                acc = check_accuracy(loader_val, model)
                if acc > best_acc:
                    best_acc = acc
                    best_model_wts = copy.deepcopy(model.state_dict())
                fo = open("model_all_cnn_c.log", "a")
                fo.write("Epoch: {}\t Step: {}\t loss: {:.4f}\t accuracy: {:.2f}\n"\
                         .format(e, step, loss.item(), acc))
                fo.close()
                print()
        epoch_lst.append(e)
        loss_his.append(loss.item())
        acc_his.append(acc)
    
    plot(epoch_lst, loss_his, path="../results figure/", name="Model ALL CNN C_Loss accross Epoch", 
        xlabel="epoch", ylabel="loss")
    plot(epoch_lst, acc_his, path="../results figure/", name="Model ALL CNN C_Accuracy accross Epoch",
        xlabel="epoch", ylabel="accuracy")
    
    print("Best accuracy:", best_acc)
    fo = open("model_all_cnn_c.log", "a")
    fo.write("Best accuracy: {}".format(best_acc))
    fo.close()
    model.load_state_dict(best_model_wts)
    return model

# %%
lr_lst = [0.01]

fo = open("model_all_cnn_c.log", "w")
fo.write("Model All CNN C Trainning log\n")
fo.close()

for learning_rate in lr_lst:
    fo = open("model_all_cnn_c.log", "a")
    fo.write("\nOriginal Learning rate: {}\n".format(learning_rate))
    fo.close()
    print("Learning_rate:", learning_rate)
    model = Model(in_channel=3, channel_1=96, channel_2=192, 
             channel_3=192, channel_4=192, num_classes=10) 
    optimizer = optim.SGD(model.parameters(), lr = learning_rate, momentum=0.9, weight_decay=0.001)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                                               milestones=[200, 250, 300], gamma=0.1)
    best_model = train(model, optimizer, scheduler, epochs=350, best_acc=0.0)
    print()
# Out:
# Learning_rate: 0.01
# Epoch 0, Iteration 0, loss = 2.3034
# Checking accuracy on validation set
# Got 113 / 1000 correct (11.30)
#
# Epoch 0, Iteration 100, loss = 2.3034
# Checking accuracy on validation set
# Got 119 / 1000 correct (11.90)
#
# Epoch 0, Iteration 200, loss = 2.3000
# Checking accuracy on validation set
# Got 87 / 1000 correct (8.70)
#
# Epoch 0, Iteration 300, loss = 2.3018
# Checking accuracy on validation set
# Got 113 / 1000 correct (11.30)
#
# Epoch 0, Iteration 400, loss = 2.3013
# Checking accuracy on validation set
# Got 113 / 1000 correct (11.30)
#
# Epoch 0, Iteration 500, loss = 2.3028
# Checking accuracy on validation set
# Got 87 / 1000 correct (8.70)
#
# Epoch 0, Iteration 600, loss = 2.3019
# Checking accuracy on validation set
# Got 87 / 1000 correct (8.70)
#
# Epoch 0, Iteration 700, loss = 2.3025
# Checking accuracy on validation set
# Got 87 / 1000 correct (8.70)
#
# Epoch 1, Iteration 0, loss = 2.3004
# Checking accuracy on validation set
# Got 87 / 1000 correct (8.70)
#
# Epoch 1, Iteration 100, loss = 2.2987
# Checking accuracy on validation set
# Got 87 / 1000 correct (8.70)
#
# Epoch 1, Iteration 200, loss = 2.1661
# Checking accuracy on validation set
# Got 91 / 1000 correct (9.10)
#
# Epoch 1, Iteration 300, loss = 2.2368
# Checking accuracy on validation set
# Got 168 / 1000 correct (16.80)
#
# Epoch 1, Iteration 400, loss = 2.2583
# Checking accuracy on validation set
# Got 136 / 1000 correct (13.60)
#
# Epoch 1, Iteration 500, loss = 2.1741
# Checking accuracy on validation set
# Got 149 / 1000 correct (14.90)
#
# Epoch 1, Iteration 600, loss = 2.2509
# Checking accuracy on validation set
# Got 189 / 1000 correct (18.90)
#
# Epoch 1, Iteration 700, loss = 2.2566
# Checking accuracy on validation set
# Got 189 / 1000 correct (18.90)
#
# Epoch 2, Iteration 0, loss = 2.1762
# Checking accuracy on validation set
# Got 188 / 1000 correct (18.80)
#
# Epoch 2, Iteration 100, loss = 2.2237
# Checking accuracy on validation set
# Got 209 / 1000 correct (20.90)
#
# Epoch 2, Iteration 200, loss = 2.1712
# Checking accuracy on validation set
# Got 228 / 1000 correct (22.80)
#
# Epoch 2, Iteration 300, loss = 2.0405
# Checking accuracy on validation set
# Got 236 / 1000 correct (23.60)
#
# Epoch 2, Iteration 400, loss = 2.1676
# Checking accuracy on validation set
# Got 237 / 1000 correct (23.70)
#
# Epoch 2, Iteration 500, loss = 2.3735
# Checking accuracy on validation set
# Got 250 / 1000 correct (25.00)
#
# Epoch 2, Iteration 600, loss = 2.2140
# Checking accuracy on validation set
# Got 247 / 1000 correct (24.70)
#
# Epoch 2, Iteration 700, loss = 2.0778
# Checking accuracy on validation set
# Got 254 / 1000 correct (25.40)
#
# Epoch 3, Iteration 0, loss = 2.0382
# Checking accuracy on validation set
# Got 199 / 1000 correct (19.90)
#
# Epoch 3, Iteration 100, loss = 1.9731
# Checking accuracy on validation set
# Got 295 / 1000 correct (29.50)
#
# Epoch 3, Iteration 200, loss = 1.8192
# Checking accuracy on validation set
# Got 274 / 1000 correct (27.40)
#
# Epoch 3, Iteration 300, loss = 1.7320
# Checking accuracy on validation set
# Got 297 / 1000 correct (29.70)
#
# Epoch 3, Iteration 400, loss = 1.8879
# Checking accuracy on validation set
# Got 328 / 1000 correct (32.80)
#
# Epoch 3, Iteration 500, loss = 1.8528
# Checking accuracy on validation set
# Got 308 / 1000 correct (30.80)
#
# Epoch 3, Iteration 600, loss = 1.7873
# Checking accuracy on validation set
# Got 340 / 1000 correct (34.00)
#
# Epoch 3, Iteration 700, loss = 1.7152
# Checking accuracy on validation set
# Got 335 / 1000 correct (33.50)
#
# Epoch 4, Iteration 0, loss = 1.8382
# Checking accuracy on validation set
# Got 340 / 1000 correct (34.00)
#
# Epoch 4, Iteration 100, loss = 1.9375
# Checking accuracy on validation set
# Got 337 / 1000 correct (33.70)
#
# Epoch 4, Iteration 200, loss = 1.7335
# Checking accuracy on validation set
# Got 360 / 1000 correct (36.00)
#
# Epoch 4, Iteration 300, loss = 1.7614
# Checking accuracy on validation set
# Got 360 / 1000 correct (36.00)
#
# Epoch 4, Iteration 400, loss = 1.6994
# Checking accuracy on validation set
# Got 375 / 1000 correct (37.50)
#
# Epoch 4, Iteration 500, loss = 1.7582
# Checking accuracy on validation set
# Got 403 / 1000 correct (40.30)
#
# Epoch 4, Iteration 600, loss = 1.6032
# Checking accuracy on validation set
# Got 405 / 1000 correct (40.50)
#
# Epoch 4, Iteration 700, loss = 1.7427
# Checking accuracy on validation set
# Got 352 / 1000 correct (35.20)
#
# Epoch 5, Iteration 0, loss = 1.6890
# Checking accuracy on validation set
# Got 403 / 1000 correct (40.30)
#
# Epoch 5, Iteration 100, loss = 1.5362
# Checking accuracy on validation set
# Got 399 / 1000 correct (39.90)
#
# Epoch 5, Iteration 200, loss = 1.3963
# Checking accuracy on validation set
# Got 403 / 1000 correct (40.30)
#
# Epoch 5, Iteration 300, loss = 1.2635
# Checking accuracy on validation set
# Got 413 / 1000 correct (41.30)
#
# Epoch 5, Iteration 400, loss = 1.7545
# Checking accuracy on validation set
# Got 379 / 1000 correct (37.90)
#
# Epoch 5, Iteration 500, loss = 1.4697
# Checking accuracy on validation set
# Got 441 / 1000 correct (44.10)
#
# Epoch 5, Iteration 600, loss = 1.6265
# Checking accuracy on validation set
# Got 412 / 1000 correct (41.20)
#
# Epoch 5, Iteration 700, loss = 1.3430
# Checking accuracy on validation set
# Got 418 / 1000 correct (41.80)
#
# Epoch 6, Iteration 0, loss = 1.3595
# Checking accuracy on validation set
# Got 497 / 1000 correct (49.70)
#
# Epoch 6, Iteration 100, loss = 1.2895
# Checking accuracy on validation set
# Got 453 / 1000 correct (45.30)
#
# Epoch 6, Iteration 200, loss = 1.3636
# Checking accuracy on validation set
# Got 424 / 1000 correct (42.40)
#
# Epoch 6, Iteration 300, loss = 1.3473
# Checking accuracy on validation set
# Got 479 / 1000 correct (47.90)
#
# Epoch 6, Iteration 400, loss = 1.4049
# Checking accuracy on validation set
# Got 479 / 1000 correct (47.90)
#
# Epoch 6, Iteration 500, loss = 1.1803
# Checking accuracy on validation set
# Got 525 / 1000 correct (52.50)
#
# Epoch 6, Iteration 600, loss = 1.4559
# Checking accuracy on validation set
# Got 475 / 1000 correct (47.50)
#
# Epoch 6, Iteration 700, loss = 1.3674
# Checking accuracy on validation set
# Got 512 / 1000 correct (51.20)
#
# Epoch 7, Iteration 0, loss = 1.2717
# Checking accuracy on validation set
# Got 520 / 1000 correct (52.00)
#
# Epoch 7, Iteration 100, loss = 1.1119
# Checking accuracy on validation set
# Got 529 / 1000 correct (52.90)
#
# Epoch 7, Iteration 200, loss = 1.3722
# Checking accuracy on validation set
# Got 537 / 1000 correct (53.70)
#
# Epoch 7, Iteration 300, loss = 1.1409
# Checking accuracy on validation set
# Got 536 / 1000 correct (53.60)
#
# Epoch 7, Iteration 400, loss = 1.3169
# Checking accuracy on validation set
# Got 506 / 1000 correct (50.60)
#
# Epoch 7, Iteration 500, loss = 1.2029
# Checking accuracy on validation set
# Got 518 / 1000 correct (51.80)
#
# Epoch 7, Iteration 600, loss = 1.2109
# Checking accuracy on validation set
# Got 559 / 1000 correct (55.90)
#
# Epoch 7, Iteration 700, loss = 1.0356
# Checking accuracy on validation set
# Got 561 / 1000 correct (56.10)
#
# Epoch 8, Iteration 0, loss = 1.1778
# Checking accuracy on validation set
# Got 578 / 1000 correct (57.80)
#
# Epoch 8, Iteration 100, loss = 1.0223
# Checking accuracy on validation set
# Got 560 / 1000 correct (56.00)
#
# Epoch 8, Iteration 200, loss = 1.3334
# Checking accuracy on validation set
# Got 529 / 1000 correct (52.90)
#
#
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 338, Iteration 700, loss = 0.0086
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 339, Iteration 0, loss = 0.0050
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 339, Iteration 100, loss = 0.0133
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 339, Iteration 200, loss = 0.0113
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 339, Iteration 300, loss = 0.0144
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 339, Iteration 400, loss = 0.0101
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 339, Iteration 500, loss = 0.0085
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 339, Iteration 600, loss = 0.0185
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 339, Iteration 700, loss = 0.0133
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 340, Iteration 0, loss = 0.0217
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 340, Iteration 100, loss = 0.0116
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 340, Iteration 200, loss = 0.0079
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 340, Iteration 300, loss = 0.0141
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 340, Iteration 400, loss = 0.0061
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 340, Iteration 500, loss = 0.0163
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 340, Iteration 600, loss = 0.0128
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 340, Iteration 700, loss = 0.0094
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 341, Iteration 0, loss = 0.0122
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 341, Iteration 100, loss = 0.0079
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 341, Iteration 200, loss = 0.0141
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 341, Iteration 300, loss = 0.0116
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 341, Iteration 400, loss = 0.0130
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 341, Iteration 500, loss = 0.0062
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 341, Iteration 600, loss = 0.0045
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 341, Iteration 700, loss = 0.0060
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 0, loss = 0.0104
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 100, loss = 0.0163
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 200, loss = 0.0087
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 300, loss = 0.0106
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 400, loss = 0.0166
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 500, loss = 0.0114
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 600, loss = 0.0163
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 700, loss = 0.0128
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 343, Iteration 0, loss = 0.0144
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 343, Iteration 100, loss = 0.0103
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 343, Iteration 200, loss = 0.0070
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 343, Iteration 300, loss = 0.0226
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 343, Iteration 400, loss = 0.0097
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 343, Iteration 500, loss = 0.0148
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 343, Iteration 600, loss = 0.0135
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 343, Iteration 700, loss = 0.0128
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 344, Iteration 0, loss = 0.0114
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 344, Iteration 100, loss = 0.0106
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 344, Iteration 200, loss = 0.0065
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 344, Iteration 300, loss = 0.0136
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 344, Iteration 400, loss = 0.0146
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 344, Iteration 500, loss = 0.0160
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 344, Iteration 600, loss = 0.0065
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 344, Iteration 700, loss = 0.0132
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 345, Iteration 0, loss = 0.0120
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 345, Iteration 100, loss = 0.0084
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 345, Iteration 200, loss = 0.0131
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 345, Iteration 300, loss = 0.0103
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 345, Iteration 400, loss = 0.0124
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 345, Iteration 500, loss = 0.0106
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 345, Iteration 600, loss = 0.0076
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 345, Iteration 700, loss = 0.0090
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 346, Iteration 0, loss = 0.0081
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 346, Iteration 100, loss = 0.0093
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 346, Iteration 200, loss = 0.0156
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 346, Iteration 300, loss = 0.0115
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 346, Iteration 400, loss = 0.0112
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 346, Iteration 500, loss = 0.0098
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 346, Iteration 600, loss = 0.0133
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 346, Iteration 700, loss = 0.0161
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 347, Iteration 0, loss = 0.0089
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 347, Iteration 100, loss = 0.0094
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 347, Iteration 200, loss = 0.0115
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 347, Iteration 300, loss = 0.0106
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 347, Iteration 400, loss = 0.0124
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 347, Iteration 500, loss = 0.0125
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 347, Iteration 600, loss = 0.0069
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 347, Iteration 700, loss = 0.0109
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 348, Iteration 0, loss = 0.0124
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 348, Iteration 100, loss = 0.0086
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 348, Iteration 200, loss = 0.0087
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 348, Iteration 300, loss = 0.0111
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 348, Iteration 400, loss = 0.0101
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 348, Iteration 500, loss = 0.0067
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 348, Iteration 600, loss = 0.0152
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 348, Iteration 700, loss = 0.0132
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 0, loss = 0.0094
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 100, loss = 0.0160
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 200, loss = 0.0160
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 300, loss = 0.0094
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 400, loss = 0.0153
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 500, loss = 0.0088
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 600, loss = 0.0106
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 700, loss = 0.0125
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
# Best accuracy: 0.869

# %%
PATH = "../best_model/"
model_name = "best_model_all_cnn_c.pt"
if not os.path.exists(PATH):
    os.mkdir(PATH)
torch.save(best_model.state_dict(), PATH + model_name)
