# %%
import torch
from torch.utils.data import sampler
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import os
import copy
import matplotlib.pyplot as plt

# %%
NUM_TRAIN = 49000

transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
            ])
cifar10_train = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=True,
                                           download=True, transform=transform)
loader_train = torch.utils.data.DataLoader(cifar10_train, batch_size=64,
                                      sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))
cifar10_val = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=False,
                                         download=True, transform=transform)
loader_val = torch.utils.data.DataLoader(cifar10_train, batch_size=64,
                                    sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))
cifar10_test = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=False,
                                         download=True, transform=transform)
loader_test = torch.utils.data.DataLoader(cifar10_train, batch_size=64)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_images, train_labels = iter(loader_train).next()
print("train_X:", train_images.size(), "train_y:", train_labels.size())
val_images, val_labels = iter(loader_val).next()
print("val_X:", val_images.size(), "val_y:", val_labels.size())
test_images, test_labels = iter(loader_test).next()
print("test_X:", test_images.size(), "test_y:", test_labels.size())
# Out:
# train_X: torch.Size([64, 3, 32, 32]) train_y: torch.Size([64])
# val_X: torch.Size([64, 3, 32, 32]) val_y: torch.Size([64])
# test_X: torch.Size([64, 3, 32, 32]) test_y: torch.Size([64])

# %%
USE_GPU = True

dtype = torch.float32

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
print('using device', device)
# Out:
# using device cuda

# %%
class Model(nn.Module):
    def __init__(self, in_channel, channel_1, channel_2, 
                 channel_3, channel_4, num_classes):
        """
        Default initialization:
        model = Model(in_channel=3, channel_1=96, channel_2=192, 
                 channel_3=192, channel_4=192, num_classes=10)
        """
        super().__init__()
        self.conv1_1 = nn.Conv2d(in_channel, channel_1, 3, padding=1)  #(3, 96, 3)
        self.conv1_2 = nn.Conv2d(channel_1, channel_1, 3, stride=2, padding=1)   #(96, 96, 3)
        self.conv2_1 = nn.Conv2d(channel_1, channel_2, 3, padding=1)   #(96, 192, 3)
        self.conv2_2 = nn.Conv2d(channel_2, channel_2, 3, stride=2, padding=1)   #(192, 192, 3)
        self.conv3 = nn.Conv2d(channel_2, channel_3, 3)   #(192, 192, 3)
        self.conv4 = nn.Conv2d(channel_3, channel_4, 1)   #(192, 192, 1)
        self.conv5 = nn.Conv2d(channel_4, num_classes, 1) #(192, 10, 1)
        
    def forward(self, x):
        """
        x.shape: (64, 3, 32, 32)
        """
        N = x.shape[0]
        x_drop = F.dropout(x, .2)
        conv1_1_out = F.relu(self.conv1_1(x_drop))            # (64, 96, 32, 32)
        layer1_out = F.relu(self.conv1_2(conv1_1_out))   # (64, 96, 32, 32)
        layer1_out_drop = F.dropout(layer1_out, .5)
        conv2_1_out = F.relu(self.conv2_1(layer1_out_drop))   # (64, 192, 16, 16)
        layer2_out = F.relu(self.conv2_2(conv2_1_out))   # (64, 192, 16, 16)    
        layer2_out_drop = F.dropout(layer2_out, .5)
        layer3_out = F.relu(self.conv3(layer2_out_drop))             # (64, 192, 6, 6)
        layer4_out = F.relu(self.conv4(layer3_out))             # (64, 192, 6, 6)
        layer5_out = F.relu(self.conv5(layer4_out))             # (64, 10, 6, 6)
#         print(x.size(), conv1_1_out.size(), layer1_out.size(),layer5_out.size())
        out = layer5_out.view(N, 10, -1).mean(dim=2)
        return out
        
def test_Model():
    x = torch.zeros((64, 3, 32, 32), dtype=dtype)
    model = Model(in_channel=3, channel_1=96, channel_2=192, 
                 channel_3=192, channel_4=192, num_classes=10)
    scores = model(x)
    print(scores.size())
test_Model()
# Out:
# torch.Size([64, 10])

# %%
def check_accuracy(loader, model):
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set') 
    num_correct = 0
    num_samples = 0
    model.eval()
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            scores = model(x)
            _, preds = scores.max(1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def plot(x_lst, y_lst, path, name, xlabel, ylabel):
    plt.plot(x_lst, y_lst)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    plt.savefig(path + name)

# %%
print_every = 100
    
def train(model, optimizer, scheduler, weight_decay=0.001, epochs=1, best_acc=0.0):
    loss_his = []
    epoch_lst = []
    acc_his = []
    ori_lr = learning_rate
    
    model = model.to(device=device)
    model = nn.DataParallel(model,device_ids=[0,1])  
    
    for e in range(epochs):
        scheduler.step()
        for step, (x, y) in enumerate(loader_train):
            model.train()
            x = x.to(device=device, dtype=dtype)
            y = y.to(device=device, dtype=torch.long)
            
            scores = model(x)
            loss = F.cross_entropy(scores, y)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step % print_every == 0:
                print('Epoch %d, Iteration %d, loss = %.4f' % (e, step, loss.item()))
                acc = check_accuracy(loader_val, model)
                if acc > best_acc:
                    best_acc = acc
                    best_model_wts = copy.deepcopy(model.state_dict())
                fo = open("model_strided_cnn_c.log", "a")
                fo.write("Epoch: {}\t Step: {}\t loss: {:.4f}\t accuracy: {:.2f}\n"\
                         .format(e, step, loss.item(), acc))
                fo.close()
                print()
        epoch_lst.append(e)
        loss_his.append(loss.item())
        acc_his.append(acc)
    
    plot(epoch_lst, loss_his, path="../results figure/", name="Model Strided CNN C_Loss accross Epoch", 
        xlabel="epoch", ylabel="loss")
    plot(epoch_lst, acc_his, path="../results figure/", name="Model Strided CNN C_Accuracy accross Epoch",
        xlabel="epoch", ylabel="accuracy")
                
    print("Best accuracy:", best_acc)
    fo = open("model_strided_cnn_c.log", "a")
    fo.write("Best accuracy: {}".format(best_acc))
    fo.close()
    model.load_state_dict(best_model_wts)
    return model

# %%
lr_lst = [0.01]

fo = open("model_strided_cnn_c.log", "w")
fo.write("Model Strided CNN C Trainning log\n")
fo.close()

for learning_rate in lr_lst:
    fo = open("model_strided_cnn_c.log", "a")
    fo.write("\nOriginal Learning rate: {}\n".format(learning_rate))
    fo.close()
    print("Learning_rate:", learning_rate)
    model = Model(in_channel=3, channel_1=96, channel_2=192, 
             channel_3=192, channel_4=192, num_classes=10) 
    optimizer = optim.SGD(model.parameters(), lr = learning_rate, momentum=0.9, weight_decay=0.001)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                                               milestones=[200, 250, 300], gamma=0.1)
    best_model = train(model, optimizer, scheduler, epochs=350, best_acc=0.0)
    print()
# Out:
# Learning_rate: 0.01
# Epoch 0, Iteration 0, loss = 2.3036
# Checking accuracy on validation set
# Got 113 / 1000 correct (11.30)
#
# Epoch 0, Iteration 100, loss = 2.3044
# Checking accuracy on validation set
# Got 113 / 1000 correct (11.30)
#
# Epoch 0, Iteration 200, loss = 2.2936
# Checking accuracy on validation set
# Got 188 / 1000 correct (18.80)
#
# Epoch 0, Iteration 300, loss = 2.2411
# Checking accuracy on validation set
# Got 226 / 1000 correct (22.60)
#
# Epoch 0, Iteration 400, loss = 1.9411
# Checking accuracy on validation set
# Got 155 / 1000 correct (15.50)
#
# Epoch 0, Iteration 500, loss = 2.0615
# Checking accuracy on validation set
# Got 239 / 1000 correct (23.90)
#
# Epoch 0, Iteration 600, loss = 1.8807
# Checking accuracy on validation set
# Got 280 / 1000 correct (28.00)
#
# Epoch 0, Iteration 700, loss = 1.8305
# Checking accuracy on validation set
# Got 264 / 1000 correct (26.40)
#
# Epoch 1, Iteration 0, loss = 1.9536
# Checking accuracy on validation set
# Got 344 / 1000 correct (34.40)
#
# Epoch 1, Iteration 100, loss = 1.7692
# Checking accuracy on validation set
# Got 256 / 1000 correct (25.60)
#
# Epoch 1, Iteration 200, loss = 1.6781
# Checking accuracy on validation set
# Got 342 / 1000 correct (34.20)
#
# Epoch 1, Iteration 300, loss = 1.7513
# Checking accuracy on validation set
# Got 366 / 1000 correct (36.60)
#
# Epoch 1, Iteration 400, loss = 1.5146
# Checking accuracy on validation set
# Got 380 / 1000 correct (38.00)
#
# Epoch 1, Iteration 500, loss = 1.4177
# Checking accuracy on validation set
# Got 408 / 1000 correct (40.80)
#
# Epoch 1, Iteration 600, loss = 1.7058
# Checking accuracy on validation set
# Got 421 / 1000 correct (42.10)
#
# Epoch 1, Iteration 700, loss = 1.4752
# Checking accuracy on validation set
# Got 422 / 1000 correct (42.20)
#
# Epoch 2, Iteration 0, loss = 1.5928
# Checking accuracy on validation set
# Got 410 / 1000 correct (41.00)
#
# Epoch 2, Iteration 100, loss = 1.4986
# Checking accuracy on validation set
# Got 440 / 1000 correct (44.00)
#
# Epoch 2, Iteration 200, loss = 1.3520
# Checking accuracy on validation set
# Got 445 / 1000 correct (44.50)
#
# Epoch 2, Iteration 300, loss = 1.3147
# Checking accuracy on validation set
# Got 450 / 1000 correct (45.00)
#
# Epoch 2, Iteration 400, loss = 1.5426
# Checking accuracy on validation set
# Got 480 / 1000 correct (48.00)
#
# Epoch 2, Iteration 500, loss = 1.2518
# Checking accuracy on validation set
# Got 424 / 1000 correct (42.40)
#
# Epoch 2, Iteration 600, loss = 1.6818
# Checking accuracy on validation set
# Got 475 / 1000 correct (47.50)
#
# Epoch 2, Iteration 700, loss = 1.4350
# Checking accuracy on validation set
# Got 463 / 1000 correct (46.30)
#
# Epoch 3, Iteration 0, loss = 1.3892
# Checking accuracy on validation set
# Got 495 / 1000 correct (49.50)
#
# Epoch 3, Iteration 100, loss = 1.5079
# Checking accuracy on validation set
# Got 448 / 1000 correct (44.80)
#
# Epoch 3, Iteration 200, loss = 1.4857
# Checking accuracy on validation set
# Got 475 / 1000 correct (47.50)
#
# Epoch 3, Iteration 300, loss = 1.3394
# Checking accuracy on validation set
# Got 515 / 1000 correct (51.50)
#
# Epoch 3, Iteration 400, loss = 1.4277
# Checking accuracy on validation set
# Got 509 / 1000 correct (50.90)
#
# Epoch 3, Iteration 500, loss = 1.0993
# Checking accuracy on validation set
# Got 534 / 1000 correct (53.40)
#
# Epoch 3, Iteration 600, loss = 1.2402
# Checking accuracy on validation set
# Got 498 / 1000 correct (49.80)
#
# Epoch 3, Iteration 700, loss = 1.2783
# Checking accuracy on validation set
# Got 509 / 1000 correct (50.90)
#
# Epoch 4, Iteration 0, loss = 1.2306
# Checking accuracy on validation set
# Got 530 / 1000 correct (53.00)
#
# Epoch 4, Iteration 100, loss = 1.1382
# Checking accuracy on validation set
# Got 544 / 1000 correct (54.40)
#
# Epoch 4, Iteration 200, loss = 1.2349
# Checking accuracy on validation set
# Got 529 / 1000 correct (52.90)
#
# Epoch 4, Iteration 300, loss = 1.3647
# Checking accuracy on validation set
# Got 560 / 1000 correct (56.00)
#
# Epoch 4, Iteration 400, loss = 1.2986
# Checking accuracy on validation set
# Got 545 / 1000 correct (54.50)
#
# Epoch 4, Iteration 500, loss = 1.2442
# Checking accuracy on validation set
# Got 571 / 1000 correct (57.10)
#
# Epoch 4, Iteration 600, loss = 0.9982
# Checking accuracy on validation set
# Got 569 / 1000 correct (56.90)
#
# Epoch 4, Iteration 700, loss = 1.0125
# Checking accuracy on validation set
# Got 587 / 1000 correct (58.70)
#
# Epoch 5, Iteration 0, loss = 1.0236
# Checking accuracy on validation set
# Got 586 / 1000 correct (58.60)
#
# Epoch 5, Iteration 100, loss = 1.2610
# Checking accuracy on validation set
# Got 588 / 1000 correct (58.80)
#
# Epoch 5, Iteration 200, loss = 1.0206
# Checking accuracy on validation set
# Got 572 / 1000 correct (57.20)
#
# Epoch 5, Iteration 300, loss = 1.1493
# Checking accuracy on validation set
# Got 580 / 1000 correct (58.00)
#
# Epoch 5, Iteration 400, loss = 0.9759
# Checking accuracy on validation set
# Got 584 / 1000 correct (58.40)
#
# Epoch 5, Iteration 500, loss = 1.1266
# Checking accuracy on validation set
# Got 629 / 1000 correct (62.90)
#
# Epoch 5, Iteration 600, loss = 1.1701
# Checking accuracy on validation set
# Got 607 / 1000 correct (60.70)
#
# Epoch 5, Iteration 700, loss = 1.0737
# Checking accuracy on validation set
# Got 628 / 1000 correct (62.80)
#
# Epoch 6, Iteration 0, loss = 1.0871
# Checking accuracy on validation set
# Got 627 / 1000 correct (62.70)
#
# Epoch 6, Iteration 100, loss = 1.1126
# Checking accuracy on validation set
# Got 619 / 1000 correct (61.90)
#
# Epoch 6, Iteration 200, loss = 0.9997
# Checking accuracy on validation set
# Got 618 / 1000 correct (61.80)
#
# Epoch 6, Iteration 300, loss = 1.0234
# Checking accuracy on validation set
# Got 607 / 1000 correct (60.70)
#
# Epoch 6, Iteration 400, loss = 0.8808
# Checking accuracy on validation set
# Got 609 / 1000 correct (60.90)
#
# Epoch 6, Iteration 500, loss = 1.0370
# Checking accuracy on validation set
# Got 620 / 1000 correct (62.00)
#
# Epoch 6, Iteration 600, loss = 1.1962
# Checking accuracy on validation set
# Got 659 / 1000 correct (65.90)
#
# Epoch 6, Iteration 700, loss = 1.2949
# Checking accuracy on validation set
# Got 622 / 1000 correct (62.20)
#
# Epoch 7, Iteration 0, loss = 1.1517
# Checking accuracy on validation set
# Got 672 / 1000 correct (67.20)
#
# Epoch 7, Iteration 100, loss = 1.1340
# Checking accuracy on validation set
# Got 626 / 1000 correct (62.60)
#
# Epoch 7, Iteration 200, loss = 1.4643
# Checking accuracy on validation set
# Got 641 / 1000 correct (64.10)
#
# Epoch 7, Iteration 300, loss = 0.9204
# Checking accuracy on validation set
# Got 683 / 1000 correct (68.30)
#
# Epoch 7, Iteration 400, loss = 0.8950
# Checking accuracy on validation set
# Got 650 / 1000 correct (65.00)
#
# Epoch 7, Iteration 500, loss = 1.1693
# Checking accuracy on validation set
# Got 688 / 1000 correct (68.80)
#
# Epoch 7, Iteration 600, loss = 1.0196
# Checking accuracy on validation set
# Got 674 / 1000 correct (67.40)
#
# Epoch 7, Iteration 700, loss = 0.9132
# Checking accuracy on validation set
# Got 649 / 1000 correct (64.90)
#
# Epoch 8, Iteration 0, loss = 0.7049
# Checking accuracy on validation set
# Got 681 / 1000 correct (68.10)
#
# Epoch 8, Iteration 100, loss = 0.9447
# Checking accuracy on validation set
# Got 625 / 1000 correct (62.50)
#
# Epoch 8, Iteration 200, loss = 0.8171
# Checking accuracy on validation set
# Got 682 / 1000 correct (68.20)
#
# Epoch 8, Iteration 300, loss = 0.8409
# Checking accuracy on validation set
# Got 648 / 1000 correct (64.80)
#
# Epoch 8, Iteration 400, loss = 1.0436
# Checking accuracy on validation set
# Got 666 / 1000 correct (66.60)
#
# Epoch 8, Iteration 500, loss = 0.8815
# Checking accuracy on validation set
# Got 688 / 1000 correct (68.80)
#
# Epoch 8, Iteration 600, loss = 0.7401
# Checking accuracy on validation set
# Got 697 / 1000 correct (69.70)
#
# Epoch 8, Iteration 700, loss = 1.0250
# Checking accuracy on validation set
# Got 695 / 1000 correct (69.50)
#
# Epoch 9, Iteration 0, loss = 0.8120
# Checking accuracy on validation set
# Got 659 / 1000 correct (65.90)
#
# Epoch 9, Iteration 100, loss = 0.8743
# Checking accuracy on validation set
# Got 669 / 1000 correct (66.90)
#
# Epoch 9, Iteration 200, loss = 0.6493
# Checking accuracy on validation set
# Got 697 / 1000 correct (69.70)
#
# Epoch 9, Iteration 300, loss = 0.8151
# Checking accuracy on validation set
# Got 684 / 1000 correct (68.40)
#
# Epoch 9, Iteration 400, loss = 1.0419
# Checking accuracy on validation set
# Got 694 / 1000 correct (69.40)
#
# Epoch 9, Iteration 500, loss = 0.7959
# Checking accuracy on validation set
# Got 702 / 1000 correct (70.20)
#
# Epoch 9, Iteration 600, loss = 0.8333
# Checking accuracy on validation set
# Got 673 / 1000 correct (67.30)
#
# Epoch 9, Iteration 700, loss = 0.9100
# Checking accuracy on validation set
# Got 674 / 1000 correct (67.40)
#
# Epoch 10, Iteration 0, loss = 0.6582
# Checking accuracy on validation set
# Got 686 / 1000 correct (68.60)
#
# Epoch 10, Iteration 100, loss = 0.6554
# Checking accuracy on validation set
# Got 672 / 1000 correct (67.20)
#
# Epoch 10, Iteration 200, loss = 0.8706
# Checking accuracy on validation set
# Got 674 / 1000 correct (67.40)
#
# Epoch 10, Iteration 300, loss = 0.6803
# Checking accuracy on validation set
# Got 702 / 1000 correct (70.20)
#
# Epoch 10, Iteration 400, loss = 0.9145
# Checking accuracy on validation set
# Got 684 / 1000 correct (68.40)
#
# Epoch 10, Iteration 500, loss = 0.8895
# Checking accuracy on validation set
# Got 705 / 1000 correct (70.50)
#
# Epoch 10, Iteration 600, loss = 0.9507
# Checking accuracy on validation set
# Got 718 / 1000 correct (71.80)
#
# Epoch 10, Iteration 700, loss = 0.5344
# Checking accuracy on validation set
# Got 695 / 1000 correct (69.50)
#
# Epoch 11, Iteration 0, loss = 0.6758
# Checking accuracy on validation set
# Got 729 / 1000 correct (72.90)
#
# Epoch 11, Iteration 100, loss = 0.7356
# Checking accuracy on validation set
# Got 706 / 1000 correct (70.60)
#
# Epoch 11, Iteration 200, loss = 0.8496
# Checking accuracy on validation set
# Got 696 / 1000 correct (69.60)
#
# Epoch 11, Iteration 300, loss = 0.6993
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
#
# Epoch 11, Iteration 400, loss = 1.1998
# Checking accuracy on validation set
# Got 710 / 1000 correct (71.00)
#
# Epoch 11, Iteration 500, loss = 0.6031
# Checking accuracy on validation set
# Got 721 / 1000 correct (72.10)
#
# Epoch 11, Iteration 600, loss = 0.5636
# Checking accuracy on validation set
# Got 710 / 1000 correct (71.00)
#
# Epoch 11, Iteration 700, loss = 0.7982
# Checking accuracy on validation set
# Got 746 / 1000 correct (74.60)
#
# Epoch 12, Iteration 0, loss = 0.7798
# Checking accuracy on validation set
# Got 704 / 1000 correct (70.40)
#
# Epoch 12, Iteration 100, loss = 0.5107
# Checking accuracy on validation set
# Got 735 / 1000 correct (73.50)
#
# Epoch 12, Iteration 200, loss = 0.7951
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Epoch 12, Iteration 300, loss = 0.4815
# Checking accuracy on validation set
# Got 689 / 1000 correct (68.90)
#
# Epoch 12, Iteration 400, loss = 0.8928
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
#
# Epoch 12, Iteration 500, loss = 0.6019
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Epoch 12, Iteration 600, loss = 0.5974
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
#
# Epoch 12, Iteration 700, loss = 0.8547
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
#
# Epoch 13, Iteration 0, loss = 1.0156
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
#
# Epoch 13, Iteration 100, loss = 0.6832
# Checking accuracy on validation set
# Got 735 / 1000 correct (73.50)
#
# Epoch 13, Iteration 200, loss = 0.5883
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
#
# Epoch 13, Iteration 300, loss = 0.5954
# Checking accuracy on validation set
# Got 728 / 1000 correct (72.80)
#
# Epoch 13, Iteration 400, loss = 0.6870
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
#
# Epoch 13, Iteration 500, loss = 0.5108
# Checking accuracy on validation set
# Got 747 / 1000 correct (74.70)
#
# Epoch 13, Iteration 600, loss = 0.5791
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
#
# Epoch 13, Iteration 700, loss = 0.4892
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
#
# Epoch 14, Iteration 0, loss = 0.7256
# Checking accuracy on validation set
# Got 756 / 1000 correct (75.60)
#
# Epoch 14, Iteration 100, loss = 0.5805
# Checking accuracy on validation set
# Got 746 / 1000 correct (74.60)
#
# Epoch 14, Iteration 200, loss = 0.5871
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
#
# Epoch 14, Iteration 300, loss = 0.6443
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Epoch 14, Iteration 400, loss = 0.6073
# Checking accuracy on validation set
# Got 774 / 1000 correct (77.40)
#
# Epoch 14, Iteration 500, loss = 0.5162
# Checking accuracy on validation set
# Got 768 / 1000 correct (76.80)
#
# Epoch 14, Iteration 600, loss = 0.8510
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
#
# Epoch 14, Iteration 700, loss = 0.8215
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
#
# Epoch 15, Iteration 0, loss = 0.5672
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
#
# Epoch 15, Iteration 100, loss = 0.5540
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 15, Iteration 200, loss = 0.6215
# Checking accuracy on validation set
# Got 756 / 1000 correct (75.60)
#
# Epoch 15, Iteration 300, loss = 0.3778
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
#
# Epoch 15, Iteration 400, loss = 0.5038
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
#
# Epoch 15, Iteration 500, loss = 0.4290
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Epoch 15, Iteration 600, loss = 0.6678
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Epoch 15, Iteration 700, loss = 0.4456
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
#
# Epoch 16, Iteration 0, loss = 0.5869
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
#
# Epoch 16, Iteration 100, loss = 0.6039
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
#
# Epoch 16, Iteration 200, loss = 0.4743
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Epoch 16, Iteration 300, loss = 0.5681
# Checking accuracy on validation set
# Got 760 / 1000 correct (76.00)
#
# Epoch 16, Iteration 400, loss = 0.5828
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
#
# Epoch 16, Iteration 500, loss = 0.6450
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Epoch 16, Iteration 600, loss = 0.5701
# Checking accuracy on validation set
# Got 733 / 1000 correct (73.30)
#
# Epoch 16, Iteration 700, loss = 0.4577
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
#
# Epoch 17, Iteration 0, loss = 0.4992
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
#
# Epoch 17, Iteration 100, loss = 0.5851
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
#
# Epoch 17, Iteration 200, loss = 0.4409
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
#
# Epoch 17, Iteration 300, loss = 0.6937
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Epoch 17, Iteration 400, loss = 0.5035
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
#
# Epoch 17, Iteration 500, loss = 0.6878
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 17, Iteration 600, loss = 0.6328
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 17, Iteration 700, loss = 0.4880
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 18, Iteration 0, loss = 0.6376
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
#
# Epoch 18, Iteration 100, loss = 0.4965
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
#
# Epoch 18, Iteration 200, loss = 0.3817
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
#
# Epoch 18, Iteration 300, loss = 0.4006
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
#
# Epoch 18, Iteration 400, loss = 0.6059
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Epoch 18, Iteration 500, loss = 0.4591
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
#
# Epoch 18, Iteration 600, loss = 0.4031
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 18, Iteration 700, loss = 0.5536
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
#
# Epoch 19, Iteration 0, loss = 0.3599
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
#
# Epoch 19, Iteration 100, loss = 0.4965
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
#
# Epoch 19, Iteration 200, loss = 0.4695
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 19, Iteration 300, loss = 0.4066
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
#
# Epoch 19, Iteration 400, loss = 0.4995
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
#
# Epoch 19, Iteration 500, loss = 0.8707
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Epoch 19, Iteration 600, loss = 0.4029
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Epoch 19, Iteration 700, loss = 0.5043
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
#
# Epoch 20, Iteration 0, loss = 0.5839
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
#
# Epoch 20, Iteration 100, loss = 0.3998
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
#
# Epoch 20, Iteration 200, loss = 0.5370
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
#
# Epoch 20, Iteration 300, loss = 0.4843
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 20, Iteration 400, loss = 0.4633
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
#
# Epoch 20, Iteration 500, loss = 0.4442
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 20, Iteration 600, loss = 0.5240
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 20, Iteration 700, loss = 0.3572
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 21, Iteration 0, loss = 0.4237
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 21, Iteration 100, loss = 0.4234
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Epoch 21, Iteration 200, loss = 0.2610
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 21, Iteration 300, loss = 0.2982
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 21, Iteration 400, loss = 0.5943
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Epoch 21, Iteration 500, loss = 0.3741
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Epoch 21, Iteration 600, loss = 0.3816
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Epoch 21, Iteration 700, loss = 0.3897
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 22, Iteration 0, loss = 0.3517
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 22, Iteration 100, loss = 0.3680
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 22, Iteration 200, loss = 0.4376
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 22, Iteration 300, loss = 0.2865
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 22, Iteration 400, loss = 0.3156
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
#
# Epoch 22, Iteration 500, loss = 0.6102
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Epoch 22, Iteration 600, loss = 0.5207
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 22, Iteration 700, loss = 0.5613
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 23, Iteration 0, loss = 0.3771
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 23, Iteration 100, loss = 0.4477
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 23, Iteration 200, loss = 0.5404
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 23, Iteration 300, loss = 0.4973
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 23, Iteration 400, loss = 0.3547
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
#
# Epoch 23, Iteration 500, loss = 0.5070
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 23, Iteration 600, loss = 0.4557
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
#
# Epoch 23, Iteration 700, loss = 0.3871
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Epoch 24, Iteration 0, loss = 0.4238
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 24, Iteration 100, loss = 0.5184
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 24, Iteration 200, loss = 0.2905
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 24, Iteration 300, loss = 0.5667
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 24, Iteration 400, loss = 0.2700
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
#
# Epoch 24, Iteration 500, loss = 0.3341
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 24, Iteration 600, loss = 0.6454
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 24, Iteration 700, loss = 0.2546
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 25, Iteration 0, loss = 0.2239
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 25, Iteration 100, loss = 0.2638
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 25, Iteration 200, loss = 0.3119
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 25, Iteration 300, loss = 0.3431
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Epoch 25, Iteration 400, loss = 0.5369
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 25, Iteration 500, loss = 0.3618
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 25, Iteration 600, loss = 0.2114
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 25, Iteration 700, loss = 0.3087
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 26, Iteration 0, loss = 0.2250
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 26, Iteration 100, loss = 0.3114
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 26, Iteration 200, loss = 0.3317
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 26, Iteration 300, loss = 0.4174
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 26, Iteration 400, loss = 0.4340
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 26, Iteration 500, loss = 0.1785
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 26, Iteration 600, loss = 0.1506
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 26, Iteration 700, loss = 0.3991
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 27, Iteration 0, loss = 0.3026
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 27, Iteration 100, loss = 0.3160
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 27, Iteration 200, loss = 0.3443
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 27, Iteration 300, loss = 0.2727
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 27, Iteration 400, loss = 0.2311
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 27, Iteration 500, loss = 0.3027
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
#
# Epoch 27, Iteration 600, loss = 0.3615
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 27, Iteration 700, loss = 0.3030
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 28, Iteration 0, loss = 0.2434
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 28, Iteration 100, loss = 0.3400
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 28, Iteration 200, loss = 0.2244
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 28, Iteration 300, loss = 0.3403
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 28, Iteration 400, loss = 0.1820
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Epoch 28, Iteration 500, loss = 0.2418
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 28, Iteration 600, loss = 0.3184
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 28, Iteration 700, loss = 0.1902
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 29, Iteration 0, loss = 0.1976
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 29, Iteration 100, loss = 0.2620
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 29, Iteration 200, loss = 0.2312
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 29, Iteration 300, loss = 0.1501
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 29, Iteration 400, loss = 0.7254
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 29, Iteration 500, loss = 0.2570
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 29, Iteration 600, loss = 0.3863
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 29, Iteration 700, loss = 0.1819
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 30, Iteration 0, loss = 0.2783
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 30, Iteration 100, loss = 0.1911
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 30, Iteration 200, loss = 0.1728
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 30, Iteration 300, loss = 0.3177
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 30, Iteration 400, loss = 0.2464
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 30, Iteration 500, loss = 0.3578
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 30, Iteration 600, loss = 0.1382
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 30, Iteration 700, loss = 0.3661
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 31, Iteration 0, loss = 0.1887
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 31, Iteration 100, loss = 0.2226
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 31, Iteration 200, loss = 0.1731
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 31, Iteration 300, loss = 0.1292
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 31, Iteration 400, loss = 0.1764
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 31, Iteration 500, loss = 0.2431
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 31, Iteration 600, loss = 0.2581
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 31, Iteration 700, loss = 0.2629
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 32, Iteration 0, loss = 0.2717
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 32, Iteration 100, loss = 0.1402
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Epoch 32, Iteration 200, loss = 0.1918
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 32, Iteration 300, loss = 0.3702
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 32, Iteration 400, loss = 0.1259
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 32, Iteration 500, loss = 0.1664
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 32, Iteration 600, loss = 0.1688
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 32, Iteration 700, loss = 0.5094
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 33, Iteration 0, loss = 0.1281
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 33, Iteration 100, loss = 0.1787
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 33, Iteration 200, loss = 0.1535
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 33, Iteration 300, loss = 0.1981
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 33, Iteration 400, loss = 0.0750
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 33, Iteration 500, loss = 0.1623
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 33, Iteration 600, loss = 0.3795
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Epoch 33, Iteration 700, loss = 0.2700
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 34, Iteration 0, loss = 0.1152
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 34, Iteration 100, loss = 0.1342
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 34, Iteration 200, loss = 0.2194
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 34, Iteration 300, loss = 0.2166
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 34, Iteration 400, loss = 0.2519
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 34, Iteration 500, loss = 0.2441
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 34, Iteration 600, loss = 0.1980
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 34, Iteration 700, loss = 0.1668
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 35, Iteration 0, loss = 0.2655
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 35, Iteration 100, loss = 0.2341
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 35, Iteration 200, loss = 0.2796
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 35, Iteration 300, loss = 0.0951
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 35, Iteration 400, loss = 0.1981
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 35, Iteration 500, loss = 0.1711
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 35, Iteration 600, loss = 0.2902
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 35, Iteration 700, loss = 0.1931
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 36, Iteration 0, loss = 0.1785
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 36, Iteration 100, loss = 0.3091
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 36, Iteration 200, loss = 0.1068
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 36, Iteration 300, loss = 0.3009
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 36, Iteration 400, loss = 0.1618
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
#
# Epoch 36, Iteration 500, loss = 0.1213
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 36, Iteration 600, loss = 0.1563
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 36, Iteration 700, loss = 0.1040
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 37, Iteration 0, loss = 0.1550
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 37, Iteration 100, loss = 0.1284
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 37, Iteration 200, loss = 0.1079
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 37, Iteration 300, loss = 0.1267
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 37, Iteration 400, loss = 0.2744
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 37, Iteration 500, loss = 0.2459
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 37, Iteration 600, loss = 0.1791
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 37, Iteration 700, loss = 0.1456
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 38, Iteration 0, loss = 0.1846
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Epoch 38, Iteration 100, loss = 0.1258
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 38, Iteration 200, loss = 0.0685
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
#
# Epoch 38, Iteration 300, loss = 0.1664
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 38, Iteration 400, loss = 0.1956
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 38, Iteration 500, loss = 0.1913
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Epoch 38, Iteration 600, loss = 0.1940
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 38, Iteration 700, loss = 0.1915
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 39, Iteration 0, loss = 0.2188
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 39, Iteration 100, loss = 0.1058
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 39, Iteration 200, loss = 0.2678
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 39, Iteration 300, loss = 0.1709
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 39, Iteration 400, loss = 0.1421
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 39, Iteration 500, loss = 0.1483
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 39, Iteration 600, loss = 0.0871
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 39, Iteration 700, loss = 0.3332
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
#
# Epoch 40, Iteration 0, loss = 0.0752
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 40, Iteration 100, loss = 0.1837
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 40, Iteration 200, loss = 0.2965
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 40, Iteration 300, loss = 0.1304
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 40, Iteration 400, loss = 0.1595
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 40, Iteration 500, loss = 0.3082
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 40, Iteration 600, loss = 0.2549
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 40, Iteration 700, loss = 0.2071
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 41, Iteration 0, loss = 0.1665
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 41, Iteration 100, loss = 0.0861
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 41, Iteration 200, loss = 0.1781
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 41, Iteration 300, loss = 0.1053
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 41, Iteration 400, loss = 0.2159
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 41, Iteration 500, loss = 0.1312
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 41, Iteration 600, loss = 0.1250
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 41, Iteration 700, loss = 0.1123
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 42, Iteration 0, loss = 0.2208
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 42, Iteration 100, loss = 0.0409
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 42, Iteration 200, loss = 0.0903
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 42, Iteration 300, loss = 0.1140
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 42, Iteration 400, loss = 0.1648
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 42, Iteration 500, loss = 0.1279
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 42, Iteration 600, loss = 0.1861
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 42, Iteration 700, loss = 0.0695
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 43, Iteration 0, loss = 0.0902
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 43, Iteration 100, loss = 0.0801
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 43, Iteration 200, loss = 0.0977
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 43, Iteration 300, loss = 0.2157
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 43, Iteration 400, loss = 0.1155
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 43, Iteration 500, loss = 0.1100
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 43, Iteration 600, loss = 0.1020
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 43, Iteration 700, loss = 0.1357
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 44, Iteration 0, loss = 0.0877
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 44, Iteration 100, loss = 0.1077
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 44, Iteration 200, loss = 0.1238
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 44, Iteration 300, loss = 0.1531
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Epoch 44, Iteration 400, loss = 0.2031
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 44, Iteration 500, loss = 0.2328
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 44, Iteration 600, loss = 0.1320
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 44, Iteration 700, loss = 0.1466
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 45, Iteration 0, loss = 0.1440
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 45, Iteration 100, loss = 0.2007
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 45, Iteration 200, loss = 0.0812
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 45, Iteration 300, loss = 0.1204
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 45, Iteration 400, loss = 0.1189
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 45, Iteration 500, loss = 0.2012
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 45, Iteration 600, loss = 0.1939
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 45, Iteration 700, loss = 0.0689
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
#
# Epoch 46, Iteration 0, loss = 0.1137
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 46, Iteration 100, loss = 0.0442
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 46, Iteration 200, loss = 0.0731
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 46, Iteration 300, loss = 0.0521
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 46, Iteration 400, loss = 0.0960
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 46, Iteration 500, loss = 0.0664
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 46, Iteration 600, loss = 0.2540
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 46, Iteration 700, loss = 0.1415
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 47, Iteration 0, loss = 0.1191
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 47, Iteration 100, loss = 0.0441
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 47, Iteration 200, loss = 0.1028
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 47, Iteration 300, loss = 0.1461
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 47, Iteration 400, loss = 0.0992
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 47, Iteration 500, loss = 0.1671
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 47, Iteration 600, loss = 0.1755
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 47, Iteration 700, loss = 0.2263
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 48, Iteration 0, loss = 0.0758
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 48, Iteration 100, loss = 0.0503
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 48, Iteration 200, loss = 0.0718
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 48, Iteration 300, loss = 0.0664
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 48, Iteration 400, loss = 0.0952
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 48, Iteration 500, loss = 0.3069
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 48, Iteration 600, loss = 0.1735
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 48, Iteration 700, loss = 0.1260
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 49, Iteration 0, loss = 0.1028
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 49, Iteration 100, loss = 0.0783
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 49, Iteration 200, loss = 0.0637
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 49, Iteration 300, loss = 0.0434
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 49, Iteration 400, loss = 0.1035
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 49, Iteration 500, loss = 0.1387
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 49, Iteration 600, loss = 0.1030
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 49, Iteration 700, loss = 0.1392
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 50, Iteration 0, loss = 0.0537
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 50, Iteration 100, loss = 0.0770
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 50, Iteration 200, loss = 0.0490
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 50, Iteration 300, loss = 0.0949
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 50, Iteration 400, loss = 0.0667
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 50, Iteration 500, loss = 0.0719
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 50, Iteration 600, loss = 0.1436
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 50, Iteration 700, loss = 0.1168
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 51, Iteration 0, loss = 0.0354
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 51, Iteration 100, loss = 0.0978
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 51, Iteration 200, loss = 0.1333
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 51, Iteration 300, loss = 0.0306
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 51, Iteration 400, loss = 0.1333
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 51, Iteration 500, loss = 0.0465
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 51, Iteration 600, loss = 0.1300
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 51, Iteration 700, loss = 0.0895
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Epoch 52, Iteration 0, loss = 0.0852
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 52, Iteration 100, loss = 0.0632
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 52, Iteration 200, loss = 0.0413
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 52, Iteration 300, loss = 0.0677
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 52, Iteration 400, loss = 0.0599
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 52, Iteration 500, loss = 0.1811
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 52, Iteration 600, loss = 0.0889
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 52, Iteration 700, loss = 0.1732
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 53, Iteration 0, loss = 0.1572
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 53, Iteration 100, loss = 0.0218
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 53, Iteration 200, loss = 0.1019
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 53, Iteration 300, loss = 0.0943
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 53, Iteration 400, loss = 0.2509
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
#
# Epoch 53, Iteration 500, loss = 0.0571
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 53, Iteration 600, loss = 0.0690
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 53, Iteration 700, loss = 0.0811
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Epoch 54, Iteration 0, loss = 0.1731
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 54, Iteration 100, loss = 0.0520
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 54, Iteration 200, loss = 0.0810
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 54, Iteration 300, loss = 0.1180
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 54, Iteration 400, loss = 0.0472
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 54, Iteration 500, loss = 0.0810
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 54, Iteration 600, loss = 0.1045
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 54, Iteration 700, loss = 0.0923
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 55, Iteration 0, loss = 0.0232
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 55, Iteration 100, loss = 0.1070
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 55, Iteration 200, loss = 0.0971
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 55, Iteration 300, loss = 0.0973
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 55, Iteration 400, loss = 0.2038
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 55, Iteration 500, loss = 0.0416
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 55, Iteration 600, loss = 0.1200
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 55, Iteration 700, loss = 0.0500
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 56, Iteration 0, loss = 0.0413
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 56, Iteration 100, loss = 0.0931
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# ...
# Got 850 / 1000 correct (85.00)
#
# Epoch 331, Iteration 400, loss = 0.0086
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 331, Iteration 500, loss = 0.0131
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 331, Iteration 600, loss = 0.0126
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 331, Iteration 700, loss = 0.0104
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 332, Iteration 0, loss = 0.0117
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 332, Iteration 100, loss = 0.0125
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 332, Iteration 200, loss = 0.0187
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 332, Iteration 300, loss = 0.0158
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 332, Iteration 400, loss = 0.0176
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 332, Iteration 500, loss = 0.0185
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 332, Iteration 600, loss = 0.0106
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 332, Iteration 700, loss = 0.0145
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 333, Iteration 0, loss = 0.0102
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 333, Iteration 100, loss = 0.0153
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 333, Iteration 200, loss = 0.0093
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 333, Iteration 300, loss = 0.0119
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 333, Iteration 400, loss = 0.0117
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 333, Iteration 500, loss = 0.0127
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 333, Iteration 600, loss = 0.0072
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 333, Iteration 700, loss = 0.0146
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 334, Iteration 0, loss = 0.0116
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 334, Iteration 100, loss = 0.0182
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 334, Iteration 200, loss = 0.0104
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 334, Iteration 300, loss = 0.0095
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 334, Iteration 400, loss = 0.0083
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 334, Iteration 500, loss = 0.0132
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 334, Iteration 600, loss = 0.0118
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 334, Iteration 700, loss = 0.0140
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 335, Iteration 0, loss = 0.0196
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 335, Iteration 100, loss = 0.0138
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 335, Iteration 200, loss = 0.0138
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
# Epoch 335, Iteration 300, loss = 0.0174
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 335, Iteration 400, loss = 0.0161
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 335, Iteration 500, loss = 0.0109
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 335, Iteration 600, loss = 0.0149
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 335, Iteration 700, loss = 0.0124
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 336, Iteration 0, loss = 0.0133
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 336, Iteration 100, loss = 0.0158
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 336, Iteration 200, loss = 0.0104
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 336, Iteration 300, loss = 0.0105
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 336, Iteration 400, loss = 0.0128
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 336, Iteration 500, loss = 0.0123
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 336, Iteration 600, loss = 0.0062
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 336, Iteration 700, loss = 0.0159
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 337, Iteration 0, loss = 0.0083
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 337, Iteration 100, loss = 0.0103
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 337, Iteration 200, loss = 0.0145
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 337, Iteration 300, loss = 0.0087
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 337, Iteration 400, loss = 0.0139
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 337, Iteration 500, loss = 0.0202
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 337, Iteration 600, loss = 0.0141
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 337, Iteration 700, loss = 0.0118
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 338, Iteration 0, loss = 0.0125
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 338, Iteration 100, loss = 0.0194
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 338, Iteration 200, loss = 0.0132
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 338, Iteration 300, loss = 0.0098
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 338, Iteration 400, loss = 0.0087
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 338, Iteration 500, loss = 0.0127
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 338, Iteration 600, loss = 0.0141
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 338, Iteration 700, loss = 0.0130
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 339, Iteration 0, loss = 0.0114
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 339, Iteration 100, loss = 0.0137
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 339, Iteration 200, loss = 0.0131
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 339, Iteration 300, loss = 0.0157
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 339, Iteration 400, loss = 0.0147
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 339, Iteration 500, loss = 0.0125
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 339, Iteration 600, loss = 0.0097
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 339, Iteration 700, loss = 0.0129
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 340, Iteration 0, loss = 0.0117
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 340, Iteration 100, loss = 0.0093
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 340, Iteration 200, loss = 0.0095
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 340, Iteration 300, loss = 0.0125
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 340, Iteration 400, loss = 0.0149
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 340, Iteration 500, loss = 0.0102
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 340, Iteration 600, loss = 0.0103
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 340, Iteration 700, loss = 0.0172
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 341, Iteration 0, loss = 0.0168
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 341, Iteration 100, loss = 0.0140
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 341, Iteration 200, loss = 0.0121
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 341, Iteration 300, loss = 0.0127
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 341, Iteration 400, loss = 0.0155
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 341, Iteration 500, loss = 0.0244
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 341, Iteration 600, loss = 0.0150
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 341, Iteration 700, loss = 0.0187
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 342, Iteration 0, loss = 0.0198
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 100, loss = 0.0119
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 200, loss = 0.0140
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 300, loss = 0.0111
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 400, loss = 0.0111
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 500, loss = 0.0105
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 600, loss = 0.0142
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 342, Iteration 700, loss = 0.0138
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 343, Iteration 0, loss = 0.0084
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 343, Iteration 100, loss = 0.0119
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 343, Iteration 200, loss = 0.0072
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 343, Iteration 300, loss = 0.0141
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 343, Iteration 400, loss = 0.0121
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 343, Iteration 500, loss = 0.0167
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 343, Iteration 600, loss = 0.0093
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 343, Iteration 700, loss = 0.0057
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 344, Iteration 0, loss = 0.0136
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 344, Iteration 100, loss = 0.0085
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 344, Iteration 200, loss = 0.0203
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 344, Iteration 300, loss = 0.0140
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 344, Iteration 400, loss = 0.0093
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 344, Iteration 500, loss = 0.0112
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 344, Iteration 600, loss = 0.0137
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 344, Iteration 700, loss = 0.0108
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 345, Iteration 0, loss = 0.0165
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 345, Iteration 100, loss = 0.0164
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 345, Iteration 200, loss = 0.0154
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 345, Iteration 300, loss = 0.0148
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 345, Iteration 400, loss = 0.0088
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 345, Iteration 500, loss = 0.0129
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 345, Iteration 600, loss = 0.0134
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 345, Iteration 700, loss = 0.0114
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 346, Iteration 0, loss = 0.0101
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 346, Iteration 100, loss = 0.0113
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 346, Iteration 200, loss = 0.0194
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 346, Iteration 300, loss = 0.0074
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 346, Iteration 400, loss = 0.0137
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 346, Iteration 500, loss = 0.0147
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 346, Iteration 600, loss = 0.0135
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 346, Iteration 700, loss = 0.0144
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 347, Iteration 0, loss = 0.0218
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 347, Iteration 100, loss = 0.0113
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 347, Iteration 200, loss = 0.0197
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 347, Iteration 300, loss = 0.0072
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 347, Iteration 400, loss = 0.0138
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 347, Iteration 500, loss = 0.0164
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 347, Iteration 600, loss = 0.0099
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 347, Iteration 700, loss = 0.0146
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 348, Iteration 0, loss = 0.0139
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 348, Iteration 100, loss = 0.0102
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 348, Iteration 200, loss = 0.0126
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 348, Iteration 300, loss = 0.0165
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 348, Iteration 400, loss = 0.0115
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 348, Iteration 500, loss = 0.0152
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 348, Iteration 600, loss = 0.0117
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 348, Iteration 700, loss = 0.0195
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 0, loss = 0.0138
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 100, loss = 0.0105
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 200, loss = 0.0197
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 300, loss = 0.0127
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 400, loss = 0.0172
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 500, loss = 0.0251
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 600, loss = 0.0120
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 349, Iteration 700, loss = 0.0209
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
# Best accuracy: 0.864

# %%
PATH = "../best_model/"
model_name = "best_model_strided_cnn_c.pt"
if not os.path.exists(PATH):
    os.mkdir(PATH)
torch.save(best_model.state_dict(), PATH + model_name)
