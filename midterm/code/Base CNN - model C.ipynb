# %%
import torch
from torch.utils.data import sampler
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import os
import copy
import matplotlib.pyplot as plt

# %%
NUM_TRAIN = 49000

transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
            ])
cifar10_train = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=True,
                                           download=True, transform=transform)
loader_train = torch.utils.data.DataLoader(cifar10_train, batch_size=64,
                                      sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))
cifar10_val = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=False,
                                         download=True, transform=transform)
loader_val = torch.utils.data.DataLoader(cifar10_train, batch_size=64,
                                    sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))
cifar10_test = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=False,
                                         download=True, transform=transform)
loader_test = torch.utils.data.DataLoader(cifar10_train, batch_size=64)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_images, train_labels = iter(loader_train).next()
print("train_X:", train_images.size(), "train_y:", train_labels.size())
val_images, val_labels = iter(loader_val).next()
print("val_X:", val_images.size(), "val_y:", val_labels.size())
test_images, test_labels = iter(loader_test).next()
print("test_X:", test_images.size(), "test_y:", test_labels.size())
# Out:
# train_X: torch.Size([64, 3, 32, 32]) train_y: torch.Size([64])
# val_X: torch.Size([64, 3, 32, 32]) val_y: torch.Size([64])
# test_X: torch.Size([64, 3, 32, 32]) test_y: torch.Size([64])

# %%
USE_GPU = True

dtype = torch.float32

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
print('using device', device)
# Out:
# using device cuda

# %%
class Model(nn.Module):
    def __init__(self, in_channel, channel_1, channel_2, 
                 channel_3, channel_4, num_classes):
        """
        Default initialization:
        model = Model(in_channel=3, channel_1=96, channel_2=192, 
                 channel_3=192, channel_4=192, num_classes=10)
        """
        super().__init__()
        self.conv1_1 = nn.Conv2d(in_channel, channel_1, 3, padding=1)  #(3, 96, 3)
        self.conv1_2 = nn.Conv2d(channel_1, channel_1, 3, padding=1)   #(96, 96, 3)
        self.pool1 = nn.MaxPool2d(3, stride=2, padding=1)
        self.conv2_1 = nn.Conv2d(channel_1, channel_2, 3, padding=1)   #(96, 192, 3)
        self.conv2_2 = nn.Conv2d(channel_2, channel_2, 3, padding=1)   #(192, 192, 3)
        self.pool2 = nn.MaxPool2d(3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(channel_2, channel_3, 3)   #(192, 192, 3)
        self.conv4 = nn.Conv2d(channel_3, channel_4, 1)   #(192, 192, 1)
        self.conv5 = nn.Conv2d(channel_4, num_classes, 1) #(192, 10, 1)
        
    def forward(self, x):
        """
        x.shape: (64, 3, 32, 32)
        """
        N = x.shape[0]
        x_drop = F.dropout(x, .2)
        conv1_1_out = F.relu(self.conv1_1(x_drop))            # (64, 96, 32, 32)
        conv1_2_out = F.relu(self.conv1_2(conv1_1_out))            # (64, 96, 32, 32)
        layer1_out = self.pool1(conv1_2_out)                      # (64, 96, 16, 16)
        layer1_out_drop = F.dropout(layer1_out, .5)
        conv2_1_out = F.relu(self.conv2_1(layer1_out_drop))   # (64, 192, 16, 16)
        conv2_2_out = F.relu(self.conv2_2(conv2_1_out))   # (64, 192, 16, 16)    
        layer2_out = self.pool2(conv2_2_out)                      # (64, 192, 8, 8)
        layer2_out_drop = F.dropout(layer2_out, .5)
        layer3_out = F.relu(self.conv3(layer2_out_drop))             # (64, 192, 6, 6)
        layer4_out = F.relu(self.conv4(layer3_out))             # (64, 192, 6, 6)
        layer5_out = F.relu(self.conv5(layer4_out))             # (64, 10, 6, 6)
#         print(x.size(), conv1_1_out.size(), conv1_2_out.size(), layer1_out.size(),layer5_out.size())
        out = layer5_out.view(N, 10, -1).mean(dim=2)
        return out
        
def test_Model():
    x = torch.zeros((64, 3, 32, 32), dtype=dtype)
    model = Model(in_channel=3, channel_1=96, channel_2=192, 
                 channel_3=192, channel_4=192, num_classes=10)
    scores = model(x)
    print(scores.size())
test_Model()
# Out:
# torch.Size([64, 10])

# %%
def check_accuracy(loader, model):
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set') 
    num_correct = 0
    num_samples = 0
    model.eval()
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            scores = model(x)
            _, preds = scores.max(1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def plot(x_lst, y_lst, path, name, xlabel, ylabel):
    plt.plot(x_lst, y_lst)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    plt.savefig(path + name)

# %%
print_every = 100

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']
    
def train(model, optimizer, scheduler, weight_decay=0.001, epochs=1, best_acc=0.0):
    loss_his = []
    epoch_lst = []
    acc_his = []
    
    model = model.to(device=device)
    model = nn.DataParallel(model,device_ids=[0,1])  
    
    for e in range(epochs):
        scheduler.step()
        for step, (x, y) in enumerate(loader_train):
            model.train()
            x = x.to(device=device, dtype=dtype)
            y = y.to(device=device, dtype=torch.long)
            
            scores = model(x)
            loss = F.cross_entropy(scores, y)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step % print_every == 0:
                learning_rate = get_lr(optimizer)
                print('Epoch %d, Iteration %d, loss = %.4f' % (e, step, loss.item()))
                acc = check_accuracy(loader_val, model)
                if acc > best_acc:
                    best_acc = acc
                    best_model_wts = copy.deepcopy(model.state_dict())
                fo = open("model_c.log", "a")
                fo.write("Epoch: {}\t Step: {}\t loss: {:.4f}\t accuracy: {:.2f}\n"\
                         .format(e, step, loss.item(), acc))
                fo.close()
                print()
        epoch_lst.append(e)
        loss_his.append(loss.item())
        acc_his.append(acc)
    
    plot(epoch_lst, loss_his, path="../results figure/", name="Model C_Loss accross Epoch", 
        xlabel="epoch", ylabel="loss")
    plot(epoch_lst, acc_his, path="../results figure/", name="Model C_Accuracy accross Epoch",
        xlabel="epoch", ylabel="accuracy")
                
    print("Best accuracy:", best_acc)
    fo = open("model_c.log", "a")
    fo.write("Best accuracy: {}".format(best_acc))
    fo.close()
    model.load_state_dict(best_model_wts)
    return model

# %%
lr_lst = [0.01]

fo = open("model_c.log", "w")
fo.write("Model C Trainning log\n")
fo.close()

for learning_rate in lr_lst:
    fo = open("model_c.log", "a")
    fo.write("\nOriginal Learning rate: {}\n".format(learning_rate))
    fo.close()
    print("Learning_rate:", learning_rate)
    model = Model(in_channel=3, channel_1=96, channel_2=192, 
             channel_3=192, channel_4=192, num_classes=10) 
    optimizer = optim.SGD(model.parameters(), lr = learning_rate, momentum=0.9, weight_decay=0.001)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                                               milestones=[200, 250, 300], gamma=0.1)
    best_model = train(model, optimizer, scheduler, epochs=350, best_acc=0.0)
    print()
# Out:
# Learning_rate: 0.01
# Epoch 0, Iteration 0, loss = 2.3055
# Checking accuracy on validation set
# Got 113 / 1000 correct (11.30)
#
# Epoch 0, Iteration 100, loss = 2.3017
# Checking accuracy on validation set
# Got 128 / 1000 correct (12.80)
#
# Epoch 0, Iteration 200, loss = 2.2939
# Checking accuracy on validation set
# Got 181 / 1000 correct (18.10)
#
# Epoch 0, Iteration 300, loss = 2.2748
# Checking accuracy on validation set
# Got 154 / 1000 correct (15.40)
#
# Epoch 0, Iteration 400, loss = 2.2026
# Checking accuracy on validation set
# Got 244 / 1000 correct (24.40)
#
# Epoch 0, Iteration 500, loss = 2.1562
# Checking accuracy on validation set
# Got 222 / 1000 correct (22.20)
#
# Epoch 0, Iteration 600, loss = 2.2869
# Checking accuracy on validation set
# Got 266 / 1000 correct (26.60)
#
# Epoch 0, Iteration 700, loss = 2.2579
# Checking accuracy on validation set
# Got 239 / 1000 correct (23.90)
#
# Epoch 1, Iteration 0, loss = 2.1029
# Checking accuracy on validation set
# Got 287 / 1000 correct (28.70)
#
# Epoch 1, Iteration 100, loss = 2.2511
# Checking accuracy on validation set
# Got 272 / 1000 correct (27.20)
#
# Epoch 1, Iteration 200, loss = 1.9547
# Checking accuracy on validation set
# Got 277 / 1000 correct (27.70)
#
# Epoch 1, Iteration 300, loss = 2.0061
# Checking accuracy on validation set
# Got 280 / 1000 correct (28.00)
#
# Epoch 1, Iteration 400, loss = 2.1424
# Checking accuracy on validation set
# Got 285 / 1000 correct (28.50)
#
# Epoch 1, Iteration 500, loss = 1.9819
# Checking accuracy on validation set
# Got 321 / 1000 correct (32.10)
#
# Epoch 1, Iteration 600, loss = 2.0018
# Checking accuracy on validation set
# Got 322 / 1000 correct (32.20)
#
# Epoch 1, Iteration 700, loss = 1.8732
# Checking accuracy on validation set
# Got 364 / 1000 correct (36.40)
#
# Epoch 2, Iteration 0, loss = 1.8157
# Checking accuracy on validation set
# Got 361 / 1000 correct (36.10)
#
# Epoch 2, Iteration 100, loss = 1.6158
# Checking accuracy on validation set
# Got 388 / 1000 correct (38.80)
#
# Epoch 2, Iteration 200, loss = 1.7282
# Checking accuracy on validation set
# Got 413 / 1000 correct (41.30)
#
# Epoch 2, Iteration 300, loss = 1.6044
# Checking accuracy on validation set
# Got 397 / 1000 correct (39.70)
#
# Epoch 2, Iteration 400, loss = 1.6405
# Checking accuracy on validation set
# Got 440 / 1000 correct (44.00)
#
# Epoch 2, Iteration 500, loss = 1.6141
# Checking accuracy on validation set
# Got 435 / 1000 correct (43.50)
#
# Epoch 2, Iteration 600, loss = 1.5738
# Checking accuracy on validation set
# Got 403 / 1000 correct (40.30)
#
# Epoch 2, Iteration 700, loss = 1.6316
# Checking accuracy on validation set
# Got 432 / 1000 correct (43.20)
#
# Epoch 3, Iteration 0, loss = 1.3671
# Checking accuracy on validation set
# Got 428 / 1000 correct (42.80)
#
# Epoch 3, Iteration 100, loss = 1.6071
# Checking accuracy on validation set
# Got 475 / 1000 correct (47.50)
#
# Epoch 3, Iteration 200, loss = 1.3904
# Checking accuracy on validation set
# Got 479 / 1000 correct (47.90)
#
# Epoch 3, Iteration 300, loss = 1.3457
# Checking accuracy on validation set
# Got 512 / 1000 correct (51.20)
#
# Epoch 3, Iteration 400, loss = 1.5490
# Checking accuracy on validation set
# Got 524 / 1000 correct (52.40)
#
# Epoch 3, Iteration 500, loss = 1.3511
# Checking accuracy on validation set
# Got 527 / 1000 correct (52.70)
#
# Epoch 3, Iteration 600, loss = 1.5003
# Checking accuracy on validation set
# Got 535 / 1000 correct (53.50)
#
# Epoch 3, Iteration 700, loss = 1.1863
# Checking accuracy on validation set
# Got 550 / 1000 correct (55.00)
#
# Epoch 4, Iteration 0, loss = 1.2002
# Checking accuracy on validation set
# Got 550 / 1000 correct (55.00)
#
# Epoch 4, Iteration 100, loss = 1.3457
# Checking accuracy on validation set
# Got 520 / 1000 correct (52.00)
#
# Epoch 4, Iteration 200, loss = 1.2778
# Checking accuracy on validation set
# Got 503 / 1000 correct (50.30)
#
# Epoch 4, Iteration 300, loss = 1.4103
# Checking accuracy on validation set
# Got 503 / 1000 correct (50.30)
#
# Epoch 4, Iteration 400, loss = 1.2387
# Checking accuracy on validation set
# Got 604 / 1000 correct (60.40)
#
# Epoch 4, Iteration 500, loss = 1.2418
# Checking accuracy on validation set
# Got 588 / 1000 correct (58.80)
#
# Epoch 4, Iteration 600, loss = 1.2310
# Checking accuracy on validation set
# Got 595 / 1000 correct (59.50)
#
# Epoch 4, Iteration 700, loss = 0.8710
# Checking accuracy on validation set
# Got 623 / 1000 correct (62.30)
#
# Epoch 5, Iteration 0, loss = 0.9970
# Checking accuracy on validation set
# Got 626 / 1000 correct (62.60)
#
# Epoch 5, Iteration 100, loss = 0.9959
# Checking accuracy on validation set
# Got 662 / 1000 correct (66.20)
#
# Epoch 5, Iteration 200, loss = 0.9244
# Checking accuracy on validation set
# Got 628 / 1000 correct (62.80)
#
# Epoch 5, Iteration 300, loss = 0.9390
# Checking accuracy on validation set
# Got 658 / 1000 correct (65.80)
#
# Epoch 5, Iteration 400, loss = 0.8671
# Checking accuracy on validation set
# Got 660 / 1000 correct (66.00)
#
# Epoch 5, Iteration 500, loss = 0.6771
# Checking accuracy on validation set
# Got 687 / 1000 correct (68.70)
#
# Epoch 5, Iteration 600, loss = 0.7939
# Checking accuracy on validation set
# Got 652 / 1000 correct (65.20)
#
# Epoch 5, Iteration 700, loss = 0.7260
# Checking accuracy on validation set
# Got 687 / 1000 correct (68.70)
#
# Epoch 6, Iteration 0, loss = 1.0149
# Checking accuracy on validation set
# Got 635 / 1000 correct (63.50)
#
# Epoch 6, Iteration 100, loss = 1.0916
# Checking accuracy on validation set
# Got 661 / 1000 correct (66.10)
#
# Epoch 6, Iteration 200, loss = 0.8195
# Checking accuracy on validation set
# Got 699 / 1000 correct (69.90)
#
# Epoch 6, Iteration 300, loss = 0.8176
# Checking accuracy on validation set
# Got 720 / 1000 correct (72.00)
#
# Epoch 6, Iteration 400, loss = 0.7553
# Checking accuracy on validation set
# Got 683 / 1000 correct (68.30)
#
# Epoch 6, Iteration 500, loss = 0.6370
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
#
# Epoch 6, Iteration 600, loss = 0.9905
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
#
# Epoch 6, Iteration 700, loss = 0.8362
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Epoch 7, Iteration 0, loss = 0.5626
# Checking accuracy on validation set
# Got 724 / 1000 correct (72.40)
#
# Epoch 7, Iteration 100, loss = 0.8278
# Checking accuracy on validation set
# Got 729 / 1000 correct (72.90)
#
# Epoch 7, Iteration 200, loss = 0.8242
# Checking accuracy on validation set
# Got 729 / 1000 correct (72.90)
#
# Epoch 7, Iteration 300, loss = 0.8036
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
#
# Epoch 7, Iteration 400, loss = 0.7294
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
#
# Epoch 7, Iteration 500, loss = 0.6626
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Epoch 7, Iteration 600, loss = 0.9735
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
#
# Epoch 7, Iteration 700, loss = 0.4656
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
#
# Epoch 8, Iteration 0, loss = 0.5708
# Checking accuracy on validation set
# Got 761 / 1000 correct (76.10)
#
# Epoch 8, Iteration 100, loss = 0.5648
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
#
# Epoch 8, Iteration 200, loss = 0.7294
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
#
# Epoch 8, Iteration 300, loss = 0.6829
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
#
# Epoch 8, Iteration 400, loss = 1.0812
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
#
# Epoch 8, Iteration 500, loss = 0.8756
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
#
# Epoch 8, Iteration 600, loss = 0.4982
# Checking accuracy on validation set
# Got 764 / 1000 correct (76.40)
#
# Epoch 8, Iteration 700, loss = 0.5945
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
#
# Epoch 9, Iteration 0, loss = 0.4466
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
#
# Epoch 9, Iteration 100, loss = 0.5462
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 9, Iteration 200, loss = 0.6569
# Checking accuracy on validation set
# Got 749 / 1000 correct (74.90)
#
# Epoch 9, Iteration 300, loss = 0.5889
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
#
# Epoch 9, Iteration 400, loss = 0.6167
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
#
# Epoch 9, Iteration 500, loss = 0.5244
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
#
# Epoch 9, Iteration 600, loss = 0.7094
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
#
# Epoch 9, Iteration 700, loss = 0.6898
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 10, Iteration 0, loss = 0.5438
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
#
# Epoch 10, Iteration 100, loss = 0.6737
# Checking accuracy on validation set
# Got 761 / 1000 correct (76.10)
#
# Epoch 10, Iteration 200, loss = 0.6044
# Checking accuracy on validation set
# Got 756 / 1000 correct (75.60)
#
# Epoch 10, Iteration 300, loss = 0.6426
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Epoch 10, Iteration 400, loss = 0.4796
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
#
# Epoch 10, Iteration 500, loss = 0.4813
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
#
# Epoch 10, Iteration 600, loss = 0.3404
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 10, Iteration 700, loss = 0.5325
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 11, Iteration 0, loss = 0.5679
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
#
# Epoch 11, Iteration 100, loss = 0.4186
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 11, Iteration 200, loss = 0.3071
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 11, Iteration 300, loss = 0.4751
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
#
# Epoch 11, Iteration 400, loss = 0.3822
# Checking accuracy on validation set
# Got 760 / 1000 correct (76.00)
#
# Epoch 11, Iteration 500, loss = 0.6415
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Epoch 11, Iteration 600, loss = 0.5042
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 11, Iteration 700, loss = 0.3235
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Epoch 12, Iteration 0, loss = 0.4081
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 12, Iteration 100, loss = 0.5718
# Checking accuracy on validation set
# Got 764 / 1000 correct (76.40)
#
# Epoch 12, Iteration 200, loss = 0.5386
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Epoch 12, Iteration 300, loss = 0.5019
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 12, Iteration 400, loss = 0.4002
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 12, Iteration 500, loss = 0.4122
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 12, Iteration 600, loss = 0.3210
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 12, Iteration 700, loss = 0.2787
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 13, Iteration 0, loss = 0.7289
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 13, Iteration 100, loss = 0.4409
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
#
# Epoch 13, Iteration 200, loss = 0.4805
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 13, Iteration 300, loss = 0.5770
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 13, Iteration 400, loss = 0.6754
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 13, Iteration 500, loss = 0.4122
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 13, Iteration 600, loss = 0.4718
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 13, Iteration 700, loss = 0.1891
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 14, Iteration 0, loss = 0.4820
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 14, Iteration 100, loss = 0.4676
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 14, Iteration 200, loss = 0.3939
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 14, Iteration 300, loss = 0.2952
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 14, Iteration 400, loss = 0.3580
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 14, Iteration 500, loss = 0.3269
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 14, Iteration 600, loss = 0.4313
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 14, Iteration 700, loss = 0.3263
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 15, Iteration 0, loss = 0.4202
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 15, Iteration 100, loss = 0.3289
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 15, Iteration 200, loss = 0.2979
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 15, Iteration 300, loss = 0.3022
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 15, Iteration 400, loss = 0.5126
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 15, Iteration 500, loss = 0.4026
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 15, Iteration 600, loss = 0.3379
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 15, Iteration 700, loss = 0.4431
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 16, Iteration 0, loss = 0.2886
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 16, Iteration 100, loss = 0.3695
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 16, Iteration 200, loss = 0.2767
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 16, Iteration 300, loss = 0.2312
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 16, Iteration 400, loss = 0.5411
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 16, Iteration 500, loss = 0.2338
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 16, Iteration 600, loss = 0.2202
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 16, Iteration 700, loss = 0.2348
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 17, Iteration 0, loss = 0.2722
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 17, Iteration 100, loss = 0.2785
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 17, Iteration 200, loss = 0.2509
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Epoch 17, Iteration 300, loss = 0.3676
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 17, Iteration 400, loss = 0.2908
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 17, Iteration 500, loss = 0.2753
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 17, Iteration 600, loss = 0.2449
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 17, Iteration 700, loss = 0.2438
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 18, Iteration 0, loss = 0.1935
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 18, Iteration 100, loss = 0.1520
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 18, Iteration 200, loss = 0.1995
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
#
# Epoch 18, Iteration 300, loss = 0.2514
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 18, Iteration 400, loss = 0.4220
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 18, Iteration 500, loss = 0.3265
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 18, Iteration 600, loss = 0.2479
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 18, Iteration 700, loss = 0.1934
# Checking accuracy on validation set
# Got 856 / 1000 correct (85.60)
#
# Epoch 19, Iteration 0, loss = 0.2173
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 19, Iteration 100, loss = 0.2749
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 19, Iteration 200, loss = 0.1881
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 19, Iteration 300, loss = 0.3443
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 19, Iteration 400, loss = 0.2310
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 19, Iteration 500, loss = 0.2658
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 19, Iteration 600, loss = 0.3575
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 19, Iteration 700, loss = 0.2512
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 20, Iteration 0, loss = 0.1488
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 20, Iteration 100, loss = 0.1507
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 20, Iteration 200, loss = 0.1856
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 20, Iteration 300, loss = 0.2304
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 20, Iteration 400, loss = 0.2826
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 20, Iteration 500, loss = 0.4049
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 20, Iteration 600, loss = 0.2621
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 20, Iteration 700, loss = 0.3005
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 21, Iteration 0, loss = 0.2244
# Checking accuracy on validation set
# Got 864 / 1000 correct (86.40)
#
# Epoch 21, Iteration 100, loss = 0.2255
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 21, Iteration 200, loss = 0.1361
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 21, Iteration 300, loss = 0.1304
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 21, Iteration 400, loss = 0.1900
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 21, Iteration 500, loss = 0.2738
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 21, Iteration 600, loss = 0.2692
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 21, Iteration 700, loss = 0.3035
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Epoch 22, Iteration 0, loss = 0.1682
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 22, Iteration 100, loss = 0.2555
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 22, Iteration 200, loss = 0.1102
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 22, Iteration 300, loss = 0.1681
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 22, Iteration 400, loss = 0.2707
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 22, Iteration 500, loss = 0.2300
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 22, Iteration 600, loss = 0.2140
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 22, Iteration 700, loss = 0.4843
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 23, Iteration 0, loss = 0.1500
# Checking accuracy on validation set
# Got 853 / 1000 correct (85.30)
#
# Epoch 23, Iteration 100, loss = 0.0978
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 23, Iteration 200, loss = 0.1735
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 23, Iteration 300, loss = 0.0718
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 23, Iteration 400, loss = 0.1546
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 23, Iteration 500, loss = 0.0489
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 23, Iteration 600, loss = 0.0777
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 23, Iteration 700, loss = 0.2560
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 24, Iteration 0, loss = 0.1449
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 24, Iteration 100, loss = 0.1714
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 24, Iteration 200, loss = 0.1575
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 24, Iteration 300, loss = 0.3946
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 24, Iteration 400, loss = 0.1706
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 24, Iteration 500, loss = 0.1499
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 24, Iteration 600, loss = 0.1066
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 24, Iteration 700, loss = 0.1145
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 25, Iteration 0, loss = 0.3191
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 25, Iteration 100, loss = 0.1265
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 25, Iteration 200, loss = 0.0868
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 25, Iteration 300, loss = 0.3018
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 25, Iteration 400, loss = 0.2773
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 25, Iteration 500, loss = 0.1128
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 25, Iteration 600, loss = 0.2252
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 25, Iteration 700, loss = 0.2552
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 26, Iteration 0, loss = 0.1446
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 26, Iteration 100, loss = 0.0392
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 26, Iteration 200, loss = 0.1539
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 26, Iteration 300, loss = 0.1745
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 26, Iteration 400, loss = 0.1161
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 26, Iteration 500, loss = 0.1787
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 26, Iteration 600, loss = 0.1316
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 26, Iteration 700, loss = 0.2223
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 27, Iteration 0, loss = 0.0710
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 27, Iteration 100, loss = 0.1685
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 27, Iteration 200, loss = 0.1154
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 27, Iteration 300, loss = 0.0715
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 27, Iteration 400, loss = 0.0869
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 27, Iteration 500, loss = 0.1962
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 27, Iteration 600, loss = 0.0936
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 27, Iteration 700, loss = 0.1520
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 28, Iteration 0, loss = 0.1736
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 28, Iteration 100, loss = 0.1556
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 28, Iteration 200, loss = 0.0152
# Checking accuracy on validation set
# Got 856 / 1000 correct (85.60)
#
# Epoch 28, Iteration 300, loss = 0.0935
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 28, Iteration 400, loss = 0.0475
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 28, Iteration 500, loss = 0.1083
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 28, Iteration 600, loss = 0.2294
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 28, Iteration 700, loss = 0.2535
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 29, Iteration 0, loss = 0.0865
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 29, Iteration 100, loss = 0.1014
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 29, Iteration 200, loss = 0.0910
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 29, Iteration 300, loss = 0.0499
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Epoch 29, Iteration 400, loss = 0.1940
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 29, Iteration 500, loss = 0.1850
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 29, Iteration 600, loss = 0.1085
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 29, Iteration 700, loss = 0.2585
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 30, Iteration 0, loss = 0.1294
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 30, Iteration 100, loss = 0.0942
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 30, Iteration 200, loss = 0.2355
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 30, Iteration 300, loss = 0.0484
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 30, Iteration 400, loss = 0.0735
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 30, Iteration 500, loss = 0.0747
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 30, Iteration 600, loss = 0.0663
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 30, Iteration 700, loss = 0.2317
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 31, Iteration 0, loss = 0.1445
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 31, Iteration 100, loss = 0.1235
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 31, Iteration 200, loss = 0.0852
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 31, Iteration 300, loss = 0.0856
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 31, Iteration 400, loss = 0.1813
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 31, Iteration 500, loss = 0.0839
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 31, Iteration 600, loss = 0.1439
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 31, Iteration 700, loss = 0.0734
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 32, Iteration 0, loss = 0.0183
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 32, Iteration 100, loss = 0.0769
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 32, Iteration 200, loss = 0.0799
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Epoch 32, Iteration 300, loss = 0.1246
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 32, Iteration 400, loss = 0.2806
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 32, Iteration 500, loss = 0.1262
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 32, Iteration 600, loss = 0.0523
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 32, Iteration 700, loss = 0.1482
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 33, Iteration 0, loss = 0.0332
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 33, Iteration 100, loss = 0.0172
# Checking accuracy on validation set
# Got 854 / 1000 correct (85.40)
#
# Epoch 33, Iteration 200, loss = 0.1084
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 33, Iteration 300, loss = 0.1084
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 33, Iteration 400, loss = 0.1455
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Epoch 33, Iteration 500, loss = 0.1069
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 33, Iteration 600, loss = 0.1543
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 33, Iteration 700, loss = 0.1094
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 34, Iteration 0, loss = 0.0967
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 34, Iteration 100, loss = 0.1526
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 34, Iteration 200, loss = 0.0696
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 34, Iteration 300, loss = 0.1455
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 34, Iteration 400, loss = 0.2620
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 34, Iteration 500, loss = 0.1616
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 34, Iteration 600, loss = 0.0617
# Checking accuracy on validation set
# Got 854 / 1000 correct (85.40)
#
# Epoch 34, Iteration 700, loss = 0.0939
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 35, Iteration 0, loss = 0.1490
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 35, Iteration 100, loss = 0.0805
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 35, Iteration 200, loss = 0.0900
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 35, Iteration 300, loss = 0.0199
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 35, Iteration 400, loss = 0.0655
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 35, Iteration 500, loss = 0.1184
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 35, Iteration 600, loss = 0.2173
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 35, Iteration 700, loss = 0.1221
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 36, Iteration 0, loss = 0.0951
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 36, Iteration 100, loss = 0.0478
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 36, Iteration 200, loss = 0.1030
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 36, Iteration 300, loss = 0.1837
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 36, Iteration 400, loss = 0.0655
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 36, Iteration 500, loss = 0.1629
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 36, Iteration 600, loss = 0.1222
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 36, Iteration 700, loss = 0.0807
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 37, Iteration 0, loss = 0.0528
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 37, Iteration 100, loss = 0.0798
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 37, Iteration 200, loss = 0.0785
# Checking accuracy on validation set
# Got 858 / 1000 correct (85.80)
#
# Epoch 37, Iteration 300, loss = 0.0911
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 37, Iteration 400, loss = 0.0737
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 37, Iteration 500, loss = 0.0497
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 37, Iteration 600, loss = 0.2342
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 37, Iteration 700, loss = 0.2547
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 38, Iteration 0, loss = 0.0828
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 38, Iteration 100, loss = 0.1168
# Checking accuracy on validation set
# Got 870 / 1000 correct (87.00)
#
# Epoch 38, Iteration 200, loss = 0.5257
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 38, Iteration 300, loss = 0.1144
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 38, Iteration 400, loss = 0.0337
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 38, Iteration 500, loss = 0.0246
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 38, Iteration 600, loss = 0.1179
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 38, Iteration 700, loss = 0.2156
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 39, Iteration 0, loss = 0.1711
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 39, Iteration 100, loss = 0.0459
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 39, Iteration 200, loss = 0.0771
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 39, Iteration 300, loss = 0.0437
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Epoch 39, Iteration 400, loss = 0.0516
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 39, Iteration 500, loss = 0.1643
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 39, Iteration 600, loss = 0.0285
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 39, Iteration 700, loss = 0.1203
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 40, Iteration 0, loss = 0.1484
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 40, Iteration 100, loss = 0.0628
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 40, Iteration 200, loss = 0.0987
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 40, Iteration 300, loss = 0.0369
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 40, Iteration 400, loss = 0.0803
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 40, Iteration 500, loss = 0.1138
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 40, Iteration 600, loss = 0.0267
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 40, Iteration 700, loss = 0.0384
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 41, Iteration 0, loss = 0.0821
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 41, Iteration 100, loss = 0.0486
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 41, Iteration 200, loss = 0.1600
# Checking accuracy on validation set
# Got 856 / 1000 correct (85.60)
#
# Epoch 41, Iteration 300, loss = 0.1942
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 41, Iteration 400, loss = 0.0942
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 41, Iteration 500, loss = 0.1184
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Epoch 41, Iteration 600, loss = 0.0723
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 41, Iteration 700, loss = 0.1075
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 42, Iteration 0, loss = 0.1984
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 42, Iteration 100, loss = 0.0885
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 42, Iteration 200, loss = 0.1381
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 42, Iteration 300, loss = 0.1082
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 42, Iteration 400, loss = 0.0855
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 42, Iteration 500, loss = 0.1171
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 42, Iteration 600, loss = 0.0539
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 42, Iteration 700, loss = 0.0603
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 43, Iteration 0, loss = 0.0432
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 43, Iteration 100, loss = 0.0589
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 43, Iteration 200, loss = 0.0509
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 43, Iteration 300, loss = 0.0852
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 43, Iteration 400, loss = 0.1034
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 43, Iteration 500, loss = 0.1056
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 43, Iteration 600, loss = 0.0676
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 43, Iteration 700, loss = 0.2325
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 44, Iteration 0, loss = 0.1980
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 44, Iteration 100, loss = 0.0354
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 44, Iteration 200, loss = 0.0399
# Checking accuracy on validation set
# Got 856 / 1000 correct (85.60)
#
# Epoch 44, Iteration 300, loss = 0.1466
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 44, Iteration 400, loss = 0.0451
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 44, Iteration 500, loss = 0.0738
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 44, Iteration 600, loss = 0.0552
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 44, Iteration 700, loss = 0.1142
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 45, Iteration 0, loss = 0.0888
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 45, Iteration 100, loss = 0.0527
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 45, Iteration 200, loss = 0.0255
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 45, Iteration 300, loss = 0.0437
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 45, Iteration 400, loss = 0.1430
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 45, Iteration 500, loss = 0.0654
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 45, Iteration 600, loss = 0.1290
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 45, Iteration 700, loss = 0.1434
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 46, Iteration 0, loss = 0.0914
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 46, Iteration 100, loss = 0.1739
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 46, Iteration 200, loss = 0.1557
# Checking accuracy on validation set
# Got 860 / 1000 correct (86.00)
#
# Epoch 46, Iteration 300, loss = 0.0673
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 46, Iteration 400, loss = 0.0852
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 46, Iteration 500, loss = 0.1202
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 46, Iteration 600, loss = 0.1306
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 46, Iteration 700, loss = 0.1719
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 47, Iteration 0, loss = 0.0908
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 47, Iteration 100, loss = 0.1036
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 47, Iteration 200, loss = 0.0796
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 47, Iteration 300, loss = 0.0151
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 47, Iteration 400, loss = 0.0809
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 47, Iteration 500, loss = 0.2072
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 47, Iteration 600, loss = 0.1321
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 47, Iteration 700, loss = 0.0678
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 48, Iteration 0, loss = 0.1232
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 48, Iteration 100, loss = 0.0310
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Epoch 48, Iteration 200, loss = 0.0712
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 48, Iteration 300, loss = 0.0768
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 48, Iteration 400, loss = 0.1117
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 48, Iteration 500, loss = 0.0634
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 48, Iteration 600, loss = 0.0524
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 48, Iteration 700, loss = 0.1132
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 49, Iteration 0, loss = 0.0486
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 49, Iteration 100, loss = 0.0607
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 49, Iteration 200, loss = 0.1369
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 49, Iteration 300, loss = 0.0764
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 49, Iteration 400, loss = 0.0479
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 49, Iteration 500, loss = 0.0952
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 49, Iteration 600, loss = 0.1022
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 49, Iteration 700, loss = 0.0770
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 50, Iteration 0, loss = 0.1234
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 50, Iteration 100, loss = 0.0326
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Epoch 50, Iteration 200, loss = 0.1613
# Checking accuracy on validation set
# Got 848 / 1000 correct (84.80)
#
# Epoch 50, Iteration 300, loss = 0.0741
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 50, Iteration 400, loss = 0.0651
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 50, Iteration 500, loss = 0.1519
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 50, Iteration 600, loss = 0.1409
# Checking accuracy on validation set
# Got 865 / 1000 correct (86.50)
#
# Epoch 50, Iteration 700, loss = 0.0553
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 51, Iteration 0, loss = 0.1189
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 51, Iteration 100, loss = 0.1428
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 51, Iteration 200, loss = 0.1032
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 51, Iteration 300, loss = 0.0333
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Epoch 51, Iteration 400, loss = 0.1043
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Epoch 51, Iteration 500, loss = 0.1009
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 51, Iteration 600, loss = 0.1584
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 51, Iteration 700, loss = 0.0560
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 52, Iteration 0, loss = 0.0251
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 52, Iteration 100, loss = 0.0840
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 52, Iteration 200, loss = 0.1129
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 52, Iteration 300, loss = 0.0627
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 52, Iteration 400, loss = 0.0972
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 52, Iteration 500, loss = 0.0794
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Epoch 52, Iteration 600, loss = 0.1267
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 52, Iteration 700, loss = 0.0354
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 53, Iteration 0, loss = 0.0629
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 53, Iteration 100, loss = 0.0629
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 53, Iteration 200, loss = 0.0689
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 53, Iteration 300, loss = 0.0608
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 53, Iteration 400, loss = 0.1605
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Epoch 53, Iteration 500, loss = 0.1268
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 53, Iteration 600, loss = 0.1423
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 53, Iteration 700, loss = 0.0327
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 54, Iteration 0, loss = 0.2134
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 54, Iteration 100, loss = 0.1276
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 54, Iteration 200, loss = 0.0438
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 54, Iteration 300, loss = 0.0568
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 54, Iteration 400, loss = 0.1787
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Epoch 54, Iteration 500, loss = 0.0874
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 54, Iteration 600, loss = 0.0911
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 54, Iteration 700, loss = 0.2409
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 55, Iteration 0, loss = 0.0922
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Epoch 55, Iteration 100, loss = 0.0080
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Epoch 55, Iteration 200, loss = 0.1351
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 55, Iteration 300, loss = 0.1230
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 55, Iteration 400, loss = 0.1910
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Epoch 55, Iteration 500, loss = 0.0868
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Epoch 55, Iteration 600, loss = 0.2744
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 55, Iteration 700, loss = 0.0991
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 56, Iteration 0, loss = 0.1011
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 56, Iteration 100, loss = 0.0352
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# ...
# Got 870 / 1000 correct (87.00)
#
# Epoch 331, Iteration 400, loss = 0.0120
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 331, Iteration 500, loss = 0.0101
# Checking accuracy on validation set
# Got 870 / 1000 correct (87.00)
#
# Epoch 331, Iteration 600, loss = 0.0083
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 331, Iteration 700, loss = 0.0123
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 332, Iteration 0, loss = 0.0070
# Checking accuracy on validation set
# Got 873 / 1000 correct (87.30)
#
# Epoch 332, Iteration 100, loss = 0.0067
# Checking accuracy on validation set
# Got 873 / 1000 correct (87.30)
#
# Epoch 332, Iteration 200, loss = 0.0116
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 332, Iteration 300, loss = 0.0079
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 332, Iteration 400, loss = 0.0061
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 332, Iteration 500, loss = 0.0091
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 332, Iteration 600, loss = 0.0109
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 332, Iteration 700, loss = 0.0076
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 333, Iteration 0, loss = 0.0068
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 333, Iteration 100, loss = 0.0058
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 333, Iteration 200, loss = 0.0072
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 333, Iteration 300, loss = 0.0099
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 333, Iteration 400, loss = 0.0033
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 333, Iteration 500, loss = 0.0091
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 333, Iteration 600, loss = 0.0119
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 333, Iteration 700, loss = 0.0122
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 334, Iteration 0, loss = 0.0084
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 334, Iteration 100, loss = 0.0110
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 334, Iteration 200, loss = 0.0070
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 334, Iteration 300, loss = 0.0091
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 334, Iteration 400, loss = 0.0109
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 334, Iteration 500, loss = 0.0092
# Checking accuracy on validation set
# Got 873 / 1000 correct (87.30)
#
# Epoch 334, Iteration 600, loss = 0.0085
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 334, Iteration 700, loss = 0.0058
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 335, Iteration 0, loss = 0.0075
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 335, Iteration 100, loss = 0.0132
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 335, Iteration 200, loss = 0.0074
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
# Epoch 335, Iteration 300, loss = 0.0125
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 335, Iteration 400, loss = 0.0108
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 335, Iteration 500, loss = 0.0060
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 335, Iteration 600, loss = 0.0075
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 335, Iteration 700, loss = 0.0073
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 336, Iteration 0, loss = 0.0074
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 336, Iteration 100, loss = 0.0079
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 336, Iteration 200, loss = 0.0110
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 336, Iteration 300, loss = 0.0091
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 336, Iteration 400, loss = 0.0100
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 336, Iteration 500, loss = 0.0142
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 336, Iteration 600, loss = 0.0107
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 336, Iteration 700, loss = 0.0077
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 337, Iteration 0, loss = 0.0091
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 337, Iteration 100, loss = 0.0075
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 337, Iteration 200, loss = 0.0096
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 337, Iteration 300, loss = 0.0080
# Checking accuracy on validation set
# Got 870 / 1000 correct (87.00)
#
# Epoch 337, Iteration 400, loss = 0.0046
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 337, Iteration 500, loss = 0.0045
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 337, Iteration 600, loss = 0.0104
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 337, Iteration 700, loss = 0.0087
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 338, Iteration 0, loss = 0.0062
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 338, Iteration 100, loss = 0.0071
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 338, Iteration 200, loss = 0.0090
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 338, Iteration 300, loss = 0.0065
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 338, Iteration 400, loss = 0.0077
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 338, Iteration 500, loss = 0.0074
# Checking accuracy on validation set
# Got 870 / 1000 correct (87.00)
#
# Epoch 338, Iteration 600, loss = 0.0079
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 338, Iteration 700, loss = 0.0095
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 339, Iteration 0, loss = 0.0073
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 339, Iteration 100, loss = 0.0105
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 339, Iteration 200, loss = 0.0092
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 339, Iteration 300, loss = 0.0079
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 339, Iteration 400, loss = 0.0078
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 339, Iteration 500, loss = 0.0113
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 339, Iteration 600, loss = 0.0102
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 339, Iteration 700, loss = 0.0087
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 340, Iteration 0, loss = 0.0075
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 340, Iteration 100, loss = 0.0062
# Checking accuracy on validation set
# Got 870 / 1000 correct (87.00)
#
# Epoch 340, Iteration 200, loss = 0.0067
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 340, Iteration 300, loss = 0.0066
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 340, Iteration 400, loss = 0.0090
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 340, Iteration 500, loss = 0.0042
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 340, Iteration 600, loss = 0.0056
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 340, Iteration 700, loss = 0.0132
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 341, Iteration 0, loss = 0.0071
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 341, Iteration 100, loss = 0.0072
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 341, Iteration 200, loss = 0.0094
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 341, Iteration 300, loss = 0.0063
# Checking accuracy on validation set
# Got 870 / 1000 correct (87.00)
#
# Epoch 341, Iteration 400, loss = 0.0117
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 341, Iteration 500, loss = 0.0077
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 341, Iteration 600, loss = 0.0061
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 341, Iteration 700, loss = 0.0088
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 342, Iteration 0, loss = 0.0071
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 342, Iteration 100, loss = 0.0095
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 342, Iteration 200, loss = 0.0049
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 342, Iteration 300, loss = 0.0097
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 342, Iteration 400, loss = 0.0104
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 342, Iteration 500, loss = 0.0066
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 342, Iteration 600, loss = 0.0088
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 342, Iteration 700, loss = 0.0084
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 343, Iteration 0, loss = 0.0114
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 343, Iteration 100, loss = 0.0084
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 343, Iteration 200, loss = 0.0075
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 343, Iteration 300, loss = 0.0110
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 343, Iteration 400, loss = 0.0079
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 343, Iteration 500, loss = 0.0110
# Checking accuracy on validation set
# Got 870 / 1000 correct (87.00)
#
# Epoch 343, Iteration 600, loss = 0.0041
# Checking accuracy on validation set
# Got 870 / 1000 correct (87.00)
#
# Epoch 343, Iteration 700, loss = 0.0126
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 344, Iteration 0, loss = 0.0110
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 344, Iteration 100, loss = 0.0121
# Checking accuracy on validation set
# Got 874 / 1000 correct (87.40)
#
# Epoch 344, Iteration 200, loss = 0.0094
# Checking accuracy on validation set
# Got 875 / 1000 correct (87.50)
#
# Epoch 344, Iteration 300, loss = 0.0095
# Checking accuracy on validation set
# Got 873 / 1000 correct (87.30)
#
# Epoch 344, Iteration 400, loss = 0.0095
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 344, Iteration 500, loss = 0.0099
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 344, Iteration 600, loss = 0.0059
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 344, Iteration 700, loss = 0.0102
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 345, Iteration 0, loss = 0.0095
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 345, Iteration 100, loss = 0.0090
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 345, Iteration 200, loss = 0.0094
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 345, Iteration 300, loss = 0.0083
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 345, Iteration 400, loss = 0.0091
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 345, Iteration 500, loss = 0.0099
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 345, Iteration 600, loss = 0.0078
# Checking accuracy on validation set
# Got 870 / 1000 correct (87.00)
#
# Epoch 345, Iteration 700, loss = 0.0079
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 346, Iteration 0, loss = 0.0058
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 346, Iteration 100, loss = 0.0089
# Checking accuracy on validation set
# Got 873 / 1000 correct (87.30)
#
# Epoch 346, Iteration 200, loss = 0.0117
# Checking accuracy on validation set
# Got 873 / 1000 correct (87.30)
#
# Epoch 346, Iteration 300, loss = 0.0162
# Checking accuracy on validation set
# Got 873 / 1000 correct (87.30)
#
# Epoch 346, Iteration 400, loss = 0.0050
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 346, Iteration 500, loss = 0.0124
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 346, Iteration 600, loss = 0.0126
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 346, Iteration 700, loss = 0.0066
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 347, Iteration 0, loss = 0.0065
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 347, Iteration 100, loss = 0.0066
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 347, Iteration 200, loss = 0.0126
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 347, Iteration 300, loss = 0.0055
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 347, Iteration 400, loss = 0.0078
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 347, Iteration 500, loss = 0.0064
# Checking accuracy on validation set
# Got 870 / 1000 correct (87.00)
#
# Epoch 347, Iteration 600, loss = 0.0101
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 347, Iteration 700, loss = 0.0076
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 348, Iteration 0, loss = 0.0070
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 348, Iteration 100, loss = 0.0062
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 348, Iteration 200, loss = 0.0072
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 348, Iteration 300, loss = 0.0099
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 348, Iteration 400, loss = 0.0091
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 348, Iteration 500, loss = 0.0065
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 348, Iteration 600, loss = 0.0053
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 348, Iteration 700, loss = 0.0111
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 349, Iteration 0, loss = 0.0064
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 349, Iteration 100, loss = 0.0057
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 349, Iteration 200, loss = 0.0075
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 349, Iteration 300, loss = 0.0076
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 349, Iteration 400, loss = 0.0088
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 349, Iteration 500, loss = 0.0098
# Checking accuracy on validation set
# Got 872 / 1000 correct (87.20)
#
# Epoch 349, Iteration 600, loss = 0.0066
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
#
# Epoch 349, Iteration 700, loss = 0.0082
# Checking accuracy on validation set
# Got 871 / 1000 correct (87.10)
# Best accuracy: 0.877

# %%
PATH = "../best_model/"
model_name = "best_model_c.pt"
if not os.path.exists(PATH):
    os.mkdir(PATH)
torch.save(best_model.state_dict(), PATH + model_name)
