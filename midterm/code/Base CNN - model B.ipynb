# %%
import torch
from torch.utils.data import sampler
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import os
import copy
import matplotlib.pyplot as plt

# %%
NUM_TRAIN = 49000

transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
            ])
cifar10_train = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=True,
                                           download=True, transform=transform)
loader_train = torch.utils.data.DataLoader(cifar10_train, batch_size=64,
                                      sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))
cifar10_val = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=False,
                                         download=True, transform=transform)
loader_val = torch.utils.data.DataLoader(cifar10_train, batch_size=64,
                                    sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))
cifar10_test = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=False,
                                         download=True, transform=transform)
loader_test = torch.utils.data.DataLoader(cifar10_train, batch_size=64)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_images, train_labels = iter(loader_train).next()
print("train_X:", train_images.size(), "train_y:", train_labels.size())
val_images, val_labels = iter(loader_val).next()
print("val_X:", val_images.size(), "val_y:", val_labels.size())
test_images, test_labels = iter(loader_test).next()
print("test_X:", test_images.size(), "test_y:", test_labels.size())
# Out:
# train_X: torch.Size([64, 3, 32, 32]) train_y: torch.Size([64])
# val_X: torch.Size([64, 3, 32, 32]) val_y: torch.Size([64])
# test_X: torch.Size([64, 3, 32, 32]) test_y: torch.Size([64])

# %%
USE_GPU = True

dtype = torch.float32

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
print('using device', device)
# Out:
# using device cuda

# %%
class Model(nn.Module):
    def __init__(self, in_channel, channel_1, channel_2, 
                 channel_3, channel_4, num_classes):
        """
        Default initialization:
        model = Model(in_channel=3, channel_1=96, channel_2=192, 
                 channel_3=192, channel_4=192, num_classes=10)
        """
        super().__init__()
        self.conv1_1 = nn.Conv2d(in_channel, channel_1, 5, padding=2)  #(3, 96, 5)
        self.conv1_2 = nn.Conv2d(channel_1, channel_1, 1)   #(96, 96, 1)
        self.pool1 = nn.MaxPool2d(3, stride=2, padding=1)
        self.conv2_1 = nn.Conv2d(channel_1, channel_2, 5, padding=2)   #(96, 192, 5)
        self.conv2_2 = nn.Conv2d(channel_2, channel_2, 1)   #(192, 192, 1)
        self.pool2 = nn.MaxPool2d(3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(channel_2, channel_3, 3)   #(192, 192, 3)
        self.conv4 = nn.Conv2d(channel_3, channel_4, 1)   #(192, 192, 1)
        self.conv5 = nn.Conv2d(channel_4, num_classes, 1) #(192, 10, 1)
        
    def forward(self, x):
        """
        x.shape: (64, 3, 32, 32)
        """
        N = x.shape[0]
        x_drop = F.dropout(x, .2)
        conv1_1_out = F.relu(self.conv1_1(x_drop))                       # (64, 96, 32, 32)
        conv1_2_out = F.relu(self.conv1_2(conv1_1_out))             # (64, 96, 32, 32)
        layer1_out = self.pool1(conv1_2_out)                        # (64, 96, 16, 16)
        layer1_out_drop = F.dropout(layer1_out, .5)
        conv2_1_out = F.relu(self.conv2_1(layer1_out_drop))              # (64, 192, 16, 16)
        conv2_2_out = F.relu(self.conv2_2(conv2_1_out))             # (64, 192, 16, 16)        
        layer2_out = self.pool2(conv2_2_out)                        # (64, 192, 8, 8)
        layer2_out_drop = F.dropout(layer2_out, .5)
        layer3_out = F.relu(self.conv3(layer2_out_drop))                 # (64, 192, 6, 6)
        layer4_out = F.relu(self.conv4(layer3_out))                 # (64, 192, 6, 6)
        layer5_out = F.relu(self.conv5(layer4_out))                 # (64, 10, 6, 6)
#         print(x.size(), conv1_1_out.size(), conv1_2_out.size(), layer1_out.size(),layer5_out.size())
        out = layer5_out.view(N, 10, -1).mean(dim=2)
        return out
        
def test_Model():
    x = torch.zeros((64, 3, 32, 32), dtype=dtype)
    model = Model(in_channel=3, channel_1=96, channel_2=192, 
                 channel_3=192, channel_4=192, num_classes=10)
    scores = model(x)
    print(scores.size())
test_Model()
# Out:
# torch.Size([64, 10])

# %%
def check_accuracy(loader, model):
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set') 
    num_correct = 0
    num_samples = 0
    model.eval()
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            scores = model(x)
            _, preds = scores.max(1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def plot(x_lst, y_lst, path, name, xlabel, ylabel):
    plt.plot(x_lst, y_lst)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    plt.savefig(path + name)

# %%
print_every = 100

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']
    
def train(model, optimizer, scheduler, weight_decay=0.001, epochs=1, best_acc=0.0):
    loss_his = []
    epoch_lst = []
    acc_his = []
    
    model = model.to(device=device)
    model = nn.DataParallel(model,device_ids=[0,1])  
    
    for e in range(epochs):
        scheduler.step()
        for step, (x, y) in enumerate(loader_train):
            model.train()
            x = x.to(device=device, dtype=dtype)
            y = y.to(device=device, dtype=torch.long)
            
            scores = model(x)
            loss = F.cross_entropy(scores, y)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step % print_every == 0:
                print('Epoch %d, Iteration %d, loss = %.4f' % (e, step, loss.item()))
                acc = check_accuracy(loader_val, model)
                if acc > best_acc:
                    best_acc = acc
                    best_model_wts = copy.deepcopy(model.state_dict())
                fo = open("model_b.log", "a")
                fo.write("Epoch: {}\t Step: {}\t loss: {:.4f}\t accuracy: {:.2f}\n"\
                         .format(e, step, loss.item(), acc))
                fo.close()
                print()
        epoch_lst.append(e)
        loss_his.append(loss.item())
        acc_his.append(acc)
    
    plot(epoch_lst, loss_his, path="../results figure/", name="Model B_Loss accross Epoch", 
        xlabel="epoch", ylabel="loss")
    plot(epoch_lst, acc_his, path="../results figure/", name="Model B_Accuracy accross Epoch",
        xlabel="epoch", ylabel="accuracy")
                
    print("Best accuracy:", best_acc)
    fo = open("model_b.log", "a")
    fo.write("Best accuracy: {}".format(best_acc))
    fo.close()
    model.load_state_dict(best_model_wts)
    return model

# %%
lr_lst = [0.01]

fo = open("model_b.log", "w")
fo.write("Model B Trainning log\n")
fo.close()

for learning_rate in lr_lst:
    fo = open("model_b.log", "a")
    fo.write("\nOriginal Learning rate: {}\n".format(learning_rate))
    fo.close()
    print("Learning_rate:", learning_rate)
    model = Model(in_channel=3, channel_1=96, channel_2=192, 
             channel_3=192, channel_4=192, num_classes=10) 
    optimizer = optim.SGD(model.parameters(), lr = learning_rate, momentum=0.9, weight_decay=0.001)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                                               milestones=[200, 250, 300], gamma=0.1)
    best_model = train(model, optimizer, scheduler, epochs=350, best_acc=0.0)
    print()
# Out:
# Learning_rate: 0.01
# Epoch 0, Iteration 0, loss = 2.3002
# Checking accuracy on validation set
# Got 79 / 1000 correct (7.90)
#
# Epoch 0, Iteration 100, loss = 2.2980
# Checking accuracy on validation set
# Got 137 / 1000 correct (13.70)
#
# Epoch 0, Iteration 200, loss = 2.3042
# Checking accuracy on validation set
# Got 164 / 1000 correct (16.40)
#
# Epoch 0, Iteration 300, loss = 2.1751
# Checking accuracy on validation set
# Got 201 / 1000 correct (20.10)
#
# Epoch 0, Iteration 400, loss = 2.0565
# Checking accuracy on validation set
# Got 217 / 1000 correct (21.70)
#
# Epoch 0, Iteration 500, loss = 2.0960
# Checking accuracy on validation set
# Got 234 / 1000 correct (23.40)
#
# Epoch 0, Iteration 600, loss = 2.0926
# Checking accuracy on validation set
# Got 233 / 1000 correct (23.30)
#
# Epoch 0, Iteration 700, loss = 1.9043
# Checking accuracy on validation set
# Got 269 / 1000 correct (26.90)
#
# Epoch 1, Iteration 0, loss = 1.8776
# Checking accuracy on validation set
# Got 294 / 1000 correct (29.40)
#
# Epoch 1, Iteration 100, loss = 1.8832
# Checking accuracy on validation set
# Got 299 / 1000 correct (29.90)
#
# Epoch 1, Iteration 200, loss = 1.7982
# Checking accuracy on validation set
# Got 331 / 1000 correct (33.10)
#
# Epoch 1, Iteration 300, loss = 1.5762
# Checking accuracy on validation set
# Got 344 / 1000 correct (34.40)
#
# Epoch 1, Iteration 400, loss = 1.6957
# Checking accuracy on validation set
# Got 406 / 1000 correct (40.60)
#
# Epoch 1, Iteration 500, loss = 1.4570
# Checking accuracy on validation set
# Got 415 / 1000 correct (41.50)
#
# Epoch 1, Iteration 600, loss = 1.4212
# Checking accuracy on validation set
# Got 404 / 1000 correct (40.40)
#
# Epoch 1, Iteration 700, loss = 1.7124
# Checking accuracy on validation set
# Got 466 / 1000 correct (46.60)
#
# Epoch 2, Iteration 0, loss = 1.5103
# Checking accuracy on validation set
# Got 455 / 1000 correct (45.50)
#
# Epoch 2, Iteration 100, loss = 1.4547
# Checking accuracy on validation set
# Got 408 / 1000 correct (40.80)
#
# Epoch 2, Iteration 200, loss = 1.2308
# Checking accuracy on validation set
# Got 487 / 1000 correct (48.70)
#
# Epoch 2, Iteration 300, loss = 1.3746
# Checking accuracy on validation set
# Got 504 / 1000 correct (50.40)
#
# Epoch 2, Iteration 400, loss = 1.5140
# Checking accuracy on validation set
# Got 522 / 1000 correct (52.20)
#
# Epoch 2, Iteration 500, loss = 1.2980
# Checking accuracy on validation set
# Got 523 / 1000 correct (52.30)
#
# Epoch 2, Iteration 600, loss = 1.1402
# Checking accuracy on validation set
# Got 531 / 1000 correct (53.10)
#
# Epoch 2, Iteration 700, loss = 1.4525
# Checking accuracy on validation set
# Got 510 / 1000 correct (51.00)
#
# Epoch 3, Iteration 0, loss = 1.2986
# Checking accuracy on validation set
# Got 528 / 1000 correct (52.80)
#
# Epoch 3, Iteration 100, loss = 1.1007
# Checking accuracy on validation set
# Got 545 / 1000 correct (54.50)
#
# Epoch 3, Iteration 200, loss = 1.2332
# Checking accuracy on validation set
# Got 556 / 1000 correct (55.60)
#
# Epoch 3, Iteration 300, loss = 1.0156
# Checking accuracy on validation set
# Got 567 / 1000 correct (56.70)
#
# Epoch 3, Iteration 400, loss = 1.0612
# Checking accuracy on validation set
# Got 567 / 1000 correct (56.70)
#
# Epoch 3, Iteration 500, loss = 1.1152
# Checking accuracy on validation set
# Got 554 / 1000 correct (55.40)
#
# Epoch 3, Iteration 600, loss = 1.3051
# Checking accuracy on validation set
# Got 550 / 1000 correct (55.00)
#
# Epoch 3, Iteration 700, loss = 1.2234
# Checking accuracy on validation set
# Got 622 / 1000 correct (62.20)
#
# Epoch 4, Iteration 0, loss = 1.3158
# Checking accuracy on validation set
# Got 600 / 1000 correct (60.00)
#
# Epoch 4, Iteration 100, loss = 1.0023
# Checking accuracy on validation set
# Got 625 / 1000 correct (62.50)
#
# Epoch 4, Iteration 200, loss = 1.1040
# Checking accuracy on validation set
# Got 601 / 1000 correct (60.10)
#
# Epoch 4, Iteration 300, loss = 1.3899
# Checking accuracy on validation set
# Got 578 / 1000 correct (57.80)
#
# Epoch 4, Iteration 400, loss = 0.9807
# Checking accuracy on validation set
# Got 634 / 1000 correct (63.40)
#
# Epoch 4, Iteration 500, loss = 1.1847
# Checking accuracy on validation set
# Got 627 / 1000 correct (62.70)
#
# Epoch 4, Iteration 600, loss = 0.9964
# Checking accuracy on validation set
# Got 623 / 1000 correct (62.30)
#
# Epoch 4, Iteration 700, loss = 0.8982
# Checking accuracy on validation set
# Got 608 / 1000 correct (60.80)
#
# Epoch 5, Iteration 0, loss = 0.8926
# Checking accuracy on validation set
# Got 656 / 1000 correct (65.60)
#
# Epoch 5, Iteration 100, loss = 0.8139
# Checking accuracy on validation set
# Got 654 / 1000 correct (65.40)
#
# Epoch 5, Iteration 200, loss = 0.9754
# Checking accuracy on validation set
# Got 592 / 1000 correct (59.20)
#
# Epoch 5, Iteration 300, loss = 1.1715
# Checking accuracy on validation set
# Got 652 / 1000 correct (65.20)
#
# Epoch 5, Iteration 400, loss = 0.9454
# Checking accuracy on validation set
# Got 673 / 1000 correct (67.30)
#
# Epoch 5, Iteration 500, loss = 0.8089
# Checking accuracy on validation set
# Got 678 / 1000 correct (67.80)
#
# Epoch 5, Iteration 600, loss = 0.8168
# Checking accuracy on validation set
# Got 676 / 1000 correct (67.60)
#
# Epoch 5, Iteration 700, loss = 1.2887
# Checking accuracy on validation set
# Got 668 / 1000 correct (66.80)
#
# Epoch 6, Iteration 0, loss = 0.8981
# Checking accuracy on validation set
# Got 687 / 1000 correct (68.70)
#
# Epoch 6, Iteration 100, loss = 0.7711
# Checking accuracy on validation set
# Got 685 / 1000 correct (68.50)
#
# Epoch 6, Iteration 200, loss = 1.0229
# Checking accuracy on validation set
# Got 640 / 1000 correct (64.00)
#
# Epoch 6, Iteration 300, loss = 0.8415
# Checking accuracy on validation set
# Got 684 / 1000 correct (68.40)
#
# Epoch 6, Iteration 400, loss = 0.8875
# Checking accuracy on validation set
# Got 678 / 1000 correct (67.80)
#
# Epoch 6, Iteration 500, loss = 1.3634
# Checking accuracy on validation set
# Got 684 / 1000 correct (68.40)
#
# Epoch 6, Iteration 600, loss = 0.6910
# Checking accuracy on validation set
# Got 704 / 1000 correct (70.40)
#
# Epoch 6, Iteration 700, loss = 0.7358
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Epoch 7, Iteration 0, loss = 0.8722
# Checking accuracy on validation set
# Got 710 / 1000 correct (71.00)
#
# Epoch 7, Iteration 100, loss = 0.9309
# Checking accuracy on validation set
# Got 706 / 1000 correct (70.60)
#
# Epoch 7, Iteration 200, loss = 0.7335
# Checking accuracy on validation set
# Got 705 / 1000 correct (70.50)
#
# Epoch 7, Iteration 300, loss = 1.1287
# Checking accuracy on validation set
# Got 661 / 1000 correct (66.10)
#
# Epoch 7, Iteration 400, loss = 0.6922
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Epoch 7, Iteration 500, loss = 0.9704
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
#
# Epoch 7, Iteration 600, loss = 0.5012
# Checking accuracy on validation set
# Got 713 / 1000 correct (71.30)
#
# Epoch 7, Iteration 700, loss = 0.7860
# Checking accuracy on validation set
# Got 735 / 1000 correct (73.50)
#
# Epoch 8, Iteration 0, loss = 0.9350
# Checking accuracy on validation set
# Got 712 / 1000 correct (71.20)
#
# Epoch 8, Iteration 100, loss = 0.9693
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
#
# Epoch 8, Iteration 200, loss = 0.5562
# Checking accuracy on validation set
# Got 714 / 1000 correct (71.40)
#
# Epoch 8, Iteration 300, loss = 0.5833
# Checking accuracy on validation set
# Got 742 / 1000 correct (74.20)
#
# Epoch 8, Iteration 400, loss = 0.6799
# Checking accuracy on validation set
# Got 761 / 1000 correct (76.10)
#
# Epoch 8, Iteration 500, loss = 0.6530
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
#
# Epoch 8, Iteration 600, loss = 0.9232
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
#
# Epoch 8, Iteration 700, loss = 0.6471
# Checking accuracy on validation set
# Got 688 / 1000 correct (68.80)
#
# Epoch 9, Iteration 0, loss = 0.6587
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
#
# Epoch 9, Iteration 100, loss = 0.9492
# Checking accuracy on validation set
# Got 767 / 1000 correct (76.70)
#
# Epoch 9, Iteration 200, loss = 0.8293
# Checking accuracy on validation set
# Got 738 / 1000 correct (73.80)
#
# Epoch 9, Iteration 300, loss = 0.4692
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
#
# Epoch 9, Iteration 400, loss = 0.5727
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
#
# Epoch 9, Iteration 500, loss = 0.5021
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
#
# Epoch 9, Iteration 600, loss = 0.3698
# Checking accuracy on validation set
# Got 764 / 1000 correct (76.40)
#
# Epoch 9, Iteration 700, loss = 0.5923
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
#
# Epoch 10, Iteration 0, loss = 0.8160
# Checking accuracy on validation set
# Got 738 / 1000 correct (73.80)
#
# Epoch 10, Iteration 100, loss = 0.4059
# Checking accuracy on validation set
# Got 749 / 1000 correct (74.90)
#
# Epoch 10, Iteration 200, loss = 0.7857
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
#
# Epoch 10, Iteration 300, loss = 0.6366
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
#
# Epoch 10, Iteration 400, loss = 0.5695
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
#
# Epoch 10, Iteration 500, loss = 0.7259
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
#
# Epoch 10, Iteration 600, loss = 0.7429
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
#
# Epoch 10, Iteration 700, loss = 0.5777
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
#
# Epoch 11, Iteration 0, loss = 0.4713
# Checking accuracy on validation set
# Got 756 / 1000 correct (75.60)
#
# Epoch 11, Iteration 100, loss = 0.5994
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
#
# Epoch 11, Iteration 200, loss = 0.7085
# Checking accuracy on validation set
# Got 761 / 1000 correct (76.10)
#
# Epoch 11, Iteration 300, loss = 0.3684
# Checking accuracy on validation set
# Got 768 / 1000 correct (76.80)
#
# Epoch 11, Iteration 400, loss = 0.4599
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
#
# Epoch 11, Iteration 500, loss = 0.5154
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Epoch 11, Iteration 600, loss = 0.4043
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
#
# Epoch 11, Iteration 700, loss = 0.8419
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
#
# Epoch 12, Iteration 0, loss = 0.5423
# Checking accuracy on validation set
# Got 756 / 1000 correct (75.60)
#
# Epoch 12, Iteration 100, loss = 0.3051
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Epoch 12, Iteration 200, loss = 0.5412
# Checking accuracy on validation set
# Got 762 / 1000 correct (76.20)
#
# Epoch 12, Iteration 300, loss = 0.6213
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
#
# Epoch 12, Iteration 400, loss = 0.5380
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
#
# Epoch 12, Iteration 500, loss = 0.8152
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
#
# Epoch 12, Iteration 600, loss = 0.5527
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
#
# Epoch 12, Iteration 700, loss = 0.6350
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
#
# Epoch 13, Iteration 0, loss = 0.5187
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
#
# Epoch 13, Iteration 100, loss = 0.5321
# Checking accuracy on validation set
# Got 768 / 1000 correct (76.80)
#
# Epoch 13, Iteration 200, loss = 0.4154
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
#
# Epoch 13, Iteration 300, loss = 0.5926
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
#
# Epoch 13, Iteration 400, loss = 0.3785
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
#
# Epoch 13, Iteration 500, loss = 0.3911
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 13, Iteration 600, loss = 0.5892
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
#
# Epoch 13, Iteration 700, loss = 0.4933
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
#
# Epoch 14, Iteration 0, loss = 0.4222
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
#
# Epoch 14, Iteration 100, loss = 0.4781
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 14, Iteration 200, loss = 0.6654
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
#
# Epoch 14, Iteration 300, loss = 0.4993
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
#
# Epoch 14, Iteration 400, loss = 0.6461
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
#
# Epoch 14, Iteration 500, loss = 0.3655
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
#
# Epoch 14, Iteration 600, loss = 0.3739
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
#
# Epoch 14, Iteration 700, loss = 0.5775
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 15, Iteration 0, loss = 0.3191
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
#
# Epoch 15, Iteration 100, loss = 0.6192
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 15, Iteration 200, loss = 0.4505
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 15, Iteration 300, loss = 0.4996
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
#
# Epoch 15, Iteration 400, loss = 0.5090
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 15, Iteration 500, loss = 0.4020
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
#
# Epoch 15, Iteration 600, loss = 0.6048
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
#
# Epoch 15, Iteration 700, loss = 0.3576
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Epoch 16, Iteration 0, loss = 0.2925
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Epoch 16, Iteration 100, loss = 0.3571
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
#
# Epoch 16, Iteration 200, loss = 0.4538
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
#
# Epoch 16, Iteration 300, loss = 0.2634
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
#
# Epoch 16, Iteration 400, loss = 0.4281
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
#
# Epoch 16, Iteration 500, loss = 0.3987
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
#
# Epoch 16, Iteration 600, loss = 0.6217
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
#
# Epoch 16, Iteration 700, loss = 0.2955
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Epoch 17, Iteration 0, loss = 0.4830
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
#
# Epoch 17, Iteration 100, loss = 0.3316
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 17, Iteration 200, loss = 0.3017
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 17, Iteration 300, loss = 0.2742
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Epoch 17, Iteration 400, loss = 0.3640
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 17, Iteration 500, loss = 0.6486
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
#
# Epoch 17, Iteration 600, loss = 0.3171
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 17, Iteration 700, loss = 0.3845
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 18, Iteration 0, loss = 0.4050
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Epoch 18, Iteration 100, loss = 0.3070
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 18, Iteration 200, loss = 0.3815
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
#
# Epoch 18, Iteration 300, loss = 0.3664
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 18, Iteration 400, loss = 0.3784
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Epoch 18, Iteration 500, loss = 0.4681
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Epoch 18, Iteration 600, loss = 0.4404
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 18, Iteration 700, loss = 0.4094
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 19, Iteration 0, loss = 0.3157
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 19, Iteration 100, loss = 0.3065
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 19, Iteration 200, loss = 0.2533
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 19, Iteration 300, loss = 0.4251
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 19, Iteration 400, loss = 0.2533
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 19, Iteration 500, loss = 0.4943
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
#
# Epoch 19, Iteration 600, loss = 0.2874
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 19, Iteration 700, loss = 0.2990
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 20, Iteration 0, loss = 0.3558
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 20, Iteration 100, loss = 0.1650
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
#
# Epoch 20, Iteration 200, loss = 0.4803
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 20, Iteration 300, loss = 0.2551
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
#
# Epoch 20, Iteration 400, loss = 0.3407
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 20, Iteration 500, loss = 0.3423
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
#
# Epoch 20, Iteration 600, loss = 0.4154
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 20, Iteration 700, loss = 0.2772
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 21, Iteration 0, loss = 0.3307
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 21, Iteration 100, loss = 0.2856
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 21, Iteration 200, loss = 0.4055
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 21, Iteration 300, loss = 0.3510
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 21, Iteration 400, loss = 0.3744
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 21, Iteration 500, loss = 0.2783
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 21, Iteration 600, loss = 0.4539
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 21, Iteration 700, loss = 0.5194
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 22, Iteration 0, loss = 0.1750
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 22, Iteration 100, loss = 0.2718
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 22, Iteration 200, loss = 0.2397
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 22, Iteration 300, loss = 0.1831
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 22, Iteration 400, loss = 0.3020
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 22, Iteration 500, loss = 0.3231
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 22, Iteration 600, loss = 0.2563
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 22, Iteration 700, loss = 0.1511
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 23, Iteration 0, loss = 0.4563
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Epoch 23, Iteration 100, loss = 0.4143
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 23, Iteration 200, loss = 0.1488
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Epoch 23, Iteration 300, loss = 0.1719
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 23, Iteration 400, loss = 0.1588
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 23, Iteration 500, loss = 0.3069
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 23, Iteration 600, loss = 0.2820
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 23, Iteration 700, loss = 0.1862
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 24, Iteration 0, loss = 0.1334
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 24, Iteration 100, loss = 0.1441
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 24, Iteration 200, loss = 0.2373
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 24, Iteration 300, loss = 0.1725
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 24, Iteration 400, loss = 0.2239
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 24, Iteration 500, loss = 0.3783
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 24, Iteration 600, loss = 0.2399
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 24, Iteration 700, loss = 0.3589
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 25, Iteration 0, loss = 0.2083
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 25, Iteration 100, loss = 0.1345
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 25, Iteration 200, loss = 0.2855
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 25, Iteration 300, loss = 0.2609
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 25, Iteration 400, loss = 0.2016
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 25, Iteration 500, loss = 0.5017
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Epoch 25, Iteration 600, loss = 0.1882
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 25, Iteration 700, loss = 0.1995
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 26, Iteration 0, loss = 0.2229
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 26, Iteration 100, loss = 0.0931
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 26, Iteration 200, loss = 0.3151
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Epoch 26, Iteration 300, loss = 0.2274
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 26, Iteration 400, loss = 0.2665
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Epoch 26, Iteration 500, loss = 0.2053
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 26, Iteration 600, loss = 0.2057
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 26, Iteration 700, loss = 0.5176
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 27, Iteration 0, loss = 0.4252
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 27, Iteration 100, loss = 0.3441
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 27, Iteration 200, loss = 0.1731
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 27, Iteration 300, loss = 0.3010
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 27, Iteration 400, loss = 0.2359
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 27, Iteration 500, loss = 0.3125
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 27, Iteration 600, loss = 0.1010
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 27, Iteration 700, loss = 0.3967
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 28, Iteration 0, loss = 0.2443
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 28, Iteration 100, loss = 0.2067
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 28, Iteration 200, loss = 0.1311
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 28, Iteration 300, loss = 0.1737
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 28, Iteration 400, loss = 0.3254
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 28, Iteration 500, loss = 0.3308
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 28, Iteration 600, loss = 0.2131
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 28, Iteration 700, loss = 0.2199
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 29, Iteration 0, loss = 0.1828
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Epoch 29, Iteration 100, loss = 0.1705
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 29, Iteration 200, loss = 0.2040
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 29, Iteration 300, loss = 0.1334
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 29, Iteration 400, loss = 0.3724
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 29, Iteration 500, loss = 0.2769
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 29, Iteration 600, loss = 0.1255
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 29, Iteration 700, loss = 0.3148
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
#
# Epoch 30, Iteration 0, loss = 0.1067
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 30, Iteration 100, loss = 0.0760
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 30, Iteration 200, loss = 0.1661
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 30, Iteration 300, loss = 0.2271
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 30, Iteration 400, loss = 0.2360
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
#
# Epoch 30, Iteration 500, loss = 0.1953
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 30, Iteration 600, loss = 0.2686
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 30, Iteration 700, loss = 0.1525
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 31, Iteration 0, loss = 0.2619
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 31, Iteration 100, loss = 0.0881
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 31, Iteration 200, loss = 0.1136
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 31, Iteration 300, loss = 0.4227
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 31, Iteration 400, loss = 0.1296
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 31, Iteration 500, loss = 0.2017
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 31, Iteration 600, loss = 0.2757
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 31, Iteration 700, loss = 0.2642
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 32, Iteration 0, loss = 0.0886
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 32, Iteration 100, loss = 0.1319
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 32, Iteration 200, loss = 0.0832
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 32, Iteration 300, loss = 0.2172
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 32, Iteration 400, loss = 0.1723
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 32, Iteration 500, loss = 0.1458
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 32, Iteration 600, loss = 0.1818
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 32, Iteration 700, loss = 0.3326
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 33, Iteration 0, loss = 0.1901
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
#
# Epoch 33, Iteration 100, loss = 0.1327
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 33, Iteration 200, loss = 0.1713
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 33, Iteration 300, loss = 0.1903
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 33, Iteration 400, loss = 0.2818
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 33, Iteration 500, loss = 0.1908
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 33, Iteration 600, loss = 0.1361
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 33, Iteration 700, loss = 0.1346
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 34, Iteration 0, loss = 0.0880
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 34, Iteration 100, loss = 0.1597
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
#
# Epoch 34, Iteration 200, loss = 0.2360
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 34, Iteration 300, loss = 0.3774
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
#
# Epoch 34, Iteration 400, loss = 0.1438
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 34, Iteration 500, loss = 0.1125
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 34, Iteration 600, loss = 0.3403
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 34, Iteration 700, loss = 0.2153
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 35, Iteration 0, loss = 0.1534
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 35, Iteration 100, loss = 0.0549
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 35, Iteration 200, loss = 0.2727
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 35, Iteration 300, loss = 0.1208
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 35, Iteration 400, loss = 0.0585
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 35, Iteration 500, loss = 0.1422
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 35, Iteration 600, loss = 0.2077
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 35, Iteration 700, loss = 0.1496
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 36, Iteration 0, loss = 0.1250
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Epoch 36, Iteration 100, loss = 0.0839
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 36, Iteration 200, loss = 0.1407
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Epoch 36, Iteration 300, loss = 0.0812
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 36, Iteration 400, loss = 0.0632
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 36, Iteration 500, loss = 0.0914
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 36, Iteration 600, loss = 0.1442
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 36, Iteration 700, loss = 0.1851
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
#
# Epoch 37, Iteration 0, loss = 0.1535
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 37, Iteration 100, loss = 0.1060
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 37, Iteration 200, loss = 0.2405
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 37, Iteration 300, loss = 0.2019
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
#
# Epoch 37, Iteration 400, loss = 0.1185
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 37, Iteration 500, loss = 0.1752
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 37, Iteration 600, loss = 0.1976
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 37, Iteration 700, loss = 0.1347
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 38, Iteration 0, loss = 0.0803
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 38, Iteration 100, loss = 0.1234
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 38, Iteration 200, loss = 0.2835
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 38, Iteration 300, loss = 0.0690
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 38, Iteration 400, loss = 0.0926
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 38, Iteration 500, loss = 0.0736
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 38, Iteration 600, loss = 0.3352
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 38, Iteration 700, loss = 0.1167
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 39, Iteration 0, loss = 0.0534
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 39, Iteration 100, loss = 0.1096
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 39, Iteration 200, loss = 0.2028
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 39, Iteration 300, loss = 0.1431
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 39, Iteration 400, loss = 0.1970
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 39, Iteration 500, loss = 0.4122
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 39, Iteration 600, loss = 0.1599
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 39, Iteration 700, loss = 0.2334
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 40, Iteration 0, loss = 0.1338
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 40, Iteration 100, loss = 0.0791
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 40, Iteration 200, loss = 0.0539
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Epoch 40, Iteration 300, loss = 0.1097
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 40, Iteration 400, loss = 0.1212
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 40, Iteration 500, loss = 0.2262
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 40, Iteration 600, loss = 0.1136
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 40, Iteration 700, loss = 0.0694
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 41, Iteration 0, loss = 0.1437
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 41, Iteration 100, loss = 0.1825
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 41, Iteration 200, loss = 0.1460
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 41, Iteration 300, loss = 0.2573
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 41, Iteration 400, loss = 0.1982
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 41, Iteration 500, loss = 0.1637
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 41, Iteration 600, loss = 0.2202
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 41, Iteration 700, loss = 0.1578
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 42, Iteration 0, loss = 0.1178
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 42, Iteration 100, loss = 0.0942
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 42, Iteration 200, loss = 0.1961
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 42, Iteration 300, loss = 0.0269
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 42, Iteration 400, loss = 0.3894
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 42, Iteration 500, loss = 0.1491
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 42, Iteration 600, loss = 0.2990
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 42, Iteration 700, loss = 0.3377
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 43, Iteration 0, loss = 0.1481
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 43, Iteration 100, loss = 0.0944
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 43, Iteration 200, loss = 0.3867
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
#
# Epoch 43, Iteration 300, loss = 0.1961
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 43, Iteration 400, loss = 0.3188
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 43, Iteration 500, loss = 0.1077
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 43, Iteration 600, loss = 0.1007
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 43, Iteration 700, loss = 0.1301
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 44, Iteration 0, loss = 0.1922
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 44, Iteration 100, loss = 0.1043
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 44, Iteration 200, loss = 0.1208
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 44, Iteration 300, loss = 0.1201
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 44, Iteration 400, loss = 0.0654
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 44, Iteration 500, loss = 0.1942
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Epoch 44, Iteration 600, loss = 0.2427
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 44, Iteration 700, loss = 0.1580
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 45, Iteration 0, loss = 0.1878
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 45, Iteration 100, loss = 0.0657
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 45, Iteration 200, loss = 0.0824
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 45, Iteration 300, loss = 0.2169
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 45, Iteration 400, loss = 0.1355
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 45, Iteration 500, loss = 0.1948
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 45, Iteration 600, loss = 0.1184
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 45, Iteration 700, loss = 0.3662
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Epoch 46, Iteration 0, loss = 0.1394
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 46, Iteration 100, loss = 0.0828
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 46, Iteration 200, loss = 0.3261
# Checking accuracy on validation set
# Got 767 / 1000 correct (76.70)
#
# Epoch 46, Iteration 300, loss = 0.1409
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 46, Iteration 400, loss = 0.2503
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 46, Iteration 500, loss = 0.1190
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 46, Iteration 600, loss = 0.1116
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 46, Iteration 700, loss = 0.1473
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 47, Iteration 0, loss = 0.1156
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 47, Iteration 100, loss = 0.1100
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 47, Iteration 200, loss = 0.1289
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 47, Iteration 300, loss = 0.1550
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 47, Iteration 400, loss = 0.1889
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
#
# Epoch 47, Iteration 500, loss = 0.1665
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 47, Iteration 600, loss = 0.1541
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 47, Iteration 700, loss = 0.1096
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Epoch 48, Iteration 0, loss = 0.1141
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Epoch 48, Iteration 100, loss = 0.0451
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 48, Iteration 200, loss = 0.0535
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 48, Iteration 300, loss = 0.0754
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 48, Iteration 400, loss = 0.2246
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 48, Iteration 500, loss = 0.2289
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 48, Iteration 600, loss = 0.2093
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 48, Iteration 700, loss = 0.1599
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 49, Iteration 0, loss = 0.1214
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 49, Iteration 100, loss = 0.0441
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 49, Iteration 200, loss = 0.1067
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 49, Iteration 300, loss = 0.2884
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 49, Iteration 400, loss = 0.0791
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 49, Iteration 500, loss = 0.1325
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 49, Iteration 600, loss = 0.1670
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 49, Iteration 700, loss = 0.1750
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 50, Iteration 0, loss = 0.0616
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 50, Iteration 100, loss = 0.1912
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 50, Iteration 200, loss = 0.0963
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Epoch 50, Iteration 300, loss = 0.1214
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 50, Iteration 400, loss = 0.0936
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 50, Iteration 500, loss = 0.1408
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 50, Iteration 600, loss = 0.0700
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 50, Iteration 700, loss = 0.0874
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
#
# Epoch 51, Iteration 0, loss = 0.0642
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 51, Iteration 100, loss = 0.0816
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 51, Iteration 200, loss = 0.0567
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 51, Iteration 300, loss = 0.1087
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 51, Iteration 400, loss = 0.1474
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 51, Iteration 500, loss = 0.1965
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 51, Iteration 600, loss = 0.1436
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 51, Iteration 700, loss = 0.1406
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 52, Iteration 0, loss = 0.0841
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 52, Iteration 100, loss = 0.0426
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Epoch 52, Iteration 200, loss = 0.0568
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
#
# Epoch 52, Iteration 300, loss = 0.1120
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 52, Iteration 400, loss = 0.2343
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 52, Iteration 500, loss = 0.2028
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
#
# Epoch 52, Iteration 600, loss = 0.2387
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
#
# Epoch 52, Iteration 700, loss = 0.1092
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 53, Iteration 0, loss = 0.0744
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 53, Iteration 100, loss = 0.1460
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Epoch 53, Iteration 200, loss = 0.1231
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 53, Iteration 300, loss = 0.1872
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 53, Iteration 400, loss = 0.1584
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 53, Iteration 500, loss = 0.1307
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 53, Iteration 600, loss = 0.1466
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 53, Iteration 700, loss = 0.0898
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 54, Iteration 0, loss = 0.0857
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 54, Iteration 100, loss = 0.0931
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 54, Iteration 200, loss = 0.1567
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 54, Iteration 300, loss = 0.1441
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 54, Iteration 400, loss = 0.1037
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 54, Iteration 500, loss = 0.0766
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 54, Iteration 600, loss = 0.2007
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 54, Iteration 700, loss = 0.1827
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 55, Iteration 0, loss = 0.1323
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 55, Iteration 100, loss = 0.1514
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 55, Iteration 200, loss = 0.2022
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 55, Iteration 300, loss = 0.1160
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 55, Iteration 400, loss = 0.0828
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 55, Iteration 500, loss = 0.0655
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Epoch 55, Iteration 600, loss = 0.1507
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 55, Iteration 700, loss = 0.1814
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 56, Iteration 0, loss = 0.0950
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 56, Iteration 100, loss = 0.1103
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# ...
# Got 838 / 1000 correct (83.80)
#
# Epoch 331, Iteration 400, loss = 0.0084
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 331, Iteration 500, loss = 0.0138
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 331, Iteration 600, loss = 0.0107
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 331, Iteration 700, loss = 0.0117
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 332, Iteration 0, loss = 0.0198
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 332, Iteration 100, loss = 0.0153
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 332, Iteration 200, loss = 0.0138
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 332, Iteration 300, loss = 0.0154
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 332, Iteration 400, loss = 0.0175
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 332, Iteration 500, loss = 0.0172
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 332, Iteration 600, loss = 0.0141
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 332, Iteration 700, loss = 0.0148
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 333, Iteration 0, loss = 0.0086
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 333, Iteration 100, loss = 0.0120
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 333, Iteration 200, loss = 0.0102
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 333, Iteration 300, loss = 0.0105
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 333, Iteration 400, loss = 0.0096
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 333, Iteration 500, loss = 0.0074
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 333, Iteration 600, loss = 0.0097
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 333, Iteration 700, loss = 0.0140
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 334, Iteration 0, loss = 0.0095
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 334, Iteration 100, loss = 0.0197
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 334, Iteration 200, loss = 0.0175
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 334, Iteration 300, loss = 0.0199
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 334, Iteration 400, loss = 0.0152
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 334, Iteration 500, loss = 0.0236
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 334, Iteration 600, loss = 0.0179
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 334, Iteration 700, loss = 0.0130
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 335, Iteration 0, loss = 0.0110
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 335, Iteration 100, loss = 0.0142
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 335, Iteration 200, loss = 0.0139
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
# Epoch 335, Iteration 300, loss = 0.0086
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 335, Iteration 400, loss = 0.0162
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 335, Iteration 500, loss = 0.0188
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 335, Iteration 600, loss = 0.0129
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 335, Iteration 700, loss = 0.0183
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 336, Iteration 0, loss = 0.0189
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 336, Iteration 100, loss = 0.0091
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 336, Iteration 200, loss = 0.0181
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 336, Iteration 300, loss = 0.0162
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 336, Iteration 400, loss = 0.0072
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 336, Iteration 500, loss = 0.0149
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 336, Iteration 600, loss = 0.0091
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 336, Iteration 700, loss = 0.0164
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 337, Iteration 0, loss = 0.0106
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 337, Iteration 100, loss = 0.0260
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 337, Iteration 200, loss = 0.0208
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 337, Iteration 300, loss = 0.0127
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 337, Iteration 400, loss = 0.0109
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 337, Iteration 500, loss = 0.0114
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 337, Iteration 600, loss = 0.0107
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 337, Iteration 700, loss = 0.0120
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 338, Iteration 0, loss = 0.0154
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 338, Iteration 100, loss = 0.0091
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 338, Iteration 200, loss = 0.0090
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 338, Iteration 300, loss = 0.0113
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 338, Iteration 400, loss = 0.0101
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 338, Iteration 500, loss = 0.0114
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 338, Iteration 600, loss = 0.0115
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 338, Iteration 700, loss = 0.0099
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 339, Iteration 0, loss = 0.0124
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 339, Iteration 100, loss = 0.0082
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 339, Iteration 200, loss = 0.0086
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 339, Iteration 300, loss = 0.0139
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 339, Iteration 400, loss = 0.0135
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 339, Iteration 500, loss = 0.0133
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 339, Iteration 600, loss = 0.0145
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 339, Iteration 700, loss = 0.0214
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 340, Iteration 0, loss = 0.0119
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 340, Iteration 100, loss = 0.0108
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 340, Iteration 200, loss = 0.0086
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 340, Iteration 300, loss = 0.0103
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 340, Iteration 400, loss = 0.0089
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 340, Iteration 500, loss = 0.0125
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 340, Iteration 600, loss = 0.0145
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 340, Iteration 700, loss = 0.0167
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 341, Iteration 0, loss = 0.0223
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 341, Iteration 100, loss = 0.0143
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 341, Iteration 200, loss = 0.0162
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 341, Iteration 300, loss = 0.0175
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 341, Iteration 400, loss = 0.0175
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 341, Iteration 500, loss = 0.0210
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 341, Iteration 600, loss = 0.0147
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 341, Iteration 700, loss = 0.0143
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 342, Iteration 0, loss = 0.0158
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 342, Iteration 100, loss = 0.0111
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 342, Iteration 200, loss = 0.0149
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 342, Iteration 300, loss = 0.0102
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 342, Iteration 400, loss = 0.0192
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 342, Iteration 500, loss = 0.0163
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 342, Iteration 600, loss = 0.0099
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 342, Iteration 700, loss = 0.0119
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 343, Iteration 0, loss = 0.0152
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 343, Iteration 100, loss = 0.0126
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 343, Iteration 200, loss = 0.0177
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 343, Iteration 300, loss = 0.0143
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 343, Iteration 400, loss = 0.0120
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 343, Iteration 500, loss = 0.0102
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 343, Iteration 600, loss = 0.0152
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 343, Iteration 700, loss = 0.0133
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 344, Iteration 0, loss = 0.0074
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 344, Iteration 100, loss = 0.0161
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 344, Iteration 200, loss = 0.0118
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 344, Iteration 300, loss = 0.0116
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 344, Iteration 400, loss = 0.0143
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 344, Iteration 500, loss = 0.0192
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 344, Iteration 600, loss = 0.0154
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 344, Iteration 700, loss = 0.0126
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 345, Iteration 0, loss = 0.0161
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 345, Iteration 100, loss = 0.0069
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 345, Iteration 200, loss = 0.0134
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 345, Iteration 300, loss = 0.0123
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 345, Iteration 400, loss = 0.0149
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 345, Iteration 500, loss = 0.0123
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 345, Iteration 600, loss = 0.0115
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 345, Iteration 700, loss = 0.0114
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 346, Iteration 0, loss = 0.0160
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 346, Iteration 100, loss = 0.0121
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 346, Iteration 200, loss = 0.0138
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 346, Iteration 300, loss = 0.0088
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 346, Iteration 400, loss = 0.0125
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 346, Iteration 500, loss = 0.0162
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 346, Iteration 600, loss = 0.0229
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 346, Iteration 700, loss = 0.0104
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 347, Iteration 0, loss = 0.0151
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 347, Iteration 100, loss = 0.0079
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 347, Iteration 200, loss = 0.0118
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 347, Iteration 300, loss = 0.0135
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 347, Iteration 400, loss = 0.0110
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 347, Iteration 500, loss = 0.0102
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 347, Iteration 600, loss = 0.0131
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 347, Iteration 700, loss = 0.0184
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 348, Iteration 0, loss = 0.0100
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 348, Iteration 100, loss = 0.0141
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 348, Iteration 200, loss = 0.0062
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 348, Iteration 300, loss = 0.0197
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 348, Iteration 400, loss = 0.0147
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 348, Iteration 500, loss = 0.0104
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 348, Iteration 600, loss = 0.0172
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 348, Iteration 700, loss = 0.0134
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 349, Iteration 0, loss = 0.0127
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 349, Iteration 100, loss = 0.0172
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 349, Iteration 200, loss = 0.0097
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 349, Iteration 300, loss = 0.0113
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 349, Iteration 400, loss = 0.0170
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 349, Iteration 500, loss = 0.0082
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 349, Iteration 600, loss = 0.0157
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Epoch 349, Iteration 700, loss = 0.0135
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
# Best accuracy: 0.844

# %%
PATH = "../best_model/"
model_name = "best_model_b.pt"
if not os.path.exists(PATH):
    os.mkdir(PATH)
torch.save(best_model.state_dict(), PATH + model_name)
