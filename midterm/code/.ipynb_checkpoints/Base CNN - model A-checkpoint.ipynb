# %%
import torch
from torch.utils.data import sampler
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import os
import copy
import matplotlib.pyplot as plt

# %%
NUM_TRAIN = 49000

transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
            ])
cifar10_train = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=True,
                                           download=True, transform=transform)
loader_train = torch.utils.data.DataLoader(cifar10_train, batch_size=64,
                                      sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))
cifar10_val = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=False,
                                         download=True, transform=transform)
loader_val = torch.utils.data.DataLoader(cifar10_train, batch_size=64,
                                    sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))
cifar10_test = torchvision.datasets.CIFAR10(root='../data/CIFAR10', train=False,
                                         download=True, transform=transform)
loader_test = torch.utils.data.DataLoader(cifar10_train, batch_size=64)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_images, train_labels = iter(loader_train).next()
print("train_X:", train_images.size(), "train_y:", train_labels.size())
val_images, val_labels = iter(loader_val).next()
print("val_X:", val_images.size(), "val_y:", val_labels.size())
test_images, test_labels = iter(loader_test).next()
print("test_X:", test_images.size(), "test_y:", test_labels.size())
# Out:
# train_X: torch.Size([64, 3, 32, 32]) train_y: torch.Size([64])
# val_X: torch.Size([64, 3, 32, 32]) val_y: torch.Size([64])
# test_X: torch.Size([64, 3, 32, 32]) test_y: torch.Size([64])

# %%
USE_GPU = True

dtype = torch.float32

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
print('using device', device)
# Out:
# using device cuda

# %%
class Model(nn.Module):
    def __init__(self, in_channel, channel_1, channel_2, 
                 channel_3, channel_4, num_classes):
        """
        Default initialization:
        model = Model(in_channel=3, channel_1=96, channel_2=192, 
                 channel_3=192, channel_4=192, num_classes=10)
        """
        super().__init__()
        self.conv1 = nn.Conv2d(in_channel, channel_1, 5, padding=2)  #(3, 96, 5)
        self.pool1 = nn.MaxPool2d(3, stride=2, padding=1)
        self.conv2 = nn.Conv2d(channel_1, channel_2, 5, padding=2)   #(96, 192, 5)
        self.pool2 = nn.MaxPool2d(3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(channel_2, channel_3, 3)   #(192, 192, 3)
        self.conv4 = nn.Conv2d(channel_3, channel_4, 1)   #(192, 192, 1)
        self.conv5 = nn.Conv2d(channel_4, num_classes, 1) #(192, 10, 1)
        
    def forward(self, x):
        """
        x.shape: (64, 3, 32, 32)
        """
        N = x.shape[0]
        x_drop = F.dropout(x, .2)
        conv1_out = F.relu(self.conv1(x_drop))            # (64, 96, 32, 32)
        layer1_out = self.pool1(conv1_out)                      # (64, 96, 16, 16)
        layer1_out_drop = F.dropout(layer1_out, .5)
        conv2_out = F.relu(self.conv2(layer1_out_drop))   # (64, 192, 16, 16)
        layer2_out = self.pool2(conv2_out)                      # (64, 192, 8, 8)
        layer2_out_drop = F.dropout(layer2_out, .5)
        layer3_out = F.relu(self.conv3(layer2_out_drop))             # (64, 192, 6, 6)
        layer4_out = F.relu(self.conv4(layer3_out))             # (64, 192, 6, 6)
        layer5_out = F.relu(self.conv5(layer4_out))             # (64, 10, 6, 6)
#         print(x.size(), conv1_out.size(), layer1_out.size(),layer5_out.size())
        out = layer5_out.view(N, 10, -1).mean(dim=2)
        return out
        
def test_Model():
    x = torch.zeros((64, 3, 32, 32), dtype=dtype)
    model = Model(in_channel=3, channel_1=96, channel_2=192, 
                 channel_3=192, channel_4=192, num_classes=10)
    scores = model(x)
    print(scores.size())
test_Model()
# Out:
# torch.Size([64, 10])

# %%
def check_accuracy(loader, model):
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set') 
    num_correct = 0
    num_samples = 0
    model.eval()
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            scores = model(x)
            _, preds = scores.max(1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def plot(x_lst, y_lst, path, name, xlabel, ylabel):
    plt.plot(x_lst, y_lst)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    plt.savefig(path + name)

# %%
print_every = 100
    
def train(model, optimizer, scheduler, weight_decay=0.001, epochs=1, best_acc=0.0):
    loss_his = []
    epoch_lst = []
    acc_his = []
    
    model = model.to(device=device)
    model = nn.DataParallel(model,device_ids=[0,1])  
    
    for e in range(epochs):
        scheduler.step()
        for step, (x, y) in enumerate(loader_train):
            model.train()
            x = x.to(device=device, dtype=dtype)
            y = y.to(device=device, dtype=torch.long)
            
            scores = model(x)
            loss = F.cross_entropy(scores, y)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step % print_every == 0:
                print('Epoch %d, Iteration %d, loss = %.4f' % (e, step, loss.item()))
                acc = check_accuracy(loader_val, model)
                if acc > best_acc:
                    best_acc = acc
                    best_model_wts = copy.deepcopy(model.state_dict())
                fo = open("model_a.log", "a")
                fo.write("Epoch: {}\t Step: {}\t loss: {:.4f}\t accuracy: {:.2f}\n"\
                         .format(e, step, loss.item(), acc))
                fo.close()
                print()
        epoch_lst.append(e)
        loss_his.append(loss.item())
        acc_his.append(acc)
    
    plot(epoch_lst, loss_his, path="../results figure/", name="Model A_Loss accross Epoch", 
        xlabel="epoch", ylabel="loss")
    plot(epoch_lst, acc_his, path="../results figure/", name="Model A_Accuracy accross Epoch",
        xlabel="epoch", ylabel="accuracy")
                
    print("Best accuracy:", best_acc)
    fo = open("model_a.log", "a")
    fo.write("Best accuracy: {}".format(best_acc))
    fo.close()
    model.load_state_dict(best_model_wts)
    return model

# %%
lr_lst = [0.01]

fo = open("model_a.log", "w")
fo.write("Model A Trainning log\n")
fo.close()

for learning_rate in lr_lst:
    fo = open("model_a.log", "a")
    fo.write("\nOriginal Learning rate: {}\n".format(learning_rate))
    fo.close()
    print("Learning_rate:", learning_rate)
    model = Model(in_channel=3, channel_1=96, channel_2=192, 
             channel_3=192, channel_4=192, num_classes=10) 
    optimizer = optim.SGD(model.parameters(), lr = learning_rate, momentum=0.9, weight_decay=0.001)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                                               milestones=[200, 250, 300], gamma=0.1)
    best_model = train(model, optimizer, scheduler, epochs=350, best_acc=0.0)
    print()
# Out:
# Learning_rate: 0.01
# Epoch 0, Iteration 0, loss = 2.3023
# Checking accuracy on validation set
# Got 122 / 1000 correct (12.20)
#
# Epoch 0, Iteration 100, loss = 2.2496
# Checking accuracy on validation set
# Got 246 / 1000 correct (24.60)
#
# Epoch 0, Iteration 200, loss = 2.0139
# Checking accuracy on validation set
# Got 295 / 1000 correct (29.50)
#
# Epoch 0, Iteration 300, loss = 1.9867
# Checking accuracy on validation set
# Got 325 / 1000 correct (32.50)
#
# Epoch 0, Iteration 400, loss = 1.6896
# Checking accuracy on validation set
# Got 332 / 1000 correct (33.20)
#
# Epoch 0, Iteration 500, loss = 1.7971
# Checking accuracy on validation set
# Got 392 / 1000 correct (39.20)
#
# Epoch 0, Iteration 600, loss = 1.6612
# Checking accuracy on validation set
# Got 401 / 1000 correct (40.10)
#
# Epoch 0, Iteration 700, loss = 1.4894
# Checking accuracy on validation set
# Got 416 / 1000 correct (41.60)
#
# Epoch 1, Iteration 0, loss = 1.3058
# Checking accuracy on validation set
# Got 455 / 1000 correct (45.50)
#
# Epoch 1, Iteration 100, loss = 1.4079
# Checking accuracy on validation set
# Got 416 / 1000 correct (41.60)
#
# Epoch 1, Iteration 200, loss = 1.3570
# Checking accuracy on validation set
# Got 490 / 1000 correct (49.00)
#
# Epoch 1, Iteration 300, loss = 1.4456
# Checking accuracy on validation set
# Got 488 / 1000 correct (48.80)
#
# Epoch 1, Iteration 400, loss = 1.3000
# Checking accuracy on validation set
# Got 509 / 1000 correct (50.90)
#
# Epoch 1, Iteration 500, loss = 1.1741
# Checking accuracy on validation set
# Got 522 / 1000 correct (52.20)
#
# Epoch 1, Iteration 600, loss = 1.3583
# Checking accuracy on validation set
# Got 563 / 1000 correct (56.30)
#
# Epoch 1, Iteration 700, loss = 1.3336
# Checking accuracy on validation set
# Got 562 / 1000 correct (56.20)
#
# Epoch 2, Iteration 0, loss = 1.2958
# Checking accuracy on validation set
# Got 596 / 1000 correct (59.60)
#
# Epoch 2, Iteration 100, loss = 1.2060
# Checking accuracy on validation set
# Got 544 / 1000 correct (54.40)
#
# Epoch 2, Iteration 200, loss = 1.1281
# Checking accuracy on validation set
# Got 612 / 1000 correct (61.20)
#
# Epoch 2, Iteration 300, loss = 1.2000
# Checking accuracy on validation set
# Got 629 / 1000 correct (62.90)
#
# Epoch 2, Iteration 400, loss = 1.2235
# Checking accuracy on validation set
# Got 604 / 1000 correct (60.40)
#
# Epoch 2, Iteration 500, loss = 0.9392
# Checking accuracy on validation set
# Got 633 / 1000 correct (63.30)
#
# Epoch 2, Iteration 600, loss = 1.0751
# Checking accuracy on validation set
# Got 653 / 1000 correct (65.30)
#
# Epoch 2, Iteration 700, loss = 1.0806
# Checking accuracy on validation set
# Got 620 / 1000 correct (62.00)
#
# Epoch 3, Iteration 0, loss = 0.9724
# Checking accuracy on validation set
# Got 640 / 1000 correct (64.00)
#
# Epoch 3, Iteration 100, loss = 1.0114
# Checking accuracy on validation set
# Got 656 / 1000 correct (65.60)
#
# Epoch 3, Iteration 200, loss = 0.9489
# Checking accuracy on validation set
# Got 673 / 1000 correct (67.30)
#
# Epoch 3, Iteration 300, loss = 1.1030
# Checking accuracy on validation set
# Got 628 / 1000 correct (62.80)
#
# Epoch 3, Iteration 400, loss = 0.9099
# Checking accuracy on validation set
# Got 689 / 1000 correct (68.90)
#
# Epoch 3, Iteration 500, loss = 1.0443
# Checking accuracy on validation set
# Got 672 / 1000 correct (67.20)
#
# Epoch 3, Iteration 600, loss = 1.0785
# Checking accuracy on validation set
# Got 672 / 1000 correct (67.20)
#
# Epoch 3, Iteration 700, loss = 0.9086
# Checking accuracy on validation set
# Got 703 / 1000 correct (70.30)
#
# Epoch 4, Iteration 0, loss = 0.9754
# Checking accuracy on validation set
# Got 674 / 1000 correct (67.40)
#
# Epoch 4, Iteration 100, loss = 0.8487
# Checking accuracy on validation set
# Got 693 / 1000 correct (69.30)
#
# Epoch 4, Iteration 200, loss = 0.6846
# Checking accuracy on validation set
# Got 710 / 1000 correct (71.00)
#
# Epoch 4, Iteration 300, loss = 0.7712
# Checking accuracy on validation set
# Got 697 / 1000 correct (69.70)
#
# Epoch 4, Iteration 400, loss = 0.7067
# Checking accuracy on validation set
# Got 696 / 1000 correct (69.60)
#
# Epoch 4, Iteration 500, loss = 0.8509
# Checking accuracy on validation set
# Got 711 / 1000 correct (71.10)
#
# Epoch 4, Iteration 600, loss = 0.8821
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
#
# Epoch 4, Iteration 700, loss = 0.9604
# Checking accuracy on validation set
# Got 647 / 1000 correct (64.70)
#
# Epoch 5, Iteration 0, loss = 0.8724
# Checking accuracy on validation set
# Got 742 / 1000 correct (74.20)
#
# Epoch 5, Iteration 100, loss = 0.7000
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
#
# Epoch 5, Iteration 200, loss = 0.5074
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
#
# Epoch 5, Iteration 300, loss = 0.8545
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
#
# Epoch 5, Iteration 400, loss = 0.6333
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
#
# Epoch 5, Iteration 500, loss = 1.0010
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
#
# Epoch 5, Iteration 600, loss = 0.7383
# Checking accuracy on validation set
# Got 714 / 1000 correct (71.40)
#
# Epoch 5, Iteration 700, loss = 0.7704
# Checking accuracy on validation set
# Got 715 / 1000 correct (71.50)
#
# Epoch 6, Iteration 0, loss = 0.6066
# Checking accuracy on validation set
# Got 741 / 1000 correct (74.10)
#
# Epoch 6, Iteration 100, loss = 0.6332
# Checking accuracy on validation set
# Got 746 / 1000 correct (74.60)
#
# Epoch 6, Iteration 200, loss = 0.5932
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
#
# Epoch 6, Iteration 300, loss = 0.5830
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
#
# Epoch 6, Iteration 400, loss = 0.6495
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
#
# Epoch 6, Iteration 500, loss = 0.5452
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
#
# Epoch 6, Iteration 600, loss = 0.5747
# Checking accuracy on validation set
# Got 742 / 1000 correct (74.20)
#
# Epoch 6, Iteration 700, loss = 0.7250
# Checking accuracy on validation set
# Got 746 / 1000 correct (74.60)
#
# Epoch 7, Iteration 0, loss = 0.6795
# Checking accuracy on validation set
# Got 735 / 1000 correct (73.50)
#
# Epoch 7, Iteration 100, loss = 0.6369
# Checking accuracy on validation set
# Got 729 / 1000 correct (72.90)
#
# Epoch 7, Iteration 200, loss = 0.5769
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
#
# Epoch 7, Iteration 300, loss = 0.6138
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
#
# Epoch 7, Iteration 400, loss = 0.6687
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
#
# Epoch 7, Iteration 500, loss = 0.6182
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
#
# Epoch 7, Iteration 600, loss = 0.6892
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Epoch 7, Iteration 700, loss = 0.4477
# Checking accuracy on validation set
# Got 760 / 1000 correct (76.00)
#
# Epoch 8, Iteration 0, loss = 0.5011
# Checking accuracy on validation set
# Got 771 / 1000 correct (77.10)
#
# Epoch 8, Iteration 100, loss = 0.5746
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
#
# Epoch 8, Iteration 200, loss = 0.4254
# Checking accuracy on validation set
# Got 731 / 1000 correct (73.10)
#
# Epoch 8, Iteration 300, loss = 0.3788
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
#
# Epoch 8, Iteration 400, loss = 0.4258
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
#
# Epoch 8, Iteration 500, loss = 0.8597
# Checking accuracy on validation set
# Got 761 / 1000 correct (76.10)
#
# Epoch 8, Iteration 600, loss = 0.6385
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Epoch 8, Iteration 700, loss = 0.4787
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 9, Iteration 0, loss = 0.5206
# Checking accuracy on validation set
# Got 767 / 1000 correct (76.70)
#
# Epoch 9, Iteration 100, loss = 0.5747
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
#
# Epoch 9, Iteration 200, loss = 0.6597
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
#
# Epoch 9, Iteration 300, loss = 0.4753
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
#
# Epoch 9, Iteration 400, loss = 0.7370
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
#
# Epoch 9, Iteration 500, loss = 0.8273
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
#
# Epoch 9, Iteration 600, loss = 0.5104
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 9, Iteration 700, loss = 0.6009
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
#
# Epoch 10, Iteration 0, loss = 0.4967
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
#
# Epoch 10, Iteration 100, loss = 0.4590
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 10, Iteration 200, loss = 0.3107
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 10, Iteration 300, loss = 0.4546
# Checking accuracy on validation set
# Got 768 / 1000 correct (76.80)
#
# Epoch 10, Iteration 400, loss = 0.5931
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 10, Iteration 500, loss = 0.5246
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
#
# Epoch 10, Iteration 600, loss = 0.6509
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
#
# Epoch 10, Iteration 700, loss = 0.6643
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 11, Iteration 0, loss = 0.5365
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
#
# Epoch 11, Iteration 100, loss = 0.3857
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 11, Iteration 200, loss = 0.4808
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
#
# Epoch 11, Iteration 300, loss = 0.5994
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
#
# Epoch 11, Iteration 400, loss = 0.4876
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Epoch 11, Iteration 500, loss = 0.6133
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 11, Iteration 600, loss = 0.4154
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
#
# Epoch 11, Iteration 700, loss = 0.4958
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
#
# Epoch 12, Iteration 0, loss = 0.4781
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
#
# Epoch 12, Iteration 100, loss = 0.4322
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 12, Iteration 200, loss = 0.3763
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 12, Iteration 300, loss = 0.5061
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Epoch 12, Iteration 400, loss = 0.3354
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Epoch 12, Iteration 500, loss = 0.4059
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Epoch 12, Iteration 600, loss = 0.4529
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 12, Iteration 700, loss = 0.3731
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 13, Iteration 0, loss = 0.3570
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 13, Iteration 100, loss = 0.3621
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 13, Iteration 200, loss = 0.2794
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
#
# Epoch 13, Iteration 300, loss = 0.2395
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 13, Iteration 400, loss = 0.4278
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
#
# Epoch 13, Iteration 500, loss = 0.5083
# Checking accuracy on validation set
# Got 749 / 1000 correct (74.90)
#
# Epoch 13, Iteration 600, loss = 0.3607
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Epoch 13, Iteration 700, loss = 0.4724
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
#
# Epoch 14, Iteration 0, loss = 0.2627
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 14, Iteration 100, loss = 0.3258
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 14, Iteration 200, loss = 0.4674
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 14, Iteration 300, loss = 0.5038
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 14, Iteration 400, loss = 0.3215
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 14, Iteration 500, loss = 0.5341
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 14, Iteration 600, loss = 0.4400
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 14, Iteration 700, loss = 0.4029
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 15, Iteration 0, loss = 0.3501
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 15, Iteration 100, loss = 0.3526
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Epoch 15, Iteration 200, loss = 0.2859
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
#
# Epoch 15, Iteration 300, loss = 0.2625
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 15, Iteration 400, loss = 0.5579
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Epoch 15, Iteration 500, loss = 0.4084
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 15, Iteration 600, loss = 0.3118
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
#
# Epoch 15, Iteration 700, loss = 0.3755
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 16, Iteration 0, loss = 0.5329
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 16, Iteration 100, loss = 0.3281
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Epoch 16, Iteration 200, loss = 0.1477
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 16, Iteration 300, loss = 0.3531
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 16, Iteration 400, loss = 0.3903
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Epoch 16, Iteration 500, loss = 0.3979
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
#
# Epoch 16, Iteration 600, loss = 0.3857
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
#
# Epoch 16, Iteration 700, loss = 0.4333
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 17, Iteration 0, loss = 0.2417
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
#
# Epoch 17, Iteration 100, loss = 0.4444
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 17, Iteration 200, loss = 0.2290
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 17, Iteration 300, loss = 0.4391
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 17, Iteration 400, loss = 0.2806
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
#
# Epoch 17, Iteration 500, loss = 0.3350
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 17, Iteration 600, loss = 0.3039
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 17, Iteration 700, loss = 0.2333
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 18, Iteration 0, loss = 0.5245
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 18, Iteration 100, loss = 0.2140
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 18, Iteration 200, loss = 0.3501
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 18, Iteration 300, loss = 0.4192
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Epoch 18, Iteration 400, loss = 0.2274
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 18, Iteration 500, loss = 0.3262
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 18, Iteration 600, loss = 0.2456
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 18, Iteration 700, loss = 0.3575
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 19, Iteration 0, loss = 0.1349
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
#
# Epoch 19, Iteration 100, loss = 0.2853
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 19, Iteration 200, loss = 0.3040
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
#
# Epoch 19, Iteration 300, loss = 0.2268
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 19, Iteration 400, loss = 0.2326
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 19, Iteration 500, loss = 0.3684
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 19, Iteration 600, loss = 0.3689
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 19, Iteration 700, loss = 0.2054
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 20, Iteration 0, loss = 0.2476
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 20, Iteration 100, loss = 0.1785
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 20, Iteration 200, loss = 0.3103
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 20, Iteration 300, loss = 0.2981
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 20, Iteration 400, loss = 0.3592
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 20, Iteration 500, loss = 0.2787
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 20, Iteration 600, loss = 0.2997
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 20, Iteration 700, loss = 0.3283
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 21, Iteration 0, loss = 0.3092
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 21, Iteration 100, loss = 0.3024
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 21, Iteration 200, loss = 0.2791
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
#
# Epoch 21, Iteration 300, loss = 0.2769
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 21, Iteration 400, loss = 0.2151
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 21, Iteration 500, loss = 0.2589
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 21, Iteration 600, loss = 0.1947
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 21, Iteration 700, loss = 0.2410
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 22, Iteration 0, loss = 0.2448
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 22, Iteration 100, loss = 0.2086
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 22, Iteration 200, loss = 0.0969
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 22, Iteration 300, loss = 0.1076
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 22, Iteration 400, loss = 0.2864
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Epoch 22, Iteration 500, loss = 0.4138
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Epoch 22, Iteration 600, loss = 0.3792
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Epoch 22, Iteration 700, loss = 0.2137
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Epoch 23, Iteration 0, loss = 0.1229
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 23, Iteration 100, loss = 0.2151
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Epoch 23, Iteration 200, loss = 0.1543
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Epoch 23, Iteration 300, loss = 0.3220
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 23, Iteration 400, loss = 0.4696
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Epoch 23, Iteration 500, loss = 0.3362
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Epoch 23, Iteration 600, loss = 0.1698
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 23, Iteration 700, loss = 0.4157
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 24, Iteration 0, loss = 0.2345
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Epoch 24, Iteration 100, loss = 0.2471
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Epoch 24, Iteration 200, loss = 0.3026
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 24, Iteration 300, loss = 0.2675
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Epoch 24, Iteration 400, loss = 0.3600
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 24, Iteration 500, loss = 0.2015
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Epoch 24, Iteration 600, loss = 0.2200
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Epoch 24, Iteration 700, loss = 0.3741
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Epoch 25, Iteration 0, loss = 0.3400
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 25, Iteration 100, loss = 0.2403
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 25, Iteration 200, loss = 0.2293
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 25, Iteration 300, loss = 0.2132
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 25, Iteration 400, loss = 0.2641
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 25, Iteration 500, loss = 0.3424
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 25, Iteration 600, loss = 0.3179
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Epoch 25, Iteration 700, loss = 0.2374
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 26, Iteration 0, loss = 0.4197
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 26, Iteration 100, loss = 0.2134
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Epoch 26, Iteration 200, loss = 0.2386
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Epoch 26, Iteration 300, loss = 0.1996
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Epoch 26, Iteration 400, loss = 0.1261
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 26, Iteration 500, loss = 0.3375
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 26, Iteration 600, loss = 0.2156
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 26, Iteration 700, loss = 0.3143
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 27, Iteration 0, loss = 0.1883
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Epoch 27, Iteration 100, loss = 0.1422
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 27, Iteration 200, loss = 0.3090
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Epoch 27, Iteration 300, loss = 0.2588
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 27, Iteration 400, loss = 0.2646
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Epoch 27, Iteration 500, loss = 0.1404
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Epoch 27, Iteration 600, loss = 0.2509
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Epoch 27, Iteration 700, loss = 0.1698
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 28, Iteration 0, loss = 0.3593
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Epoch 28, Iteration 100, loss = 0.1868
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Epoch 28, Iteration 200, loss = 0.2406
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Epoch 28, Iteration 300, loss = 0.2804
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Epoch 28, Iteration 400, loss = 0.3505
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Epoch 28, Iteration 500, loss = 0.2631
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Epoch 28, Iteration 600, loss = 0.2966
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Epoch 28, Iteration 700, loss = 0.1621
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Epoch 29, Iteration 0, loss = 0.1080
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Epoch 29, Iteration 100, loss = 0.1467
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Epoch 29, Iteration 200, loss = 0.2157
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Epoch 29, Iteration 300, loss = 0.3415
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Epoch 29, Iteration 400, loss = 0.1708
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)

# %%
PATH = "../best_model/"
model_name = "best_model_a.pt"
if not os.path.exists(PATH):
    os.mkdir(PATH)
torch.save(best_model.state_dict(), PATH + model_name)
