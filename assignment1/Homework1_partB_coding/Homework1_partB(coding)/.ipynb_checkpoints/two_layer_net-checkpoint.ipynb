# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

from __future__ import print_function

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.6802720745909845e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.7985612998927536e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W2 max relative error: 3.440708e-09
# b2 max relative error: 4.447646e-11
# W1 max relative error: 3.561318e-09
# b1 max relative error: 2.738421e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.017149607938732048

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.259602
# iteration 400 / 1000: loss 2.204170
# iteration 500 / 1000: loss 2.118565
# iteration 600 / 1000: loss 2.051535
# iteration 700 / 1000: loss 1.988466
# iteration 800 / 1000: loss 2.006591
# iteration 900 / 1000: loss 1.951473
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
# fig, axes = plt.subplots(nrows=2, ncols=1)
# fig.tight_layout()
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
best_val = -1
best_stats = None
learning_rates = [1e-3, 1e-4]
regularization_strengths = [1e-1, 1e-2, 1e-3, 1e-4]
batch_sizes = [200, 400, 800]
hidden_sizes = [80, 160, 320]
results = {}
num_iters = 1000
i = 0
for lr in learning_rates:
    for rs in regularization_strengths:
        for bs in batch_sizes:
            for hs in hidden_sizes:
                print('Train {}th module'.format(i))
                net = TwoLayerNet(input_size, hs, num_classes)
                # Train the network
                stats = net.train(X_train, y_train, X_val, y_val,
                            num_iters=num_iters, batch_size=bs,
                            learning_rate=lr, learning_rate_decay=0.95,
                            reg=rs, verbose=True)
                y_train_pred = net.predict(X_train)
                acc_train = np.mean(y_train == y_train_pred)
                y_val_pred = net.predict(X_val)
                acc_val = np.mean(y_val == y_val_pred)
                results[(lr, rs, bs, hs)] = (acc_train, acc_val)
                if best_val < acc_val:
                    best_stats = stats
                    best_val = acc_val
                    best_net = net
                print('lr %e reg %e bs %e hs %e train accuracy: %f val accuracy: %f' % (
                lr, reg, bs, hs train_accuracy, val_accuracy))
                i += 1
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# for lr, reg, bs, hs in sorted(results):
#     train_accuracy, val_accuracy = results[(lr, reg, bs, hs)]
   
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# Train 0th module
# iteration 0 / 1000: loss 2.302802
# iteration 100 / 1000: loss 1.830393
# iteration 200 / 1000: loss 1.901714
# iteration 300 / 1000: loss 1.766513
# iteration 400 / 1000: loss 1.550016
# iteration 500 / 1000: loss 1.572420
# iteration 600 / 1000: loss 1.556419
# iteration 700 / 1000: loss 1.615722
# iteration 800 / 1000: loss 1.384912
# iteration 900 / 1000: loss 1.381274
# lr 1.000000e-03 reg 1.000000e-01 bs 2.000000e+02 hs 8.000000e+01 train accuracy: 0.491980 val accuracy: 0.464000
#
# Train 1th module
# iteration 0 / 1000: loss 2.303050
# iteration 100 / 1000: loss 1.965608
# iteration 200 / 1000: loss 1.779631
# iteration 300 / 1000: loss 1.679294
# iteration 400 / 1000: loss 1.593090
# iteration 500 / 1000: loss 1.529344
# iteration 600 / 1000: loss 1.563856
# iteration 700 / 1000: loss 1.625965
# iteration 800 / 1000: loss 1.369850
# iteration 900 / 1000: loss 1.368548
# lr 1.000000e-03 reg 1.000000e-01 bs 2.000000e+02 hs 1.600000e+02 train accuracy: 0.510898 val accuracy: 0.488000
#
# Train 2th module
# iteration 0 / 1000: loss 2.303528
# iteration 100 / 1000: loss 1.903600
# iteration 200 / 1000: loss 1.637191
# iteration 300 / 1000: loss 1.644838
# iteration 400 / 1000: loss 1.573476
# iteration 500 / 1000: loss 1.550664
# iteration 600 / 1000: loss 1.450847
# iteration 700 / 1000: loss 1.450555
# iteration 800 / 1000: loss 1.440362
# iteration 900 / 1000: loss 1.431873
# lr 1.000000e-03 reg 1.000000e-01 bs 2.000000e+02 hs 3.200000e+02 train accuracy: 0.511041 val accuracy: 0.477000
#
# Train 3th module
# iteration 0 / 1000: loss 2.302835
# iteration 100 / 1000: loss 1.927402
# iteration 200 / 1000: loss 1.708232
# iteration 300 / 1000: loss 1.697034
# iteration 400 / 1000: loss 1.519277
# iteration 500 / 1000: loss 1.601256
# iteration 600 / 1000: loss 1.509648
# iteration 700 / 1000: loss 1.540590
# iteration 800 / 1000: loss 1.491608
# iteration 900 / 1000: loss 1.459943
# lr 1.000000e-03 reg 1.000000e-01 bs 4.000000e+02 hs 8.000000e+01 train accuracy: 0.514449 val accuracy: 0.494000
#
# Train 4th module
# iteration 0 / 1000: loss 2.303092
# iteration 100 / 1000: loss 1.933021
# iteration 200 / 1000: loss 1.772388
# iteration 300 / 1000: loss 1.654728
# iteration 400 / 1000: loss 1.641777
# iteration 500 / 1000: loss 1.593637
# iteration 600 / 1000: loss 1.494591
# iteration 700 / 1000: loss 1.519664
# iteration 800 / 1000: loss 1.455360
# iteration 900 / 1000: loss 1.403491
# lr 1.000000e-03 reg 1.000000e-01 bs 4.000000e+02 hs 1.600000e+02 train accuracy: 0.525449 val accuracy: 0.502000
#
# Train 5th module
# iteration 0 / 1000: loss 2.303637
# iteration 100 / 1000: loss 1.934927
# iteration 200 / 1000: loss 1.806251
# iteration 300 / 1000: loss 1.588448
# iteration 400 / 1000: loss 1.496871
# iteration 500 / 1000: loss 1.477696
# iteration 600 / 1000: loss 1.500027
# iteration 700 / 1000: loss 1.388791
# iteration 800 / 1000: loss 1.412684
# iteration 900 / 1000: loss 1.533734
# lr 1.000000e-03 reg 1.000000e-01 bs 4.000000e+02 hs 3.200000e+02 train accuracy: 0.534796 val accuracy: 0.494000
#
# Train 6th module
# iteration 0 / 1000: loss 2.302863
# iteration 100 / 1000: loss 1.898350
# iteration 200 / 1000: loss 1.717592
# iteration 300 / 1000: loss 1.682682
# iteration 400 / 1000: loss 1.560112
# iteration 500 / 1000: loss 1.554598
# iteration 600 / 1000: loss 1.536116
# iteration 700 / 1000: loss 1.539092
# iteration 800 / 1000: loss 1.418347
# iteration 900 / 1000: loss 1.493139
# lr 1.000000e-03 reg 1.000000e-01 bs 8.000000e+02 hs 8.000000e+01 train accuracy: 0.515388 val accuracy: 0.497000
#
# Train 7th module
# iteration 0 / 1000: loss 2.303076
# iteration 100 / 1000: loss 1.910639
# iteration 200 / 1000: loss 1.739062
# iteration 300 / 1000: loss 1.694082
# iteration 400 / 1000: loss 1.624929
# iteration 500 / 1000: loss 1.523682
# iteration 600 / 1000: loss 1.504795
# iteration 700 / 1000: loss 1.455399
# iteration 800 / 1000: loss 1.412157
# iteration 900 / 1000: loss 1.352605
# lr 1.000000e-03 reg 1.000000e-01 bs 8.000000e+02 hs 1.600000e+02 train accuracy: 0.533429 val accuracy: 0.496000
#
# Train 8th module
# iteration 0 / 1000: loss 2.303591
# iteration 100 / 1000: loss 1.893158
# iteration 200 / 1000: loss 1.749052
# iteration 300 / 1000: loss 1.613375
# iteration 400 / 1000: loss 1.570371
# iteration 500 / 1000: loss 1.453784
# iteration 600 / 1000: loss 1.483568
# iteration 700 / 1000: loss 1.412335
# iteration 800 / 1000: loss 1.473562
# iteration 900 / 1000: loss 1.381345
# lr 1.000000e-03 reg 1.000000e-01 bs 8.000000e+02 hs 3.200000e+02 train accuracy: 0.542959 val accuracy: 0.499000
#
# Train 9th module
# iteration 0 / 1000: loss 2.302630
# iteration 100 / 1000: loss 1.915114
# iteration 200 / 1000: loss 1.715445
# iteration 300 / 1000: loss 1.759495
# iteration 400 / 1000: loss 1.668780
# iteration 500 / 1000: loss 1.528597
# iteration 600 / 1000: loss 1.489340
# iteration 700 / 1000: loss 1.464660
# iteration 800 / 1000: loss 1.448771
# iteration 900 / 1000: loss 1.406780
# lr 1.000000e-03 reg 1.000000e-02 bs 2.000000e+02 hs 8.000000e+01 train accuracy: 0.493898 val accuracy: 0.451000
#
# Train 10th module
# iteration 0 / 1000: loss 2.302645
# iteration 100 / 1000: loss 1.881135
# iteration 200 / 1000: loss 1.727380
# iteration 300 / 1000: loss 1.704689
# iteration 400 / 1000: loss 1.565136
# iteration 500 / 1000: loss 1.560265
# iteration 600 / 1000: loss 1.478774
# iteration 700 / 1000: loss 1.460654
# iteration 800 / 1000: loss 1.399929
# iteration 900 / 1000: loss 1.296127
# lr 1.000000e-03 reg 1.000000e-02 bs 2.000000e+02 hs 1.600000e+02 train accuracy: 0.513653 val accuracy: 0.491000
#
# Train 11th module
# iteration 0 / 1000: loss 2.302738
# iteration 100 / 1000: loss 1.914200
# iteration 200 / 1000: loss 1.698182
# iteration 300 / 1000: loss 1.619836
# iteration 400 / 1000: loss 1.697684
# iteration 500 / 1000: loss 1.507364
# iteration 600 / 1000: loss 1.605458
# iteration 700 / 1000: loss 1.474802
# iteration 800 / 1000: loss 1.454903
# iteration 900 / 1000: loss 1.391837
# lr 1.000000e-03 reg 1.000000e-02 bs 2.000000e+02 hs 3.200000e+02 train accuracy: 0.518388 val accuracy: 0.484000
#
# Train 12th module
# iteration 0 / 1000: loss 2.302628
# iteration 100 / 1000: loss 1.908137
# iteration 200 / 1000: loss 1.782651
# iteration 300 / 1000: loss 1.593467
# iteration 400 / 1000: loss 1.619192
# iteration 500 / 1000: loss 1.466300
# iteration 600 / 1000: loss 1.595630
# iteration 700 / 1000: loss 1.454136
# iteration 800 / 1000: loss 1.396448
# iteration 900 / 1000: loss 1.352075
# lr 1.000000e-03 reg 1.000000e-02 bs 4.000000e+02 hs 8.000000e+01 train accuracy: 0.518551 val accuracy: 0.482000
#
# Train 13th module
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 1.845898
# iteration 200 / 1000: loss 1.670916
# iteration 300 / 1000: loss 1.660880
# iteration 400 / 1000: loss 1.613298
# iteration 500 / 1000: loss 1.548932
# iteration 600 / 1000: loss 1.541050
# iteration 700 / 1000: loss 1.462936
# iteration 800 / 1000: loss 1.450704
# iteration 900 / 1000: loss 1.466225
# lr 1.000000e-03 reg 1.000000e-02 bs 4.000000e+02 hs 1.600000e+02 train accuracy: 0.521082 val accuracy: 0.478000
#
# Train 14th module
# iteration 0 / 1000: loss 2.302655
# iteration 100 / 1000: loss 1.882082
# iteration 200 / 1000: loss 1.663477
# iteration 300 / 1000: loss 1.676904
# iteration 400 / 1000: loss 1.572803
# iteration 500 / 1000: loss 1.496264
# iteration 600 / 1000: loss 1.431121
# iteration 700 / 1000: loss 1.388667
# iteration 800 / 1000: loss 1.360246
# iteration 900 / 1000: loss 1.438570
# lr 1.000000e-03 reg 1.000000e-02 bs 4.000000e+02 hs 3.200000e+02 train accuracy: 0.537918 val accuracy: 0.497000
#
# Train 15th module
# iteration 0 / 1000: loss 2.302591
# iteration 100 / 1000: loss 1.921701
# iteration 200 / 1000: loss 1.690675
# iteration 300 / 1000: loss 1.645628
# iteration 400 / 1000: loss 1.557138
# iteration 500 / 1000: loss 1.518938
# iteration 600 / 1000: loss 1.508381
# iteration 700 / 1000: loss 1.429674
# iteration 800 / 1000: loss 1.461401
# iteration 900 / 1000: loss 1.377159
# lr 1.000000e-03 reg 1.000000e-02 bs 8.000000e+02 hs 8.000000e+01 train accuracy: 0.523653 val accuracy: 0.498000
#
# Train 16th module
# iteration 0 / 1000: loss 2.302648
# iteration 100 / 1000: loss 1.910752
# iteration 200 / 1000: loss 1.734887
# iteration 300 / 1000: loss 1.623622
# iteration 400 / 1000: loss 1.571841
# iteration 500 / 1000: loss 1.523988
# iteration 600 / 1000: loss 1.461423
# iteration 700 / 1000: loss 1.448692
# iteration 800 / 1000: loss 1.303693
# iteration 900 / 1000: loss 1.388222
# lr 1.000000e-03 reg 1.000000e-02 bs 8.000000e+02 hs 1.600000e+02 train accuracy: 0.539000 val accuracy: 0.507000
#
# Train 17th module
# iteration 0 / 1000: loss 2.302666
# iteration 100 / 1000: loss 1.863301
# iteration 200 / 1000: loss 1.722161
# iteration 300 / 1000: loss 1.568023
# iteration 400 / 1000: loss 1.483045
# iteration 500 / 1000: loss 1.518561
# iteration 600 / 1000: loss 1.471167
# iteration 700 / 1000: loss 1.410912
# iteration 800 / 1000: loss 1.341847
# iteration 900 / 1000: loss 1.359425
# lr 1.000000e-03 reg 1.000000e-02 bs 8.000000e+02 hs 3.200000e+02 train accuracy: 0.547102 val accuracy: 0.514000
#
# Train 18th module
# iteration 0 / 1000: loss 2.302557
# iteration 100 / 1000: loss 1.967349
# iteration 200 / 1000: loss 1.711518
# iteration 300 / 1000: loss 1.703025
# iteration 400 / 1000: loss 1.708903
# iteration 500 / 1000: loss 1.633010
# iteration 600 / 1000: loss 1.480699
# iteration 700 / 1000: loss 1.504234
# iteration 800 / 1000: loss 1.507616
# iteration 900 / 1000: loss 1.442532
# lr 1.000000e-03 reg 1.000000e-03 bs 2.000000e+02 hs 8.000000e+01 train accuracy: 0.505776 val accuracy: 0.471000
#
# Train 19th module
# iteration 0 / 1000: loss 2.302615
# iteration 100 / 1000: loss 1.948148
# iteration 200 / 1000: loss 1.851589
# iteration 300 / 1000: loss 1.625631
# iteration 400 / 1000: loss 1.475511
# iteration 500 / 1000: loss 1.450219
# iteration 600 / 1000: loss 1.429147
# iteration 700 / 1000: loss 1.573331
# iteration 800 / 1000: loss 1.581513
# iteration 900 / 1000: loss 1.340181
# lr 1.000000e-03 reg 1.000000e-03 bs 2.000000e+02 hs 1.600000e+02 train accuracy: 0.507653 val accuracy: 0.480000
#
# Train 20th module
# iteration 0 / 1000: loss 2.302575
# iteration 100 / 1000: loss 1.839175
# iteration 200 / 1000: loss 1.744214
# iteration 300 / 1000: loss 1.692826
# iteration 400 / 1000: loss 1.544430
# iteration 500 / 1000: loss 1.646433
# iteration 600 / 1000: loss 1.566783
# iteration 700 / 1000: loss 1.545656
# iteration 800 / 1000: loss 1.415597
# iteration 900 / 1000: loss 1.380148
# lr 1.000000e-03 reg 1.000000e-03 bs 2.000000e+02 hs 3.200000e+02 train accuracy: 0.526653 val accuracy: 0.504000
#
# Train 21th module
# iteration 0 / 1000: loss 2.302594
# iteration 100 / 1000: loss 1.841762
# iteration 200 / 1000: loss 1.692569
# iteration 300 / 1000: loss 1.657394
# iteration 400 / 1000: loss 1.623537
# iteration 500 / 1000: loss 1.611007
# iteration 600 / 1000: loss 1.517668
# iteration 700 / 1000: loss 1.388985
# iteration 800 / 1000: loss 1.443554
# iteration 900 / 1000: loss 1.469289
# lr 1.000000e-03 reg 1.000000e-03 bs 4.000000e+02 hs 8.000000e+01 train accuracy: 0.518939 val accuracy: 0.490000
#
# Train 22th module
# iteration 0 / 1000: loss 2.302581
# iteration 100 / 1000: loss 1.882432
# iteration 200 / 1000: loss 1.730562
# iteration 300 / 1000: loss 1.732961
# iteration 400 / 1000: loss 1.540485
# iteration 500 / 1000: loss 1.541091
# iteration 600 / 1000: loss 1.524591
# iteration 700 / 1000: loss 1.381290
# iteration 800 / 1000: loss 1.515489
# iteration 900 / 1000: loss 1.343496
# lr 1.000000e-03 reg 1.000000e-03 bs 4.000000e+02 hs 1.600000e+02 train accuracy: 0.531980 val accuracy: 0.493000
#
# Train 23th module
# iteration 0 / 1000: loss 2.302611
# iteration 100 / 1000: loss 1.867243
# iteration 200 / 1000: loss 1.770576
# iteration 300 / 1000: loss 1.658747
# iteration 400 / 1000: loss 1.492260
# iteration 500 / 1000: loss 1.519912
# iteration 600 / 1000: loss 1.441217
# iteration 700 / 1000: loss 1.441774
# iteration 800 / 1000: loss 1.493742
# iteration 900 / 1000: loss 1.299048
# lr 1.000000e-03 reg 1.000000e-03 bs 4.000000e+02 hs 3.200000e+02 train accuracy: 0.538612 val accuracy: 0.514000
#
# Train 24th module
# iteration 0 / 1000: loss 2.302581
# iteration 100 / 1000: loss 1.930933
# iteration 200 / 1000: loss 1.721286
# iteration 300 / 1000: loss 1.649919
# iteration 400 / 1000: loss 1.613941
# iteration 500 / 1000: loss 1.539966
# iteration 600 / 1000: loss 1.478979
# iteration 700 / 1000: loss 1.436100
# iteration 800 / 1000: loss 1.388377
# iteration 900 / 1000: loss 1.391893
# lr 1.000000e-03 reg 1.000000e-03 bs 8.000000e+02 hs 8.000000e+01 train accuracy: 0.515510 val accuracy: 0.481000
#
# Train 25th module
# iteration 0 / 1000: loss 2.302584
# iteration 100 / 1000: loss 1.920508
# iteration 200 / 1000: loss 1.756560
# iteration 300 / 1000: loss 1.585442
# iteration 400 / 1000: loss 1.527487
# iteration 500 / 1000: loss 1.471746
# iteration 600 / 1000: loss 1.456055
# iteration 700 / 1000: loss 1.407952
# iteration 800 / 1000: loss 1.419713
# iteration 900 / 1000: loss 1.299017
# lr 1.000000e-03 reg 1.000000e-03 bs 8.000000e+02 hs 1.600000e+02 train accuracy: 0.535490 val accuracy: 0.490000
#
# Train 26th module
# iteration 0 / 1000: loss 2.302598
# iteration 100 / 1000: loss 1.867841
# iteration 200 / 1000: loss 1.687671
# iteration 300 / 1000: loss 1.562641
# iteration 400 / 1000: loss 1.507202
# iteration 500 / 1000: loss 1.480959
# iteration 600 / 1000: loss 1.443170
# iteration 700 / 1000: loss 1.378382
# iteration 800 / 1000: loss 1.268410
# iteration 900 / 1000: loss 1.347210
# lr 1.000000e-03 reg 1.000000e-03 bs 8.000000e+02 hs 3.200000e+02 train accuracy: 0.549408 val accuracy: 0.515000
#
# Train 27th module
# iteration 0 / 1000: loss 2.302582
# iteration 100 / 1000: loss 1.918194
# iteration 200 / 1000: loss 1.780849
# iteration 300 / 1000: loss 1.631987
# iteration 400 / 1000: loss 1.648663
# iteration 500 / 1000: loss 1.459689
# iteration 600 / 1000: loss 1.475020
# iteration 700 / 1000: loss 1.534402
# iteration 800 / 1000: loss 1.380774
# iteration 900 / 1000: loss 1.381004
# lr 1.000000e-03 reg 1.000000e-04 bs 2.000000e+02 hs 8.000000e+01 train accuracy: 0.505816 val accuracy: 0.472000
#
# Train 28th module
# iteration 0 / 1000: loss 2.302601
# iteration 100 / 1000: loss 1.922105
# iteration 200 / 1000: loss 1.833822
# iteration 300 / 1000: loss 1.676621
# iteration 400 / 1000: loss 1.496993
# iteration 500 / 1000: loss 1.578385
# iteration 600 / 1000: loss 1.644324
# iteration 700 / 1000: loss 1.511920
# iteration 800 / 1000: loss 1.401235
# iteration 900 / 1000: loss 1.444529
# lr 1.000000e-03 reg 1.000000e-04 bs 2.000000e+02 hs 1.600000e+02 train accuracy: 0.506327 val accuracy: 0.485000
#
# Train 29th module
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.891965
# iteration 200 / 1000: loss 1.762356
# iteration 300 / 1000: loss 1.530022
# iteration 400 / 1000: loss 1.595994
# iteration 500 / 1000: loss 1.543927
# iteration 600 / 1000: loss 1.471506
# iteration 700 / 1000: loss 1.257418
# iteration 800 / 1000: loss 1.448039
# iteration 900 / 1000: loss 1.425776
# lr 1.000000e-03 reg 1.000000e-04 bs 2.000000e+02 hs 3.200000e+02 train accuracy: 0.519327 val accuracy: 0.492000
#
# Train 30th module
# iteration 0 / 1000: loss 2.302617
# iteration 100 / 1000: loss 1.937910
# iteration 200 / 1000: loss 1.818084
# iteration 300 / 1000: loss 1.598113
# iteration 400 / 1000: loss 1.514655
# iteration 500 / 1000: loss 1.543671
# iteration 600 / 1000: loss 1.471473
# iteration 700 / 1000: loss 1.512930
# iteration 800 / 1000: loss 1.378324
# iteration 900 / 1000: loss 1.426308
# lr 1.000000e-03 reg 1.000000e-04 bs 4.000000e+02 hs 8.000000e+01 train accuracy: 0.518612 val accuracy: 0.480000
#
# Train 31th module
# iteration 0 / 1000: loss 2.302546
# iteration 100 / 1000: loss 1.927678
# iteration 200 / 1000: loss 1.753985
# iteration 300 / 1000: loss 1.630423
# iteration 400 / 1000: loss 1.546012
# iteration 500 / 1000: loss 1.472964
# iteration 600 / 1000: loss 1.475687
# iteration 700 / 1000: loss 1.427831
# iteration 800 / 1000: loss 1.431332
# iteration 900 / 1000: loss 1.455966
# lr 1.000000e-03 reg 1.000000e-04 bs 4.000000e+02 hs 1.600000e+02 train accuracy: 0.524102 val accuracy: 0.483000
#
# Train 32th module
# iteration 0 / 1000: loss 2.302677
# iteration 100 / 1000: loss 1.863754
# iteration 200 / 1000: loss 1.686330
# iteration 300 / 1000: loss 1.747590
# iteration 400 / 1000: loss 1.551810
# iteration 500 / 1000: loss 1.569806
# iteration 600 / 1000: loss 1.477177
# iteration 700 / 1000: loss 1.463812
# iteration 800 / 1000: loss 1.422151
# iteration 900 / 1000: loss 1.418372
# lr 1.000000e-03 reg 1.000000e-04 bs 4.000000e+02 hs 3.200000e+02 train accuracy: 0.535245 val accuracy: 0.500000
#
# Train 33th module
# iteration 0 / 1000: loss 2.302560
# iteration 100 / 1000: loss 1.911096
# iteration 200 / 1000: loss 1.757005
# iteration 300 / 1000: loss 1.670253
# iteration 400 / 1000: loss 1.517635
# iteration 500 / 1000: loss 1.561199
# iteration 600 / 1000: loss 1.496132
# iteration 700 / 1000: loss 1.419084
# iteration 800 / 1000: loss 1.455779
# iteration 900 / 1000: loss 1.382087
# lr 1.000000e-03 reg 1.000000e-04 bs 8.000000e+02 hs 8.000000e+01 train accuracy: 0.528327 val accuracy: 0.489000
#
# Train 34th module
# iteration 0 / 1000: loss 2.302602
# iteration 100 / 1000: loss 1.950886
# iteration 200 / 1000: loss 1.717325
# iteration 300 / 1000: loss 1.633001
# iteration 400 / 1000: loss 1.539376
# iteration 500 / 1000: loss 1.505985
# iteration 600 / 1000: loss 1.501001
# iteration 700 / 1000: loss 1.444388
# iteration 800 / 1000: loss 1.365299
# iteration 900 / 1000: loss 1.352759
# lr 1.000000e-03 reg 1.000000e-04 bs 8.000000e+02 hs 1.600000e+02 train accuracy: 0.536939 val accuracy: 0.496000
#
# Train 35th module
# iteration 0 / 1000: loss 2.302576
# iteration 100 / 1000: loss 1.874299
# iteration 200 / 1000: loss 1.749137
# iteration 300 / 1000: loss 1.609399
# iteration 400 / 1000: loss 1.573136
# iteration 500 / 1000: loss 1.488785
# iteration 600 / 1000: loss 1.453564
# iteration 700 / 1000: loss 1.430154
# iteration 800 / 1000: loss 1.371531
# iteration 900 / 1000: loss 1.396161
# lr 1.000000e-03 reg 1.000000e-04 bs 8.000000e+02 hs 3.200000e+02 train accuracy: 0.547673 val accuracy: 0.509000
#
# Train 36th module
# iteration 0 / 1000: loss 2.302807
# iteration 100 / 1000: loss 2.302208
# iteration 200 / 1000: loss 2.295120
# iteration 300 / 1000: loss 2.251435
# iteration 400 / 1000: loss 2.170081
# iteration 500 / 1000: loss 2.157663
# iteration 600 / 1000: loss 2.123441
# iteration 700 / 1000: loss 2.045380
# iteration 800 / 1000: loss 1.919931
# iteration 900 / 1000: loss 1.993861
# lr 1.000000e-04 reg 1.000000e-01 bs 2.000000e+02 hs 8.000000e+01 train accuracy: 0.297020 val accuracy: 0.292000
#
# Train 37th module
# iteration 0 / 1000: loss 2.303072
# iteration 100 / 1000: loss 2.301251
# iteration 200 / 1000: loss 2.284470
# iteration 300 / 1000: loss 2.224655
# iteration 400 / 1000: loss 2.135191
# iteration 500 / 1000: loss 2.089689
# iteration 600 / 1000: loss 1.973991
# iteration 700 / 1000: loss 2.077292
# iteration 800 / 1000: loss 1.980545
# iteration 900 / 1000: loss 1.889729
# lr 1.000000e-04 reg 1.000000e-01 bs 2.000000e+02 hs 1.600000e+02 train accuracy: 0.303898 val accuracy: 0.307000
#
# Train 38th module
# iteration 0 / 1000: loss 2.303574
# iteration 100 / 1000: loss 2.300987
# iteration 200 / 1000: loss 2.273828
# iteration 300 / 1000: loss 2.221042
# iteration 400 / 1000: loss 2.102820
# iteration 500 / 1000: loss 2.159887
# iteration 600 / 1000: loss 1.993815
# iteration 700 / 1000: loss 1.993166
# iteration 800 / 1000: loss 1.973330
# iteration 900 / 1000: loss 1.911130
# lr 1.000000e-04 reg 1.000000e-01 bs 2.000000e+02 hs 3.200000e+02 train accuracy: 0.311510 val accuracy: 0.314000
#
# Train 39th module
# iteration 0 / 1000: loss 2.302834
# iteration 100 / 1000: loss 2.302060
# iteration 200 / 1000: loss 2.296232
# iteration 300 / 1000: loss 2.258105
# iteration 400 / 1000: loss 2.151429
# iteration 500 / 1000: loss 2.104592
# iteration 600 / 1000: loss 2.066780
# iteration 700 / 1000: loss 2.075999
# iteration 800 / 1000: loss 1.924447
# iteration 900 / 1000: loss 1.971393
# lr 1.000000e-04 reg 1.000000e-01 bs 4.000000e+02 hs 8.000000e+01 train accuracy: 0.289306 val accuracy: 0.286000
#
# Train 40th module
# iteration 0 / 1000: loss 2.303130
# iteration 100 / 1000: loss 2.301438
# iteration 200 / 1000: loss 2.287647
# iteration 300 / 1000: loss 2.230132
# iteration 400 / 1000: loss 2.127302
# iteration 500 / 1000: loss 2.082700
# iteration 600 / 1000: loss 2.058886
# iteration 700 / 1000: loss 1.969880
# iteration 800 / 1000: loss 1.972224
# iteration 900 / 1000: loss 1.927094
# lr 1.000000e-04 reg 1.000000e-01 bs 4.000000e+02 hs 1.600000e+02 train accuracy: 0.303959 val accuracy: 0.305000
#
# Train 41th module
# iteration 0 / 1000: loss 2.303580
# iteration 100 / 1000: loss 2.300804
# iteration 200 / 1000: loss 2.277062
# iteration 300 / 1000: loss 2.211579
# iteration 400 / 1000: loss 2.108743
# iteration 500 / 1000: loss 2.024221
# iteration 600 / 1000: loss 1.995929
# iteration 700 / 1000: loss 2.003454
# iteration 800 / 1000: loss 1.962733
# iteration 900 / 1000: loss 1.923382
# lr 1.000000e-04 reg 1.000000e-01 bs 4.000000e+02 hs 3.200000e+02 train accuracy: 0.312592 val accuracy: 0.309000
#
# Train 42th module
# iteration 0 / 1000: loss 2.302839
# iteration 100 / 1000: loss 2.302208
# iteration 200 / 1000: loss 2.295882
# iteration 300 / 1000: loss 2.258042
# iteration 400 / 1000: loss 2.187806
# iteration 500 / 1000: loss 2.115792
# iteration 600 / 1000: loss 2.053974
# iteration 700 / 1000: loss 2.033728
# iteration 800 / 1000: loss 2.010252
# iteration 900 / 1000: loss 1.917450
# lr 1.000000e-04 reg 1.000000e-01 bs 8.000000e+02 hs 8.000000e+01 train accuracy: 0.293020 val accuracy: 0.282000
#
# Train 43th module
# iteration 0 / 1000: loss 2.303062
# iteration 100 / 1000: loss 2.301218
# iteration 200 / 1000: loss 2.284089
# iteration 300 / 1000: loss 2.203916
# iteration 400 / 1000: loss 2.153088
# iteration 500 / 1000: loss 2.115057
# iteration 600 / 1000: loss 2.031027
# iteration 700 / 1000: loss 2.082799
# iteration 800 / 1000: loss 1.982204
# iteration 900 / 1000: loss 1.945242
# lr 1.000000e-04 reg 1.000000e-01 bs 8.000000e+02 hs 1.600000e+02 train accuracy: 0.302694 val accuracy: 0.295000
#
# Train 44th module
# iteration 0 / 1000: loss 2.303552
# iteration 100 / 1000: loss 2.300632
# iteration 200 / 1000: loss 2.275011
# iteration 300 / 1000: loss 2.192748
# iteration 400 / 1000: loss 2.104594
# iteration 500 / 1000: loss 2.080228
# iteration 600 / 1000: loss 2.064310
# iteration 700 / 1000: loss 1.985474
# iteration 800 / 1000: loss 1.940282
# iteration 900 / 1000: loss 1.938062
# lr 1.000000e-04 reg 1.000000e-01 bs 8.000000e+02 hs 3.200000e+02 train accuracy: 0.315245 val accuracy: 0.307000
#
# Train 45th module
# iteration 0 / 1000: loss 2.302589
# iteration 100 / 1000: loss 2.301755
# iteration 200 / 1000: loss 2.293394
# iteration 300 / 1000: loss 2.262755
# iteration 400 / 1000: loss 2.185184
# iteration 500 / 1000: loss 2.073224
# iteration 600 / 1000: loss 2.056370
# iteration 700 / 1000: loss 1.949121
# iteration 800 / 1000: loss 1.984812
# iteration 900 / 1000: loss 1.970013
# lr 1.000000e-04 reg 1.000000e-02 bs 2.000000e+02 hs 8.000000e+01 train accuracy: 0.297490 val accuracy: 0.301000
#
# Train 46th module
# iteration 0 / 1000: loss 2.302637
# iteration 100 / 1000: loss 2.300782
# iteration 200 / 1000: loss 2.285302
# iteration 300 / 1000: loss 2.221185
# iteration 400 / 1000: loss 2.167699
# iteration 500 / 1000: loss 2.079028
# iteration 600 / 1000: loss 2.029354
# iteration 700 / 1000: loss 2.060854
# iteration 800 / 1000: loss 1.932495
# iteration 900 / 1000: loss 1.852528
# lr 1.000000e-04 reg 1.000000e-02 bs 2.000000e+02 hs 1.600000e+02 train accuracy: 0.308061 val accuracy: 0.302000
#
# Train 47th module
# iteration 0 / 1000: loss 2.302682
# iteration 100 / 1000: loss 2.300246
# iteration 200 / 1000: loss 2.281595
# iteration 300 / 1000: loss 2.197548
# iteration 400 / 1000: loss 2.085898
# iteration 500 / 1000: loss 2.034333
# iteration 600 / 1000: loss 2.027899
# iteration 700 / 1000: loss 2.011545
# iteration 800 / 1000: loss 1.921686
# iteration 900 / 1000: loss 1.917901
# lr 1.000000e-04 reg 1.000000e-02 bs 2.000000e+02 hs 3.200000e+02 train accuracy: 0.318041 val accuracy: 0.308000
#
# Train 48th module
# iteration 0 / 1000: loss 2.302621
# iteration 100 / 1000: loss 2.302054
# iteration 200 / 1000: loss 2.297938
# iteration 300 / 1000: loss 2.268073
# iteration 400 / 1000: loss 2.160838
# iteration 500 / 1000: loss 2.113643
# iteration 600 / 1000: loss 2.048165
# iteration 700 / 1000: loss 1.977661
# iteration 800 / 1000: loss 1.997827
# iteration 900 / 1000: loss 1.948959
# lr 1.000000e-04 reg 1.000000e-02 bs 4.000000e+02 hs 8.000000e+01 train accuracy: 0.290184 val accuracy: 0.285000
#
# Train 49th module
# iteration 0 / 1000: loss 2.302601
# iteration 100 / 1000: loss 2.301411
# iteration 200 / 1000: loss 2.288206
# iteration 300 / 1000: loss 2.221240
# iteration 400 / 1000: loss 2.124221
# iteration 500 / 1000: loss 2.087234
# iteration 600 / 1000: loss 2.054807
# iteration 700 / 1000: loss 1.992952
# iteration 800 / 1000: loss 1.954742
# iteration 900 / 1000: loss 1.943304
# lr 1.000000e-04 reg 1.000000e-02 bs 4.000000e+02 hs 1.600000e+02 train accuracy: 0.305796 val accuracy: 0.305000
#
# Train 50th module
# iteration 0 / 1000: loss 2.302632
# iteration 100 / 1000: loss 2.300426
# iteration 200 / 1000: loss 2.276486
# iteration 300 / 1000: loss 2.196918
# iteration 400 / 1000: loss 2.104797
# iteration 500 / 1000: loss 2.069285
# iteration 600 / 1000: loss 2.073117
# iteration 700 / 1000: loss 1.973138
# iteration 800 / 1000: loss 1.944899
# iteration 900 / 1000: loss 1.905911
# lr 1.000000e-04 reg 1.000000e-02 bs 4.000000e+02 hs 3.200000e+02 train accuracy: 0.315735 val accuracy: 0.311000
#
# Train 51th module
# iteration 0 / 1000: loss 2.302611
# iteration 100 / 1000: loss 2.302003
# iteration 200 / 1000: loss 2.296521
# iteration 300 / 1000: loss 2.258888
# iteration 400 / 1000: loss 2.165078
# iteration 500 / 1000: loss 2.110199
# iteration 600 / 1000: loss 2.037082
# iteration 700 / 1000: loss 2.029386
# iteration 800 / 1000: loss 2.014324
# iteration 900 / 1000: loss 1.955957
# lr 1.000000e-04 reg 1.000000e-02 bs 8.000000e+02 hs 8.000000e+01 train accuracy: 0.288286 val accuracy: 0.288000
#
# Train 52th module
# iteration 0 / 1000: loss 2.302674
# iteration 100 / 1000: loss 2.301382
# iteration 200 / 1000: loss 2.287963
# iteration 300 / 1000: loss 2.219680
# iteration 400 / 1000: loss 2.150017
# iteration 500 / 1000: loss 2.092974
# iteration 600 / 1000: loss 2.085235
# iteration 700 / 1000: loss 1.975118
# iteration 800 / 1000: loss 1.970912
# iteration 900 / 1000: loss 1.948350
# lr 1.000000e-04 reg 1.000000e-02 bs 8.000000e+02 hs 1.600000e+02 train accuracy: 0.304878 val accuracy: 0.305000
#
# Train 53th module
# iteration 0 / 1000: loss 2.302717
# iteration 100 / 1000: loss 2.300419
# iteration 200 / 1000: loss 2.279694
# iteration 300 / 1000: loss 2.195302
# iteration 400 / 1000: loss 2.148786
# iteration 500 / 1000: loss 2.067582
# iteration 600 / 1000: loss 2.002110
# iteration 700 / 1000: loss 2.012523
# iteration 800 / 1000: loss 1.980247
# iteration 900 / 1000: loss 1.961129
# lr 1.000000e-04 reg 1.000000e-02 bs 8.000000e+02 hs 3.200000e+02 train accuracy: 0.317429 val accuracy: 0.314000
#
# Train 54th module
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.301624
# iteration 200 / 1000: loss 2.292141
# iteration 300 / 1000: loss 2.220183
# iteration 400 / 1000: loss 2.193293
# iteration 500 / 1000: loss 2.136690
# iteration 600 / 1000: loss 2.065053
# iteration 700 / 1000: loss 1.990307
# iteration 800 / 1000: loss 1.855560
# iteration 900 / 1000: loss 1.932720
# lr 1.000000e-04 reg 1.000000e-03 bs 2.000000e+02 hs 8.000000e+01 train accuracy: 0.293551 val accuracy: 0.301000
#
# Train 55th module
# iteration 0 / 1000: loss 2.302581
# iteration 100 / 1000: loss 2.301349
# iteration 200 / 1000: loss 2.290586
# iteration 300 / 1000: loss 2.213757
# iteration 400 / 1000: loss 2.194425
# iteration 500 / 1000: loss 2.077263
# iteration 600 / 1000: loss 2.089638
# iteration 700 / 1000: loss 1.967753
# iteration 800 / 1000: loss 2.000142
# iteration 900 / 1000: loss 2.020896
# lr 1.000000e-04 reg 1.000000e-03 bs 2.000000e+02 hs 1.600000e+02 train accuracy: 0.304490 val accuracy: 0.308000
#
# Train 56th module
# iteration 0 / 1000: loss 2.302548
# iteration 100 / 1000: loss 2.299329
# iteration 200 / 1000: loss 2.275656
# iteration 300 / 1000: loss 2.166805
# iteration 400 / 1000: loss 2.141093
# iteration 500 / 1000: loss 2.041676
# iteration 600 / 1000: loss 2.058086
# iteration 700 / 1000: loss 1.996445
# iteration 800 / 1000: loss 1.913969
# iteration 900 / 1000: loss 1.878595
# lr 1.000000e-04 reg 1.000000e-03 bs 2.000000e+02 hs 3.200000e+02 train accuracy: 0.316857 val accuracy: 0.311000
#
# Train 57th module
# iteration 0 / 1000: loss 2.302594
# iteration 100 / 1000: loss 2.301846
# iteration 200 / 1000: loss 2.296273
# iteration 300 / 1000: loss 2.253871
# iteration 400 / 1000: loss 2.173637
# iteration 500 / 1000: loss 2.148469
# iteration 600 / 1000: loss 2.073482
# iteration 700 / 1000: loss 2.017885
# iteration 800 / 1000: loss 1.992697
# iteration 900 / 1000: loss 1.945588
# lr 1.000000e-04 reg 1.000000e-03 bs 4.000000e+02 hs 8.000000e+01 train accuracy: 0.296939 val accuracy: 0.294000
#
# Train 58th module
# iteration 0 / 1000: loss 2.302600
# iteration 100 / 1000: loss 2.300901
# iteration 200 / 1000: loss 2.286024
# iteration 300 / 1000: loss 2.199966
# iteration 400 / 1000: loss 2.142710
# iteration 500 / 1000: loss 2.134499
# iteration 600 / 1000: loss 2.039546
# iteration 700 / 1000: loss 1.986641
# iteration 800 / 1000: loss 1.967290
# iteration 900 / 1000: loss 1.957346
# lr 1.000000e-04 reg 1.000000e-03 bs 4.000000e+02 hs 1.600000e+02 train accuracy: 0.299408 val accuracy: 0.288000
#
# Train 59th module
# iteration 0 / 1000: loss 2.302562
# iteration 100 / 1000: loss 2.299969
# iteration 200 / 1000: loss 2.270336
# iteration 300 / 1000: loss 2.183581
# iteration 400 / 1000: loss 2.083651
# iteration 500 / 1000: loss 2.067975
# iteration 600 / 1000: loss 2.020502
# iteration 700 / 1000: loss 1.956592
# iteration 800 / 1000: loss 1.964871
# iteration 900 / 1000: loss 1.926743
# lr 1.000000e-04 reg 1.000000e-03 bs 4.000000e+02 hs 3.200000e+02 train accuracy: 0.316327 val accuracy: 0.313000
#
# Train 60th module
# iteration 0 / 1000: loss 2.302604
# iteration 100 / 1000: loss 2.301892
# iteration 200 / 1000: loss 2.296219
# iteration 300 / 1000: loss 2.246699
# iteration 400 / 1000: loss 2.167371
# iteration 500 / 1000: loss 2.108856
# iteration 600 / 1000: loss 2.076466
# iteration 700 / 1000: loss 2.072103
# iteration 800 / 1000: loss 2.015196
# iteration 900 / 1000: loss 1.956807
# lr 1.000000e-04 reg 1.000000e-03 bs 8.000000e+02 hs 8.000000e+01 train accuracy: 0.295551 val accuracy: 0.292000
#
# Train 61th module
# iteration 0 / 1000: loss 2.302624
# iteration 100 / 1000: loss 2.301047
# iteration 200 / 1000: loss 2.289622
# iteration 300 / 1000: loss 2.201583
# iteration 400 / 1000: loss 2.140421
# iteration 500 / 1000: loss 2.096010
# iteration 600 / 1000: loss 2.038297
# iteration 700 / 1000: loss 2.017488
# iteration 800 / 1000: loss 1.975304
# iteration 900 / 1000: loss 1.958333
# lr 1.000000e-04 reg 1.000000e-03 bs 8.000000e+02 hs 1.600000e+02 train accuracy: 0.303286 val accuracy: 0.298000
#
# Train 62th module
# iteration 0 / 1000: loss 2.302531
# iteration 100 / 1000: loss 2.299444
# iteration 200 / 1000: loss 2.275683
# iteration 300 / 1000: loss 2.191488
# iteration 400 / 1000: loss 2.112625
# iteration 500 / 1000: loss 2.066736
# iteration 600 / 1000: loss 2.041135
# iteration 700 / 1000: loss 1.976164
# iteration 800 / 1000: loss 1.946923
# iteration 900 / 1000: loss 1.905774
# lr 1.000000e-04 reg 1.000000e-03 bs 8.000000e+02 hs 3.200000e+02 train accuracy: 0.315347 val accuracy: 0.310000
#
# Train 63th module
# iteration 0 / 1000: loss 2.302604
# iteration 100 / 1000: loss 2.301525
# iteration 200 / 1000: loss 2.294643
# iteration 300 / 1000: loss 2.238888
# iteration 400 / 1000: loss 2.185023
# iteration 500 / 1000: loss 2.102425
# iteration 600 / 1000: loss 2.056264
# iteration 700 / 1000: loss 1.973462
# iteration 800 / 1000: loss 2.022833
# iteration 900 / 1000: loss 1.970588
# lr 1.000000e-04 reg 1.000000e-04 bs 2.000000e+02 hs 8.000000e+01 train accuracy: 0.290612 val accuracy: 0.287000
#
# Train 64th module
# iteration 0 / 1000: loss 2.302567
# iteration 100 / 1000: loss 2.301235
# iteration 200 / 1000: loss 2.289939
# iteration 300 / 1000: loss 2.237287
# iteration 400 / 1000: loss 2.087501
# iteration 500 / 1000: loss 2.047674
# iteration 600 / 1000: loss 2.127912
# iteration 700 / 1000: loss 2.003897
# iteration 800 / 1000: loss 1.977679
# iteration 900 / 1000: loss 1.947918
# lr 1.000000e-04 reg 1.000000e-04 bs 2.000000e+02 hs 1.600000e+02 train accuracy: 0.302796 val accuracy: 0.303000
#
# Train 65th module
# iteration 0 / 1000: loss 2.302567
# iteration 100 / 1000: loss 2.298649
# iteration 200 / 1000: loss 2.271655
# iteration 300 / 1000: loss 2.219846
# iteration 400 / 1000: loss 2.196623
# iteration 500 / 1000: loss 2.077685
# iteration 600 / 1000: loss 2.089705
# iteration 700 / 1000: loss 1.998247
# iteration 800 / 1000: loss 1.992001
# iteration 900 / 1000: loss 1.931219
# lr 1.000000e-04 reg 1.000000e-04 bs 2.000000e+02 hs 3.200000e+02 train accuracy: 0.313898 val accuracy: 0.316000
#
# Train 66th module
# iteration 0 / 1000: loss 2.302607
# iteration 100 / 1000: loss 2.302001
# iteration 200 / 1000: loss 2.297377
# iteration 300 / 1000: loss 2.259836
# iteration 400 / 1000: loss 2.167960
# iteration 500 / 1000: loss 2.078964
# iteration 600 / 1000: loss 2.073948
# iteration 700 / 1000: loss 2.043175
# iteration 800 / 1000: loss 2.003697
# iteration 900 / 1000: loss 1.954797
# lr 1.000000e-04 reg 1.000000e-04 bs 4.000000e+02 hs 8.000000e+01 train accuracy: 0.293449 val accuracy: 0.298000
#
# Train 67th module
# iteration 0 / 1000: loss 2.302598
# iteration 100 / 1000: loss 2.301311
# iteration 200 / 1000: loss 2.289545
# iteration 300 / 1000: loss 2.227342
# iteration 400 / 1000: loss 2.176227
# iteration 500 / 1000: loss 2.081939
# iteration 600 / 1000: loss 2.042870
# iteration 700 / 1000: loss 1.980652
# iteration 800 / 1000: loss 2.053512
# iteration 900 / 1000: loss 1.960278
# lr 1.000000e-04 reg 1.000000e-04 bs 4.000000e+02 hs 1.600000e+02 train accuracy: 0.303449 val accuracy: 0.305000
#
# Train 68th module
# iteration 0 / 1000: loss 2.302574
# iteration 100 / 1000: loss 2.299728
# iteration 200 / 1000: loss 2.277048
# iteration 300 / 1000: loss 2.215513
# iteration 400 / 1000: loss 2.137054
# iteration 500 / 1000: loss 2.083181
# iteration 600 / 1000: loss 1.994523
# iteration 700 / 1000: loss 1.984147
# iteration 800 / 1000: loss 1.901285
# iteration 900 / 1000: loss 1.894960
# lr 1.000000e-04 reg 1.000000e-04 bs 4.000000e+02 hs 3.200000e+02 train accuracy: 0.315510 val accuracy: 0.305000
#
# Train 69th module
# iteration 0 / 1000: loss 2.302584
# iteration 100 / 1000: loss 2.301909
# iteration 200 / 1000: loss 2.294966
# iteration 300 / 1000: loss 2.249731
# iteration 400 / 1000: loss 2.171212
# iteration 500 / 1000: loss 2.108656
# iteration 600 / 1000: loss 2.076312
# iteration 700 / 1000: loss 2.038822
# iteration 800 / 1000: loss 2.042535
# iteration 900 / 1000: loss 2.005103
# lr 1.000000e-04 reg 1.000000e-04 bs 8.000000e+02 hs 8.000000e+01 train accuracy: 0.291245 val accuracy: 0.288000
#
# Train 70th module
# iteration 0 / 1000: loss 2.302619
# iteration 100 / 1000: loss 2.301399
# iteration 200 / 1000: loss 2.292084
# iteration 300 / 1000: loss 2.242366
# iteration 400 / 1000: loss 2.146109
# iteration 500 / 1000: loss 2.100452
# iteration 600 / 1000: loss 2.060543
# iteration 700 / 1000: loss 2.010661
# iteration 800 / 1000: loss 1.956902
# iteration 900 / 1000: loss 1.913439
# lr 1.000000e-04 reg 1.000000e-04 bs 8.000000e+02 hs 1.600000e+02 train accuracy: 0.304245 val accuracy: 0.300000
#
# Train 71th module
# iteration 0 / 1000: loss 2.302542
# iteration 100 / 1000: loss 2.299339
# iteration 200 / 1000: loss 2.273524
# iteration 300 / 1000: loss 2.211957
# iteration 400 / 1000: loss 2.130771
# iteration 500 / 1000: loss 2.048979
# iteration 600 / 1000: loss 2.029888
# iteration 700 / 1000: loss 2.002077
# iteration 800 / 1000: loss 1.952796
# iteration 900 / 1000: loss 1.896726
# lr 1.000000e-04 reg 1.000000e-04 bs 8.000000e+02 hs 3.200000e+02 train accuracy: 0.315224 val accuracy: 0.314000

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.527
